# %%
import os, re
from IPython.display import Audio, display
from bs4 import BeautifulSoup

import utils.prepare as prep
import pandas as pd

# %%
# Audacity parsing functions
def find_aup_file(path):
    aup_files = [f for f in os.listdir(path) if f.endswith('.aup')]
    return aup_files[0] # Assume only one file per directory

def parse_audacity_project(path_to_aup_file):
    
    with open(path_to_aup_file, 'r') as f:
        aup = BeautifulSoup(f, features="lxml-xml")
    
    root_path = os.path.split(path_to_aup_file)[:-1]
    root_path = os.path.join(*root_path)

    project = aup.find('project')
    proj_name = project.get('projname')
    data_path = os.path.join(root_path, proj_name)

    proj_imports = project.find_all('import')
    proj_files = []
    for item in proj_imports:
        filename, offset= item.get('filename'), float(item.get('offset'))
        entry = {
            'filename': filename,
            'offset': offset
        }
        proj_files.append(entry)

    
    output = {
        'project_name' : proj_name,
        'root_path': root_path,
        'data_path': data_path,
        'files': proj_files
    }

    return output

def get_discord_name(filename):
    discord_name_pattern = r'.+-(.*)\..+'
    username = re.search(discord_name_pattern, filename).group(1)
    return username

# %%
directory = './data/db_02-03-2023/'

aup_file = os.path.join(directory, find_aup_file(directory))
project = parse_audacity_project(aup_file)

# %%
# paths = [os.path.join(project['data_path'], file['filename']) for file in project['files']]

# asr_datas = []
# for path in paths:
#     # print(path)
#     result = prep.get_asr_data(path, refresh=False, model_name='medium.en')
#     asr_datas.append(result)

# %%
# for file in project['files']:
#     filepath = os.path.join(project['data_path'], file['filename'])
#     alignment_data = prep.get_alignment_data(filepath, refresh=True)

# %%
def listen_segment(segment, audio):
    from IPython.display import display, Audio
    SR = 16000
    start = segment['start']
    end = segment['end']
    clip = audio[start:end]
    display(Audio(clip, rate=SR))

# %%
dataframes = []
for file in project['files']:
        filepath = os.path.join(project['data_path'], file['filename'])
        srt_data = prep.get_srt_data(filepath)
        df = pd.DataFrame(srt_data)
        df['file'] = file['filename']
        dataframes.append(df)

df.head()
# Out:
#      start      end                                           children  \
# 0   940576   957408  [{'text': 'I', 'start': 942530, 'end': 943832}...
# 1  1013792  1032672  [{'text': 'Hello', 'start': 1015520, 'end': 10...
# 2  1158688  1211360  [{'text': 'What', 'start': 1161376, 'end': 116...
# 3  2412064  2442208  [{'text': 'Was', 'start': 2417797, 'end': 2419...
# 4  2475040  2494432  [{'text': '14 months?', 'start': 2484329, 'end...
#
#                                 text                    file
# 0                     I believe you.  4-IlMaximuslI_9218.ogg
# 1                     Hello friends.  4-IlMaximuslI_9218.ogg
# 2  What are we doing for down below?  4-IlMaximuslI_9218.ogg
# 3     Was it 400 and something days?  4-IlMaximuslI_9218.ogg
# 4                         14 months?  4-IlMaximuslI_9218.ogg

# %%
big = pd.concat(dataframes)
big = big.sort_values('start')
big.head()
# Out:
#     start     end                                           children  \
# 0    2080   17376  [{'text': 'Now', 'start': 2080, 'end': 5672}, ...
# 0   30752   91616  [{'text': 'Oh', 'start': 33004, 'end': 42012},...
# 0   42016   56800      [{'text': 'I', 'start': 51985, 'end': 55523}]
# 1   99360  138720  [{'text': 'took', 'start': 101620, 'end': 1045...
# 1  151072  201184  [{'text': 'But', 'start': 151012, 'end': 15294...
#
#                                          text                  file
# 0                              Now recording!       1-CS12_4510.ogg
# 0             Oh no, he didn't say the thing!  3-JadePixie_7138.ogg
# 0                                           I       2-Crux_4429.ogg
# 1    took away his permissions to say things.       2-Crux_4429.ogg
# 1  But I like to hear him say, now recording.  3-JadePixie_7138.ogg

# %%
# import torch
# import torchaudio
# audios = dict()
# for file in project['files']:
#         filename = file['filename']
#         filepath = os.path.join(project['data_path'], file['filename'])
#         audios[filename] = prep.get_waveform(filepath)

# audios
# def save_audio(path: str,
#                tensor: torch.Tensor,
#                sampling_rate: int = 16000):
#     torchaudio.save(path, tensor.unsqueeze(0), sampling_rate, bits_per_sample=16)


# chunks = []
# for idx, row in big.sort_values('start').iterrows():
#     file = row['file']
#     start = row['start']
#     end = row['end']
#     chunks.append(audios[file][start:end])

# wav = torch.cat(chunks)
# save_audio('output.wav', wav)

# %%
## Script format
text = ''
current_speaker = ''
for idx, row in big.sort_values('start').iterrows():
    speaker = get_discord_name(row['file'])
    s = row['text']
    if len(s.strip()) > 0:
        if not current_speaker == speaker:
            text += f"\n\n{speaker}:\n"
            current_speaker = speaker
    text = ' '.join([text,s])


with open(os.path.join(directory, 'output.txt'), 'w') as f:
    f.write(text)

# %% [markdown]
# For the most part this works.  There is a minor issue where some words were attached to the segment before the segment they were actually spoken.  For now I will probably leave it that way since it seems to happen the most to drop-words.

# %%
## Bag of words
text = ''
current_speaker = ''
for idx, row in big.sort_values('start').iterrows():
    speaker = get_discord_name(row['file'])
    s = row['text']
    if len(s.strip()) > 0:
        if not current_speaker == speaker:
            # text += f"\n\n{speaker}:\n"
            text += f"\n"
            current_speaker = speaker
    text = ' '.join([text,s])


with open(os.path.join(directory, 'corpus.txt'), 'w') as f:
    f.write(text)

# %%
# 16000 frames = 1 second
SR = 16000
frame1 = 17376
frame2 = 233776096

def frame_to_srt_timestamp(frame, rate=SR):
    ms, remainder = divmod(frame, SR/1000)
    sec, ms = divmod(ms, 1000)
    min, sec = divmod(sec, 60)
    hr, min = divmod(min, 60)
    return f"{int(hr):02d}:{int(min):02d}:{int(sec):02d},{int(ms):03d}"

print(frame_to_srt_timestamp(frame1))
print(frame_to_srt_timestamp(frame2))
# Out:
# 00:00:01,086
# 04:03:31,006

# %%
small = big.reset_index().copy().drop(columns='index')
vals = pd.DataFrame(prep.align_chunks(small[['start','end']].to_dict(orient='records')))
small[['start','end']] = vals
small.head()
# Out:
#     start     end                                           children  \
# 0       0   15296  [{'text': 'Now', 'start': 2080, 'end': 5672}, ...
# 1   15296   76160  [{'text': 'Oh', 'start': 33004, 'end': 42012},...
# 2   76160   90944      [{'text': 'I', 'start': 51985, 'end': 55523}]
# 3   90944  130304  [{'text': 'took', 'start': 101620, 'end': 1045...
# 4  130304  180416  [{'text': 'But', 'start': 151012, 'end': 15294...
#
#                                          text                  file
# 0                              Now recording!       1-CS12_4510.ogg
# 1             Oh no, he didn't say the thing!  3-JadePixie_7138.ogg
# 2                                           I       2-Crux_4429.ogg
# 3    took away his permissions to say things.       2-Crux_4429.ogg
# 4  But I like to hear him say, now recording.  3-JadePixie_7138.ogg

# %%
## srt subtitles
output = ''
n = '\n'
count = 0
for i, (idx, row) in enumerate(small.sort_values('start').iterrows()):
    txt = row['text']
    if len(txt) > 0:
        count += 1
        speaker = get_discord_name(row['file'])[:4]
        start = frame_to_srt_timestamp(row['start'])
        end = frame_to_srt_timestamp(row['end'])
        output += f"{count}"+n
        output += f"{start} --> {end}"+n
        output += f"{speaker}:{n}{txt.strip()}"+n+n

with open(os.path.join(directory, 'short.srt'), 'w') as f:
    f.write(output)    
print(output)
# Out:
# 1
# 00:00:00,000 --> 00:00:00,956
# CS12:
# Now recording!
#
# 2
# 00:00:00,956 --> 00:00:04,760
# Jade:
# Oh no, he didn't say the thing!
#
# 3
# 00:00:04,760 --> 00:00:05,684
# Crux:
# I
#
# 4
# 00:00:05,684 --> 00:00:08,144
# Crux:
# took away his permissions to say things.
#
# 5
# 00:00:08,144 --> 00:00:11,276
# Jade:
# But I like to hear him say, now recording.
#
# 6
# 00:00:11,656 --> 00:00:14,404
# Jade:
# It brought me comfort
#
# 7
# 00:00:14,404 --> 00:00:16,032
# Jade:
# and encouragement.
#
# 8
# 00:00:16,032 --> 00:00:17,212
# CS12:
# You know Josh, you could have just
#
# 9
# 00:00:17,212 --> 00:00:19,192
# CS12:
# right clicked him and done a server mute,
#
# 10
# 00:00:19,192 --> 00:00:20,404
# CS12:
# but this works too!
#
# 11
# 00:00:20,404 --> 00:00:22,192
# CS12:
# Anyway, welcome.
#
# 12
# 00:00:22,192 --> 00:00:22,732
# Jade:
# What
#
# 13
# 00:00:22,732 --> 00:00:23,272
# Jade:
# if
#
# 14
# 00:00:23,272 --> 00:00:24,740
# Jade:
# Craig can't hear me?
#
# 15
# 00:00:24,740 --> 00:00:26,592
# CS12:
# How would he be able to tell me?
#
# 16
# 00:00:27,164 --> 00:00:31,224
# Jade:
# Craig, if you can't hear me, you gotta say something.
#
# 17
# 00:00:31,956 --> 00:00:33,872
# CS12:
# Oh, well it sounds like he can hear you.
#
# 18
# 00:00:33,872 --> 00:00:35,148
# Jade:
# Uh, okay.
#
# 19
# 00:00:35,560 --> 00:00:36,612
# IlMa:
# I believe you.
#
# 20
# 00:00:36,612 --> 00:00:37,792
# IlMa:
# Hello friends.
#
# 21
# 00:00:37,792 --> 00:00:38,396
# Jade:
# I
#
# 22
# 00:00:38,396 --> 00:00:39,544
# Crux:
# Great.
#
# 23
# 00:00:39,860 --> 00:00:41,200
# Crux:
# Hello.
#
# 24
# 00:00:41,200 --> 00:00:44,492
# IlMa:
# What are we doing for down below?
#
# 25
# 00:00:44,492 --> 00:00:45,320
# CS12:
# Alllll
#
# 26
# 00:00:45,320 --> 00:00:45,860
# CS12:
# below.
#
# 27
# 00:00:45,860 --> 00:00:49,024
# Jade:
# have recapping, I guess,
#
# 28
# 00:00:49,024 --> 00:00:50,972
# Jade:
# because
#
# 29
# 00:00:50,972 --> 00:00:51,576
# Jade:
# we've got
#
# 30
# 00:00:51,576 --> 00:00:53,684
# Jade:
# multiple quests that we can go on.
#
# 31
# 00:00:53,684 --> 00:00:56,112
# Jade:
# We have just been
#
# 32
# 00:00:56,112 --> 00:01:00,332
# Jade:
# informed that war is coming to Kirk's
#
# 33
# 00:01:00,332 --> 00:01:01,096
# Jade:
# base
#
# 34
# 00:01:01,096 --> 00:01:05,540
# Jade:
# and that a bunch of Sha'a Ka'al people are disappearing
#
# 35
# 00:01:05,540 --> 00:01:07,392
# Jade:
# down on Rhaegis.
#
# 36
# 00:01:08,856 --> 00:01:10,964
# Jade:
# Myla found a city in a bottle
#
# 37
# 00:01:10,964 --> 00:01:12,144
# Jade:
# and
#
# 38
# 00:01:12,144 --> 00:01:13,836
# Jade:
# somewhere inside the city in the bottle
#
# 39
# 00:01:13,836 --> 00:01:15,080
# Jade:
# there is a
#
# 40
# 00:01:15,080 --> 00:01:16,548
# Jade:
# powerful
#
# 41
# 00:01:16,548 --> 00:01:18,912
# Jade:
# item of sorts that can protect
#
# 42
# 00:01:18,912 --> 00:01:19,964
# Jade:
# us from undead.
#
# 43
# 00:01:21,048 --> 00:01:24,084
# Jade:
# And also we've been gone from, we've
#
# 44
# 00:01:24,084 --> 00:01:24,560
# Jade:
# been,
#
# 45
# 00:01:24,560 --> 00:01:27,852
# Jade:
# you know, gone from existence for the past
#
# 46
# 00:01:27,852 --> 00:01:29,256
# Jade:
# slightly over a year.
#
# 47
# 00:01:29,256 --> 00:01:31,140
# IlMa:
# Was it 400 and something days?
#
# 48
# 00:01:31,140 --> 00:01:32,352
# IlMa:
# 14 months?
#
# 49
# 00:01:32,352 --> 00:01:35,164
# Jade:
# And Ezreal's mind is just
#
# 50
# 00:01:35,164 --> 00:01:37,880
# Jade:
# getting saw into infinity.
#
# 51
# 00:01:38,644 --> 00:01:41,520
# Jade:
# Those memories cannot be deleted as
#
# 52
# 00:01:41,520 --> 00:01:42,668
# Jade:
# of right now.
#
# 53
# 00:01:42,668 --> 00:01:43,720
# Jade:
# So
#
# 54
# 00:01:43,720 --> 00:01:45,892
# Jade:
# Ezreal has a virus and
#
# 55
# 00:01:45,892 --> 00:01:48,320
# Jade:
# we have to run antivirus software at
#
# 56
# 00:01:48,320 --> 00:01:48,860
# Jade:
# some point.
#
# 57
# 00:01:48,860 --> 00:01:52,472
# IlMa:
# Ezreal is just that really old computer that like, you know, every few months,
#
# 58
# 00:01:53,076 --> 00:01:54,096
# Jade:
# Oh no.
#
# 59
# 00:01:54,096 --> 00:01:58,092
# IlMa:
# there is there's something going on in the software that you're just like, yeah,
#
# 60
# 00:01:58,092 --> 00:02:02,344
# IlMa:
# we're gonna have to do something about this. We're gonna have to clear some things. I don't know how this happened.
#
# 61
# 00:02:02,344 --> 00:02:03,876
# IlMa:
# How did you delete
#
# 62
# 00:02:03,876 --> 00:02:04,928
# IlMa:
# Windows?
#
# 63
# 00:02:04,928 --> 00:02:06,204
# Crux:
# Ready to the omnisiah?
#
# 64
# 00:02:06,204 --> 00:02:09,528
# CS12:
# That's a good, that's a good line. I love it.
#
# 65
# 00:02:09,528 --> 00:02:10,228
# Jade:
# Yeah.
#
# 66
# 00:02:10,768 --> 00:02:12,364
# Jade:
# learned
#
# 67
# 00:02:12,364 --> 00:02:13,064
# Jade:
# that
#
# 68
# 00:02:13,064 --> 00:02:16,100
# Jade:
# let's see Yart is the new
#
# 69
# 00:02:16,100 --> 00:02:17,536
# Jade:
# supreme commander
#
# 70
# 00:02:17,536 --> 00:02:18,332
# Jade:
# and
#
# 71
# 00:02:18,332 --> 00:02:19,928
# Jade:
# like this is the gift wrap
#
# 72
# 00:02:19,928 --> 00:02:21,556
# Jade:
# for
#
# 73
# 00:02:21,556 --> 00:02:22,800
# Jade:
# Matt Matt I believe
#
# 74
# 00:02:22,800 --> 00:02:23,980
# Jade:
# and
#
# 75
# 00:02:23,980 --> 00:02:26,344
# Jade:
# we've got some of people we're trying to hope
#
# 76
# 00:02:26,344 --> 00:02:27,364
# Jade:
# they
#
# 77
# 00:02:27,364 --> 00:02:28,320
# Jade:
# be free again
#
# 78
# 00:02:28,320 --> 00:02:29,820
# Jade:
# by being able to go
#
# 79
# 00:02:29,820 --> 00:02:30,968
# Jade:
# out of the bathroom
#
# 80
# 00:02:30,968 --> 00:02:31,924
# Jade:
# and yeah
#
# 81
# 00:02:31,924 --> 00:02:32,848
# IlMa:
# But if they go, fuck
#
# 82
# 00:02:32,848 --> 00:02:34,316
# IlMa:
# ton of psychic damage.
#
# 83
# 00:02:34,316 --> 00:02:36,808
# Jade:
# it's like it damage we gotta do something about
#
# 84
# 00:02:36,808 --> 00:02:38,532
# Jade:
# all that psychic damage you got
#
# 85
# 00:02:38,532 --> 00:02:41,024
# Crux:
# What do you mean by psychic damage there, Sam?
#
# 86
# 00:02:41,024 --> 00:02:47,356
# IlMa:
# I believe that was the term you said, like if they were to leave,
#
# 87
# 00:02:47,356 --> 00:02:48,472
# IlMa:
# they would just take a- I
#
# 88
# 00:02:48,472 --> 00:02:56,564
# IlMa:
# don't know if you used the word fuck, but a lot of psychic damage. It wouldn't be that they age rapidly, it's just that their brain would probably explode. I
#
# 89
# 00:02:56,564 --> 00:03:01,776
# CS12:
# Yeah, their brain would unmake, I think that's what Josh said too, specifically, a fuckton of psychic damage.
#
# 90
# 00:03:01,776 --> 00:03:02,188
# Crux:
# Yeah.
#
# 91
# 00:03:02,952 --> 00:03:05,604
# IlMa:
# know psychic damage was used in the phrase.
#
# 92
# 00:03:05,604 --> 00:03:07,296
# IlMa:
# I did listen to the recording, so I'm
#
# 93
# 00:03:07,296 --> 00:03:10,396
# IlMa:
# fairly confident. I'm like my usual kinda confident.
#
# 94
# 00:03:10,396 --> 00:03:13,080
# CS12:
# Yes. Yeah.
#
# 95
# 00:03:13,080 --> 00:03:14,132
# IlMa:
# Yes.
#
# 96
# 00:03:14,132 --> 00:03:14,960
# CS12:
# The way they could hanky.
#
# 97
# 00:03:14,960 --> 00:03:18,700
# IlMa:
# But we got problems to ponder.
#
# 98
# 00:03:18,700 --> 00:03:20,520
# IlMa:
# to see, but
#
# 99
# 00:03:20,520 --> 00:03:21,956
# IlMa:
# we had a beautiful scene
#
# 100
# 00:03:21,956 --> 00:03:23,648
# IlMa:
# of Zynyrith and her children,
#
# 101
# 00:03:23,648 --> 00:03:24,508
# IlMa:
# seeing them
#
# 102
# 00:03:24,508 --> 00:03:25,624
# IlMa:
# far more grown
#
# 103
# 00:03:25,624 --> 00:03:26,292
# IlMa:
# up.
#
# 104
# 00:03:26,292 --> 00:03:29,616
# IlMa:
# I mean, in the last 14 months they've really started hitting puberty hard.
#
# 105
# 00:03:29,616 --> 00:03:31,276
# CS12:
# Well, and
#
# 106
# 00:03:31,276 --> 00:03:32,552
# IlMa:
# The way of the Githyanki.
#
# 107
# 00:03:32,552 --> 00:03:35,844
# CS12:
# they could survive, but more so they could hank you. It
#
# 108
# 00:03:35,844 --> 00:03:37,280
# Crux:
# And also, that's a rye.
#
# 109
# 00:03:37,280 --> 00:03:40,540
# CS12:
# was less so, compared to the githyanki.
#
# 110
# 00:03:40,540 --> 00:03:50,424
# IlMa:
# And superseding all of that stuff that we are concerned about, all of the political intrigue, all of the charming and heartwarming reunions.
#
# 111
# 00:03:50,424 --> 00:03:52,916
# IlMa:
# We got to meet Miley's husband
#
# 112
# 00:03:52,916 --> 00:03:54,096
# IlMa:
# and we all went, whoa,
#
# 113
# 00:03:54,096 --> 00:03:54,828
# IlMa:
# damn.
#
# 114
# 00:03:54,828 --> 00:03:56,360
# IlMa:
# Recorded live,
#
# 115
# 00:03:56,360 --> 00:03:56,932
# Jade:
# what
#
# 116
# 00:03:56,932 --> 00:03:58,528
# IlMa:
# forever to be known.
#
# 117
# 00:03:58,528 --> 00:04:01,212
# IlMa:
# I just want to bring attention to that, you know?
#
# 118
# 00:04:01,212 --> 00:04:01,752
# IlMa:
# Thank you.
#
# 119
# 00:04:01,752 --> 00:04:03,604
# Crux:
# These recordings aren't live, by the way.
#
# 120
# 00:04:03,604 --> 00:04:06,480
# CS12:
# It was recorded live, though.
#
# 121
# 00:04:06,480 --> 00:04:07,596
# Jade:
# What does that mean?
#
# 122
# 00:04:07,596 --> 00:04:08,200
# Jade:
# Oh, right.
#
# 123
# 00:04:08,516 --> 00:04:09,760
# Crux:
# It's true. We're not scripted.
#
# 124
# 00:04:10,588 --> 00:04:11,896
# IlMa:
# We're free spirits!
#
# 125
# 00:04:11,896 --> 00:04:13,972
# IlMa:
# Everything that happens is spontaneous,
#
# 126
# 00:04:13,972 --> 00:04:14,512
# IlMa:
# uh,
#
# 127
# 00:04:14,512 --> 00:04:15,308
# IlMa:
# future viewers.
#
# 128
# 00:04:15,308 --> 00:04:16,072
# IlMa:
# Probably me.
#
# 129
# 00:04:16,072 --> 00:04:21,124
# CS12:
# Until we start editing these things. In which case, not live!
#
# 130
# 00:04:21,124 --> 00:04:21,632
# Crux:
# Anyway.
#
# 131
# 00:04:21,632 --> 00:04:31,100
# CS12:
# Alright. Well, hello everybody! Welcome back! Last we left off, there were some Smeeple learning
#
# 132
# 00:04:31,100 --> 00:04:35,480
# CS12:
# the masculine one was holding a bag full of dead snake.
#
# 133
# 00:04:35,480 --> 00:04:37,492
# CS12:
# We met Ailiyelidusti
#
# 134
# 00:04:37,492 --> 00:04:41,200
# CS12:
# and found out that Maile is Maile-yelidusti.
#
# 135
# 00:04:41,964 --> 00:04:48,328
# CS12:
# We saw Ymir in a classroom sitting with a bunch of other kids, including Yankee,
#
# 136
# 00:04:48,328 --> 00:04:49,444
# CS12:
# who has a
#
# 137
# 00:04:49,444 --> 00:04:50,592
# CS12:
# beard-ish,
#
# 138
# 00:04:50,592 --> 00:04:52,636
# CS12:
# and his horns are too big for him.
#
# 139
# 00:04:52,636 --> 00:04:55,896
# CS12:
# And Chaya was doing flight training
#
# 140
# 00:04:55,896 --> 00:04:57,012
# CS12:
# on a giant eagle.
#
# 141
# 00:04:57,012 --> 00:04:58,768
# CS12:
# As we left off,
#
# 142
# 00:04:58,768 --> 00:05:07,340
# CS12:
# we're just about to meet up, but I'm not sure if we're actually gonna go into conversation that is totally up to you guys.
#
# 143
# 00:05:07,340 --> 00:05:10,568
# IlMa:
# I do think that is a, uh, Xun'rith call there.
#
# 144
# 00:05:10,568 --> 00:05:11,236
# Jade:
# Hmm.
#
# 145
# 00:05:11,236 --> 00:05:12,000
# Jade:
# Uhh,
#
# 146
# 00:05:12,000 --> 00:05:13,308
# Jade:
# you know, I guess not.
#
# 147
# 00:05:14,552 --> 00:05:17,268
# Jade:
# I mean, I don't really have anything,
#
# 148
# 00:05:17,268 --> 00:05:18,192
# Jade:
# personally.
#
# 149
# 00:05:18,956 --> 00:05:32,968
# CS12:
# Here, let me give you a little bit of a rundown of what's happening with Chaya. Chaya is taking more to the practical activities and the mental activities. He introduces you to his great eagle
#
# 150
# 00:05:32,968 --> 00:05:36,228
# CS12:
# friend who he rides around on and
#
# 151
# 00:05:37,120 --> 00:05:45,724
# CS12:
# you can honestly tell Vakumi that he is thinking about saying friend and then to you decides to say this is my,
#
# 152
# 00:05:45,724 --> 00:05:46,648
# CS12:
# uh,
#
# 153
# 00:05:46,648 --> 00:05:46,996
# CS12:
# this is,
#
# 154
# 00:05:46,996 --> 00:05:48,848
# CS12:
# this is my, my mount.
#
# 155
# 00:05:49,324 --> 00:05:52,168
# CS12:
# We fly together. It's really cool.
#
# 156
# 00:05:52,168 --> 00:05:53,252
# CS12:
# Um,
#
# 157
# 00:05:53,252 --> 00:05:56,608
# CS12:
# their name is Tom Sky-Sainu.
#
# 158
# 00:05:56,608 --> 00:05:57,468
# CS12:
# Um,
#
# 159
# 00:05:57,468 --> 00:05:58,360
# CS12:
# she can't,
#
# 160
# 00:05:58,360 --> 00:05:59,124
# CS12:
# she,
#
# 161
# 00:05:59,124 --> 00:06:00,240
# CS12:
# he's trying to,
#
# 162
# 00:06:01,832 --> 00:06:06,596
# CS12:
# if you want, if you want to talk to him, you can talk to him. He's a very smart bird
#
# 163
# 00:06:06,596 --> 00:06:07,104
# Jade:
# Um,
#
# 164
# 00:06:07,104 --> 00:06:09,660
# Jade:
# yeah, I'll try to telepathically
#
# 165
# 00:06:09,660 --> 00:06:11,000
# Jade:
# say something to
#
# 166
# 00:06:11,000 --> 00:06:11,636
# Jade:
# Tom.
#
# 167
# 00:06:11,636 --> 00:06:14,896
# CS12:
# as an intelligence of like 12. So yeah, for sure.
#
# 168
# 00:06:14,896 --> 00:06:15,820
# Jade:
# Holy shit,
#
# 169
# 00:06:15,820 --> 00:06:17,736
# Jade:
# that's the smartest bird in
#
# 170
# 00:06:17,736 --> 00:06:19,204
# Jade:
# existence.
#
# 171
# 00:06:19,204 --> 00:06:20,864
# CS12:
# Really not.
#
# 172
# 00:06:21,308 --> 00:06:23,128
# Jade:
# That's the smartest bird.
#
# 173
# 00:06:23,128 --> 00:06:26,260
# CS12:
# It is the smartest bird, but giant eagles are damn smart.
#
# 174
# 00:06:26,260 --> 00:06:28,784
# Jade:
# Uh, I'll stay to it.
#
# 175
# 00:06:30,792 --> 00:06:32,452
# Jade:
# Are you getting along with my son?
#
# 176
# 00:06:32,452 --> 00:06:33,120
# Jade:
# Hey,
#
# 177
# 00:06:33,120 --> 00:06:40,476
# CS12:
# Are you this wonderful, wonderful boy's mother?
#
# 178
# 00:06:40,476 --> 00:06:42,328
# CS12:
# You should feel great
#
# 179
# 00:06:42,328 --> 00:06:48,788
# CS12:
# pride in how he is, as little of it as you had to do with how he turned out. You
#
# 180
# 00:06:49,900 --> 00:06:51,688
# Crux:
# Oh, this bird's throwing shade.
#
# 181
# 00:06:52,132 --> 00:06:55,616
# Jade:
# what is that supposed to mean? I'm gone for a year
#
# 182
# 00:06:55,616 --> 00:06:56,220
# Jade:
# and I-
#
# 183
# 00:06:56,220 --> 00:06:57,912
# CS12:
# were not only gone for a year.
#
# 184
# 00:06:57,912 --> 00:06:58,804
# CS12:
# Do not lie to me.
#
# 185
# 00:06:58,804 --> 00:07:00,848
# Jade:
# Then how long has it been?
#
# 186
# 00:07:00,848 --> 00:07:02,060
# CS12:
# I don't know.
#
# 187
# 00:07:02,060 --> 00:07:03,912
# CS12:
# I do not interrogate your
#
# 188
# 00:07:03,912 --> 00:07:04,964
# CS12:
# spawn
#
# 189
# 00:07:04,964 --> 00:07:05,664
# CS12:
# because he
#
# 190
# 00:07:05,664 --> 00:07:06,908
# CS12:
# is my friend.
#
# 191
# 00:07:06,908 --> 00:07:09,176
# Jade:
# Yeah, it has a name, do you know it?
#
# 192
# 00:07:09,176 --> 00:07:09,556
# CS12:
# Hiya.
#
# 193
# 00:07:09,936 --> 00:07:10,540
# Jade:
# Good.
#
# 194
# 00:07:10,856 --> 00:07:13,284
# Jade:
# Taya is more fitting
#
# 195
# 00:07:13,284 --> 00:07:14,400
# Jade:
# than spawn.
#
# 196
# 00:07:15,580 --> 00:07:16,248
# CS12:
# Yes,
#
# 197
# 00:07:16,724 --> 00:07:17,904
# CS12:
# of course.
#
# 198
# 00:07:18,540 --> 00:07:20,424
# CS12:
# His mother.
#
# 199
# 00:07:20,424 --> 00:07:21,188
# Jade:
# I just
#
# 200
# 00:07:21,188 --> 00:07:23,968
# Jade:
# glare at this giant eagle
#
# 201
# 00:07:23,968 --> 00:07:26,684
# Jade:
# that I'm having a silent conversation with.
#
# 202
# 00:07:26,684 --> 00:07:33,304
# CS12:
# You hear Chaya say like things in secret because of your advanced telepathy,
#
# 203
# 00:07:33,304 --> 00:07:35,924
# CS12:
# where it says, uh, like, yeah,
#
# 204
# 00:07:35,924 --> 00:07:43,696
# CS12:
# be nice, be nice. She's really, she will, she will probably cut you in half if you say something mean, so be really nice.
#
# 205
# 00:07:44,652 --> 00:07:46,376
# CS12:
# She's very angry, but
#
# 206
# 00:07:46,376 --> 00:07:50,148
# CS12:
# she can be really nice if she's not angry.
#
# 207
# 00:07:50,148 --> 00:07:51,360
# IlMa:
# Oof.
#
# 208
# 00:07:51,360 --> 00:07:53,308
# Jade:
# It's good to see the two of you
#
# 209
# 00:07:53,308 --> 00:07:54,552
# Jade:
# have formed a bond.
#
# 210
# 00:07:55,536 --> 00:07:57,772
# CS12:
# Yes, he's the most magnificent pupil.
#
# 211
# 00:07:57,772 --> 00:07:58,568
# CS12:
# I'm excited
#
# 212
# 00:07:58,568 --> 00:07:58,916
# CS12:
# and
#
# 213
# 00:07:58,916 --> 00:08:01,536
# CS12:
# at the same time loathe to graduate him. Takes
#
# 214
# 00:08:01,536 --> 00:08:04,188
# CS12:
# this guy as if they were his own.
#
# 215
# 00:08:04,188 --> 00:08:05,848
# CS12:
# Shall we return?
#
# 216
# 00:08:05,848 --> 00:08:08,212
# CS12:
# He starts like walking away and Chaya says,
#
# 217
# 00:08:08,212 --> 00:08:13,040
# CS12:
# No, no, no, no, no, no, no, no. And then conversation continues. You catch up a little.
#
# 218
# 00:08:13,040 --> 00:08:14,156
# Jade:
# Yeah, she
#
# 219
# 00:08:14,156 --> 00:08:17,000
# Jade:
# is basically asking Chaya to tell her
#
# 220
# 00:08:17,000 --> 00:08:18,340
# Jade:
# stories of how
#
# 221
# 00:08:18,340 --> 00:08:19,264
# Jade:
# being gay
#
# 222
# 00:08:19,264 --> 00:08:21,372
# Jade:
# in the INU country's been like,
#
# 223
# 00:08:21,372 --> 00:08:27,032
# CS12:
# Being in the Ignihotri has been really great. There's so much room to fly here.
#
# 224
# 00:08:27,764 --> 00:08:40,848
# CS12:
# He gets a little nervousness on himself. As you can see, he's remembering a memory that he doesn't like. And you can get a sense that a sense of vertigo falls over him. He says, Well yeah, um, and,
#
# 225
# 00:08:40,848 --> 00:08:43,948
# Jade:
# I'll press him on it, I'll ask him like, what's wrong?
#
# 226
# 00:08:43,948 --> 00:08:48,872
# CS12:
# Well you don't even need to worry about flying, falling, because if you fall, there's not like a ground to hit.
#
# 227
# 00:08:48,872 --> 00:08:49,636
# CS12:
# Your
#
# 228
# 00:08:49,636 --> 00:08:51,296
# CS12:
# palm will just catch you.
#
# 229
# 00:08:51,296 --> 00:08:51,868
# CS12:
# Because he's
#
# 230
# 00:08:51,868 --> 00:08:52,824
# CS12:
# very good
#
# 231
# 00:08:52,824 --> 00:08:53,300
# CS12:
# at that.
#
# 232
# 00:08:53,300 --> 00:08:55,536
# CS12:
# Well you also have harnesses.
#
# 233
# 00:08:56,012 --> 00:08:59,272
# Jade:
# She was worried for a moment that he was like,
#
# 234
# 00:08:59,272 --> 00:09:04,036
# Jade:
# having this bad trauma memory from a long time ago, but
#
# 235
# 00:09:04,036 --> 00:09:05,920
# Jade:
# it was mostly related to his
#
# 236
# 00:09:05,920 --> 00:09:06,652
# Jade:
# like,
#
# 237
# 00:09:06,652 --> 00:09:09,624
# Jade:
# schooling here, so she's just worried about that. about that
#
# 238
# 00:09:09,624 --> 00:09:11,092
# Jade:
# and she's more relieved.
#
# 239
# 00:09:12,464 --> 00:09:13,772
# CS12:
# Chaya
#
# 240
# 00:09:13,772 --> 00:09:14,856
# CS12:
# has,
#
# 241
# 00:09:14,856 --> 00:09:19,524
# CS12:
# I may remind you, feathers of many colors,
#
# 242
# 00:09:19,524 --> 00:09:23,200
# CS12:
# white stems bound into little brass,
#
# 243
# 00:09:23,200 --> 00:09:27,804
# CS12:
# little hair clips that bind into the
#
# 244
# 00:09:28,344 --> 00:09:30,132
# CS12:
# braids of his thin hair
#
# 245
# 00:09:30,132 --> 00:09:33,936
# CS12:
# with many colors of feathers there.
#
# 246
# 00:09:33,936 --> 00:09:45,484
# CS12:
# He'll talk to you about where these feathers are from, how they're from, And then he names off some names that you don't know. And he says they are the,
#
# 247
# 00:09:45,484 --> 00:09:49,576
# CS12:
# they are the, uh, the, the, the, the bird kids. Um,
#
# 248
# 00:09:49,576 --> 00:09:51,652
# CS12:
# they're like really important. Apparently
#
# 249
# 00:09:51,652 --> 00:09:54,560
# Jade:
# I'll try to get Chaya to tell me all I know about
#
# 250
# 00:09:54,560 --> 00:09:55,420
# CS12:
# they're so
#
# 251
# 00:09:55,420 --> 00:09:57,784
# Jade:
# them because I don't know anything about them.
#
# 252
# 00:09:57,784 --> 00:09:59,060
# CS12:
# gosh.
#
# 253
# 00:09:59,060 --> 00:10:00,464
# Crux:
# We're talking about the
#
# 254
# 00:10:00,464 --> 00:10:01,612
# Jade:
# Perkins.
#
# 255
# 00:10:01,612 --> 00:10:04,040
# Crux:
# Teenage Mutant Ninja Bird Boys.
#
# 256
# 00:10:04,832 --> 00:10:06,268
# Jade:
# Oh my god. What?
#
# 257
# 00:10:06,268 --> 00:10:07,800
# IlMa:
# It's actually happening.
#
# 258
# 00:10:07,800 --> 00:10:08,564
# Crux:
# Oh.
#
# 259
# 00:10:09,296 --> 00:10:09,772
# Crux:
# So
#
# 260
# 00:10:09,772 --> 00:10:11,656
# Crux:
# these are the people
#
# 261
# 00:10:11,656 --> 00:10:13,252
# Crux:
# that were killed by Yarolai.
#
# 262
# 00:10:15,224 --> 00:10:15,604
# Crux:
# They,
#
# 263
# 00:10:15,604 --> 00:10:18,768
# Crux:
# they, uh, in their funeral pyre,
#
# 264
# 00:10:19,116 --> 00:10:20,904
# Crux:
# left behind Phoenix eggs.
#
# 265
# 00:10:20,904 --> 00:10:21,284
# Crux:
# Um,
#
# 266
# 00:10:21,284 --> 00:10:23,488
# Crux:
# and so now they're like Phoenix, Aracocra.
#
# 267
# 00:10:23,488 --> 00:10:24,156
# Crux:
# Um,
#
# 268
# 00:10:24,156 --> 00:10:25,784
# Crux:
# they are
#
# 269
# 00:10:25,784 --> 00:10:28,436
# Crux:
# coming up on like two years old. So they're teenagers.
#
# 270
# 00:10:28,752 --> 00:10:31,148
# Jade:
# Phoenix, Eric, Ocra. Do they just like
#
# 271
# 00:10:31,148 --> 00:10:32,968
# Jade:
# age really fast and then
#
# 272
# 00:10:32,968 --> 00:10:34,660
# Jade:
# reincarnate or something? Oh,
#
# 273
# 00:10:34,660 --> 00:10:35,712
# Crux:
# Aracocra
#
# 274
# 00:10:35,712 --> 00:10:37,500
# Crux:
# reached maturity by the age of three.
#
# 275
# 00:10:37,500 --> 00:10:39,128
# Jade:
# I didn't know that.
#
# 276
# 00:10:39,128 --> 00:10:39,476
# Crux:
# Yup.
#
# 277
# 00:10:39,476 --> 00:10:41,680
# Crux:
# So they're about a year away from maturity.
#
# 278
# 00:10:41,680 --> 00:10:42,220
# Crux:
# Um,
#
# 279
# 00:10:42,220 --> 00:10:44,904
# Crux:
# I'm guessing that this is like the youth flight training camp.
#
# 280
# 00:10:45,860 --> 00:10:48,992
# CS12:
# Yeah. And they definitely fly as well.
#
# 281
# 00:10:48,992 --> 00:10:49,340
# Crux:
# Yeah.
#
# 282
# 00:10:49,340 --> 00:10:50,296
# Crux:
# Oh,
#
# 283
# 00:10:50,296 --> 00:10:52,372
# Crux:
# I don't really have much more to say about them.
#
# 284
# 00:10:52,372 --> 00:10:53,360
# Crux:
# Perhaps I should
#
# 285
# 00:10:53,772 --> 00:10:54,952
# Crux:
# build a roster and
#
# 286
# 00:10:54,952 --> 00:10:56,356
# Crux:
# get art for them or something.
#
# 287
# 00:10:56,356 --> 00:10:59,904
# Jade:
# No, that's, I mean, whichever, whatever you
#
# 288
# 00:10:59,904 --> 00:11:01,468
# Jade:
# are feeling inspired to do.
#
# 289
# 00:11:01,468 --> 00:11:04,248
# CS12:
# The only other thing I would say is notable,
#
# 290
# 00:11:04,248 --> 00:11:07,476
# CS12:
# uh, that I feel like you could have brought up is they're colorful.
#
# 291
# 00:11:07,476 --> 00:11:09,776
# Crux:
# Oh, I thought that would be inside of the Phoenix,
#
# 292
# 00:11:09,776 --> 00:11:11,564
# Crux:
# uh, Arachocra thing, but yeah.
#
# 293
# 00:11:11,564 --> 00:11:12,168
# Crux:
# Very...
#
# 294
# 00:11:12,168 --> 00:11:13,092
# CS12:
# Why?
#
# 295
# 00:11:13,092 --> 00:11:13,760
# Crux:
# because, you
#
# 296
# 00:11:13,760 --> 00:11:16,060
# Crux:
# know, they're phoenixes. Phoenixes are colorful.
#
# 297
# 00:11:16,060 --> 00:11:18,584
# CS12:
# They are. I didn't mean to interrupt you.
#
# 298
# 00:11:18,584 --> 00:11:19,892
# Crux:
# That was the end of my thought.
#
# 299
# 00:11:19,892 --> 00:11:23,984
# CS12:
# No it wasn't, you were talking and then I interrupted you about how they were colorful.
#
# 300
# 00:11:23,984 --> 00:11:24,332
# Crux:
# Oh,
#
# 301
# 00:11:24,332 --> 00:11:25,352
# Crux:
# well that thought is gone.
#
# 302
# 00:11:25,352 --> 00:11:26,244
# CS12:
# Okay.
#
# 303
# 00:11:26,244 --> 00:11:27,040
# Crux:
# Begone thought.
#
# 304
# 00:11:27,804 --> 00:11:29,496
# IlMa:
# Don't spite them.
#
# 305
# 00:11:29,496 --> 00:11:31,476
# CS12:
# No more thinking. Yeah,
#
# 306
# 00:11:31,476 --> 00:11:33,456
# IlMa:
# It's too cruel punishment.
#
# 307
# 00:11:33,456 --> 00:11:34,348
# Jade:
# Yeah,
#
# 308
# 00:11:34,856 --> 00:11:36,740
# Jade:
# she comments, um,
#
# 309
# 00:11:36,740 --> 00:11:37,280
# Jade:
# I
#
# 310
# 00:11:37,280 --> 00:11:38,364
# Jade:
# doubt that they're
#
# 311
# 00:11:38,364 --> 00:11:40,024
# Jade:
# actually same person
#
# 312
# 00:11:40,024 --> 00:11:40,404
# Jade:
# but
#
# 313
# 00:11:40,404 --> 00:11:41,296
# Jade:
# it
#
# 314
# 00:11:42,028 --> 00:11:44,168
# Jade:
# does have a more meaningful end
#
# 315
# 00:11:44,168 --> 00:11:46,564
# Jade:
# to see that there was some good that
#
# 316
# 00:11:46,564 --> 00:11:47,936
# Jade:
# came out of their
#
# 317
# 00:11:47,936 --> 00:11:49,244
# Jade:
# lives that were cut short.
#
# 318
# 00:11:49,244 --> 00:11:54,328
# CS12:
# apparently they're like, gonna be really important because they're like,
#
# 319
# 00:11:54,328 --> 00:11:55,540
# CS12:
# gonna live forever,
#
# 320
# 00:11:55,540 --> 00:11:57,040
# CS12:
# so that's cool.
#
# 321
# 00:11:57,040 --> 00:11:59,244
# Jade:
# Living Forever also has a
#
# 322
# 00:11:59,244 --> 00:12:01,640
# Jade:
# burden attached to it.
#
# 323
# 00:12:01,640 --> 00:12:02,820
# CS12:
# While
#
# 324
# 00:12:02,820 --> 00:12:04,992
# CS12:
# I don't want people to die, that's
#
# 325
# 00:12:04,992 --> 00:12:09,308
# CS12:
# the final punctuation that I'm gonna put on that scene. If
#
# 326
# 00:12:09,308 --> 00:12:11,032
# Jade:
# Yeah, me too.
#
# 327
# 00:12:11,032 --> 00:12:14,964
# Jade:
# What about Yoneir? How is she doing?
#
# 328
# 00:12:14,964 --> 00:12:19,792
# CS12:
# you go back to check on Ymir, she is shy, a
#
# 329
# 00:12:20,172 --> 00:12:21,320
# CS12:
# little
#
# 330
# 00:12:21,320 --> 00:12:24,004
# CS12:
# cowering in her self-quality because
#
# 331
# 00:12:24,004 --> 00:12:29,248
# CS12:
# her own self-consciousness about her appearance due to the time that she spent
#
# 332
# 00:12:29,724 --> 00:12:32,568
# CS12:
# with Deck, with you, with everybody.
#
# 333
# 00:12:33,460 --> 00:12:35,632
# CS12:
# Her dad,
#
# 334
# 00:12:35,632 --> 00:12:36,012
# CS12:
# for sure,
#
# 335
# 00:12:36,012 --> 00:12:40,392
# CS12:
# has led her to believe and look for people
#
# 336
# 00:12:41,344 --> 00:12:42,972
# CS12:
# caring about her appearance.
#
# 337
# 00:12:44,404 --> 00:12:56,560
# CS12:
# And even though she looks like much better, that's somehow made the issue worse because she doesn't look normal. She just looks closer to it. So now she's looking for more subtle things, which means that she's also kind of making things up.
#
# 338
# 00:12:57,292 --> 00:12:59,272
# CS12:
# She's doing well.
#
# 339
# 00:12:59,272 --> 00:13:02,052
# CS12:
# She is kind of shunning her talent
#
# 340
# 00:13:02,052 --> 00:13:03,104
# CS12:
# with psychic
#
# 341
# 00:13:03,104 --> 00:13:04,796
# CS12:
# powers because of her own
#
# 342
# 00:13:04,796 --> 00:13:07,960
# CS12:
# self-worth issues.
#
# 343
# 00:13:07,960 --> 00:13:10,900
# CS12:
# Or self-acceptance issues. That's better.
#
# 344
# 00:13:11,664 --> 00:13:13,292
# CS12:
# She is
#
# 345
# 00:13:13,292 --> 00:13:15,624
# CS12:
# not being bullied, but
#
# 346
# 00:13:15,624 --> 00:13:18,532
# CS12:
# kind of feels like she's being bullied.
#
# 347
# 00:13:18,532 --> 00:13:27,104
# CS12:
# Um, because people aren't as accepting to her in order to let her know that she actually, they actually do like her. Like she's being socially, she's
#
# 348
# 00:13:27,104 --> 00:13:29,276
# Jade:
# Oh. Oh.
#
# 349
# 00:13:29,276 --> 00:13:30,904
# CS12:
# socially self isolating.
#
# 350
# 00:13:31,892 --> 00:13:34,640
# CS12:
# Um, and the only person that is not
#
# 351
# 00:13:34,640 --> 00:13:35,276
# CS12:
# in
#
# 352
# 00:13:35,276 --> 00:13:38,792
# CS12:
# that kind of camp is Chaya and Yankee.
#
# 353
# 00:13:38,792 --> 00:13:41,348
# CS12:
# And Chaya is a cool enough kid
#
# 354
# 00:13:41,348 --> 00:13:42,272
# CS12:
# where like he's
#
# 355
# 00:13:42,272 --> 00:13:45,788
# CS12:
# basically forming up to be be part of JV,
#
# 356
# 00:13:46,456 --> 00:13:48,980
# CS12:
# that Ymir is now feeling distant from Chaya,
#
# 357
# 00:13:48,980 --> 00:13:55,952
# CS12:
# and so she's becoming really good friends with Yankee, and she really likes spending time with Yankee.
#
# 358
# 00:13:56,492 --> 00:13:58,088
# Jade:
# I try to
#
# 359
# 00:13:58,088 --> 00:13:58,500
# Jade:
# get
#
# 360
# 00:13:58,500 --> 00:13:59,552
# Jade:
# Yoneir to open up
#
# 361
# 00:13:59,552 --> 00:14:05,020
# Jade:
# around me and I'll say, hey, it's me, your mom,
#
# 362
# 00:14:05,020 --> 00:14:05,848
# Jade:
# you can
#
# 363
# 00:14:06,580 --> 00:14:08,144
# Jade:
# talk to me about stuff
#
# 364
# 00:14:08,144 --> 00:14:10,316
# CS12:
# Yeah, you wanna make a parenting check here?
#
# 365
# 00:14:10,316 --> 00:14:10,952
# Jade:
# and have a
#
# 366
# 00:14:10,952 --> 00:14:11,748
# Jade:
# conversation.
#
# 367
# 00:14:11,748 --> 00:14:12,320
# Jade:
# Yeah,
#
# 368
# 00:14:12,320 --> 00:14:13,020
# CS12:
# Hmm,
#
# 369
# 00:14:13,020 --> 00:14:13,592
# Jade:
# sure.
#
# 370
# 00:14:13,592 --> 00:14:14,388
# CS12:
# exciting.
#
# 371
# 00:14:14,388 --> 00:14:18,896
# CS12:
# Well, your extended absence gives you disadvantage on this, sorry.
#
# 372
# 00:14:19,724 --> 00:14:23,592
# CS12:
# Well, it didn't make it any worse, but it didn't make it any better.
#
# 373
# 00:14:23,592 --> 00:14:29,348
# CS12:
# She is resistant to opening up, even to you,
#
# 374
# 00:14:30,400 --> 00:14:36,316
# CS12:
# which is not something that you expected. Your flaw, your fatal flaw going into this was
#
# 375
# 00:14:36,316 --> 00:14:37,432
# CS12:
# imagining
#
# 376
# 00:14:37,432 --> 00:14:39,380
# CS12:
# that this experience would be different for you,
#
# 377
# 00:14:39,380 --> 00:14:40,624
# CS12:
# that she wouldn't feel
#
# 378
# 00:14:40,624 --> 00:14:41,708
# CS12:
# self-conscious
#
# 379
# 00:14:41,708 --> 00:14:42,504
# CS12:
# with you,
#
# 380
# 00:14:42,504 --> 00:14:44,772
# CS12:
# that you would be able to talk to her.
#
# 381
# 00:14:44,772 --> 00:14:45,600
# CS12:
# That's not the case.
#
# 382
# 00:14:46,460 --> 00:14:47,384
# CS12:
# So
#
# 383
# 00:14:47,384 --> 00:14:52,884
# CS12:
# she kind of, you make your daughter cry. in a very rough spot emotionally,
#
# 384
# 00:14:52,884 --> 00:14:54,864
# CS12:
# um, hormonally,
#
# 385
# 00:14:54,864 --> 00:14:55,948
# CS12:
# tire thing.
#
# 386
# 00:14:55,948 --> 00:14:57,032
# CS12:
# Um,
#
# 387
# 00:14:57,032 --> 00:14:58,820
# CS12:
# and she just kinda
#
# 388
# 00:14:58,820 --> 00:15:01,824
# CS12:
# diffuses that entire scene by just like
#
# 389
# 00:15:01,824 --> 00:15:02,908
# CS12:
# existing
#
# 390
# 00:15:02,908 --> 00:15:05,272
# CS12:
# and refusing to communicate further.
#
# 391
# 00:15:05,272 --> 00:15:06,292
# Jade:
# Yeah,
#
# 392
# 00:15:06,768 --> 00:15:07,852
# Jade:
# that
#
# 393
# 00:15:07,852 --> 00:15:10,280
# Jade:
# is painful to
#
# 394
# 00:15:10,280 --> 00:15:11,428
# Jade:
# Zynith,
#
# 395
# 00:15:11,428 --> 00:15:12,736
# Jade:
# I think she's willing to
#
# 396
# 00:15:12,736 --> 00:15:13,276
# Jade:
# show that
#
# 397
# 00:15:13,276 --> 00:15:14,360
# Jade:
# vulnerability
#
# 398
# 00:15:14,360 --> 00:15:15,604
# Jade:
# with her daughter, but
#
# 399
# 00:15:15,604 --> 00:15:17,680
# Jade:
# she also at the same time
#
# 400
# 00:15:17,680 --> 00:15:19,756
# Jade:
# gives Yodhi some space.
#
# 401
# 00:15:19,756 --> 00:15:20,648
# CS12:
# Yeah.
#
# 402
# 00:15:20,648 --> 00:15:28,964
# CS12:
# You reckon that she'd be having a really rough time, well, without Yankee, but she's also like latching onto Yankee cause he's also different.
#
# 403
# 00:15:29,824 --> 00:15:31,388
# Jade:
# Also try
#
# 404
# 00:15:31,388 --> 00:15:32,056
# Jade:
# talking up
#
# 405
# 00:15:32,056 --> 00:15:38,132
# Jade:
# with Yankie more, being stuff like, hey, you don't remember me probably, but
#
# 406
# 00:15:38,132 --> 00:15:40,912
# CS12:
# No, he absolutely does not.
#
# 407
# 00:15:40,912 --> 00:15:41,676
# Jade:
# I'm
#
# 408
# 00:15:41,676 --> 00:15:45,800
# Jade:
# your new Aunt Chaya's mom and stuff like that.
#
# 409
# 00:15:45,800 --> 00:15:47,076
# CS12:
# Oh
#
# 410
# 00:15:47,076 --> 00:15:50,016
# CS12:
# means something to him.
#
# 411
# 00:15:50,016 --> 00:15:51,260
# CS12:
# Um,
#
# 412
# 00:15:51,260 --> 00:15:53,272
# CS12:
# so, you know, my dad, that
#
# 413
# 00:15:53,272 --> 00:15:54,004
# Jade:
# Yeah, I do.
#
# 414
# 00:15:54,004 --> 00:15:56,784
# CS12:
# makes him sad. You can tell, um,
#
# 415
# 00:15:56,784 --> 00:15:59,212
# CS12:
# thinking about his dad.
#
# 416
# 00:15:59,212 --> 00:16:01,160
# Jade:
# Why? What's wrong? Do you miss him?
#
# 417
# 00:16:01,160 --> 00:16:02,180
# IlMa:
# Just straight for it.
#
# 418
# 00:16:02,180 --> 00:16:07,168
# CS12:
# One second. Did he just ask, did he just ask Yankee, um,
#
# 419
# 00:16:07,168 --> 00:16:09,276
# IlMa:
# Just... Shudge. Ooh.
#
# 420
# 00:16:09,276 --> 00:16:13,048
# CS12:
# whose mother is dead and his father is like
#
# 421
# 00:16:13,048 --> 00:16:15,604
# CS12:
# the object of a smear campaign and too
#
# 422
# 00:16:15,604 --> 00:16:18,192
# CS12:
# dangerous to be around him and
#
# 423
# 00:16:18,192 --> 00:16:20,428
# CS12:
# like a whole bunch of things.
#
# 424
# 00:16:20,428 --> 00:16:21,320
# CS12:
# What's wrong?
#
# 425
# 00:16:21,320 --> 00:16:23,012
# CS12:
# Do you miss him?
#
# 426
# 00:16:23,012 --> 00:16:29,504
# CS12:
# I don't even know how to respond to that, but, uh, he does. And you know, it's not like
#
# 427
# 00:16:29,504 --> 00:16:36,924
# CS12:
# a complete rejection of the ideal, but he, he has these really interesting eyes where they're like, uh, black
#
# 428
# 00:16:36,924 --> 00:16:37,752
# CS12:
# sclera,
#
# 429
# 00:16:37,752 --> 00:16:39,540
# CS12:
# like gold, yellow,
#
# 430
# 00:16:39,540 --> 00:16:43,856
# CS12:
# iris and deep black purple, where it's more like, it looks like they're just
#
# 431
# 00:16:43,856 --> 00:16:45,260
# CS12:
# a gold ring
#
# 432
# 00:16:45,260 --> 00:16:47,592
# CS12:
# in a sphere of blackness.
#
# 433
# 00:16:47,592 --> 00:16:48,324
# Jade:
# Wow.
#
# 434
# 00:16:48,324 --> 00:16:49,152
# CS12:
# Um,
#
# 435
# 00:16:49,152 --> 00:16:51,548
# CS12:
# and he's got this, uh, stringy kind of,
#
# 436
# 00:16:51,548 --> 00:16:53,656
# CS12:
# uh, muddy brown
#
# 437
# 00:16:53,656 --> 00:16:54,388
# CS12:
# hair,
#
# 438
# 00:16:54,388 --> 00:16:54,896
# CS12:
# uh,
#
# 439
# 00:16:54,896 --> 00:16:56,364
# CS12:
# kind of curly,
#
# 440
# 00:16:56,364 --> 00:17:03,848
# CS12:
# um, and these long curling horns. And like, he's just awkward. He's in a very awkward stage of his life. Um,
#
# 441
# 00:17:03,848 --> 00:17:06,980
# CS12:
# and he'd become aware of how much like kids
#
# 442
# 00:17:06,980 --> 00:17:09,344
# CS12:
# are awkward as hell to talk to.
#
# 443
# 00:17:09,344 --> 00:17:09,884
# Jade:
# Has
#
# 444
# 00:17:09,884 --> 00:17:10,968
# Jade:
# he met
#
# 445
# 00:17:10,968 --> 00:17:12,788
# Jade:
# his dad before? Yeah,
#
# 446
# 00:17:12,788 --> 00:17:14,064
# CS12:
# Yeah. He's met his dad.
#
# 447
# 00:17:14,064 --> 00:17:15,020
# Jade:
# okay.
#
# 448
# 00:17:15,020 --> 00:17:16,520
# CS12:
# He spent
#
# 449
# 00:17:16,520 --> 00:17:19,844
# CS12:
# borderline more time with his dad than you have with your kids.
#
# 450
# 00:17:21,120 --> 00:17:21,884
# Jade:
# uhh,
#
# 451
# 00:17:23,032 --> 00:17:29,876
# CS12:
# Because the chair spends actual quality time with Yankee,
#
# 452
# 00:17:29,876 --> 00:17:32,048
# CS12:
# and Ymir, and Chaya.
#
# 453
# 00:17:32,048 --> 00:17:40,236
# CS12:
# While they were visiting on MatMat, and they would visit on MatMat for literally four or six weeks at a time.
#
# 454
# 00:17:40,236 --> 00:17:43,208
# CS12:
# Chaya growing into like a,
#
# 455
# 00:17:43,208 --> 00:17:44,292
# CS12:
# a socially
#
# 456
# 00:17:44,292 --> 00:17:45,152
# CS12:
# like
#
# 457
# 00:17:45,152 --> 00:17:45,820
# CS12:
# pool kid?
#
# 458
# 00:17:45,820 --> 00:17:47,256
# CS12:
# Totally to do with Zajir.
#
# 459
# 00:17:47,256 --> 00:17:47,700
# CS12:
# Um,
#
# 460
# 00:17:47,700 --> 00:17:50,992
# CS12:
# Ymir, uh, you'll find out is like,
#
# 461
# 00:17:50,992 --> 00:17:54,540
# CS12:
# Ymir and Yankee are like friends because, uh,
#
# 462
# 00:17:54,540 --> 00:18:00,104
# CS12:
# Zajir has like pushed them together to be a friend to each other.
#
# 463
# 00:18:00,452 --> 00:18:01,120
# Jade:
# hmm.
#
# 464
# 00:18:01,120 --> 00:18:02,076
# CS12:
# Um,
#
# 465
# 00:18:02,076 --> 00:18:02,904
# CS12:
# overall,
#
# 466
# 00:18:02,904 --> 00:18:09,524
# CS12:
# what do you say that so suspiciously? They were three fucking, there were four people on an entire planet all by themselves.
#
# 467
# 00:18:09,524 --> 00:18:11,760
# CS12:
# And you're like, how dare they have
#
# 468
# 00:18:11,760 --> 00:18:13,548
# CS12:
# a slightly better than
#
# 469
# 00:18:13,548 --> 00:18:14,440
# IlMa:
# Kittenship.
#
# 470
# 00:18:14,440 --> 00:18:16,740
# CS12:
# good relationship?
#
# 471
# 00:18:16,740 --> 00:18:19,104
# Jade:
# No, I was just getting like a
#
# 472
# 00:18:19,104 --> 00:18:19,868
# Jade:
# little
#
# 473
# 00:18:19,868 --> 00:18:20,888
# Jade:
# bit
#
# 474
# 00:18:21,364 --> 00:18:22,640
# Jade:
# conspiratorial
#
# 475
# 00:18:22,640 --> 00:18:24,684
# Jade:
# because I was thinking like
#
# 476
# 00:18:24,684 --> 00:18:29,480
# CS12:
# Well, you do know that Zitshir IS a conspiracy guy? Yeah,
#
# 477
# 00:18:29,828 --> 00:18:32,032
# IlMa:
# The conspiracy guy. Really.
#
# 478
# 00:18:32,032 --> 00:18:32,348
# CS12:
# he's
#
# 479
# 00:18:32,348 --> 00:18:34,072
# CS12:
# one of the most conspiracy guys you know.
#
# 480
# 00:18:34,072 --> 00:18:34,996
# CS12:
# He's super-fuck
#
# 481
# 00:18:34,996 --> 00:18:37,232
# CS12:
# clever, super-fuckin' charismatic. The
#
# 482
# 00:18:37,232 --> 00:18:40,236
# CS12:
# worst part is, he makes you like what manipulations he does.
#
# 483
# 00:18:40,236 --> 00:18:40,808
# IlMa:
# It's true.
#
# 484
# 00:18:40,808 --> 00:18:42,980
# Jade:
# yeah, so that's what I'm
#
# 485
# 00:18:42,980 --> 00:18:43,968
# Jade:
# thinking about. I
#
# 486
# 00:18:43,968 --> 00:18:44,764
# CS12:
# Yeah.
#
# 487
# 00:18:44,764 --> 00:18:45,688
# CS12:
# Um,
#
# 488
# 00:18:45,688 --> 00:18:46,292
# Jade:
# want- I
#
# 489
# 00:18:46,292 --> 00:18:48,208
# Jade:
# want Yankie to like me. Yeah, I
#
# 490
# 00:18:48,208 --> 00:18:49,804
# CS12:
# you want Yankee to like you?
#
# 491
# 00:18:49,804 --> 00:18:50,344
# Jade:
# do.
#
# 492
# 00:18:51,076 --> 00:18:54,528
# CS12:
# Make a... make a performance check.
#
# 493
# 00:18:54,528 --> 00:18:56,380
# IlMa:
# A really cool 14th level feature. It's
#
# 494
# 00:18:56,380 --> 00:18:58,136
# Jade:
# I make a performance check,
#
# 495
# 00:18:58,136 --> 00:18:58,996
# CS12:
# Yep.
#
# 496
# 00:18:58,996 --> 00:19:01,136
# Jade:
# like I do a persuasion check.
#
# 497
# 00:19:01,136 --> 00:19:04,236
# CS12:
# Oh, you know what? That's fair.
#
# 498
# 00:19:04,236 --> 00:19:04,744
# CS12:
# Well, I mean,
#
# 499
# 00:19:04,744 --> 00:19:10,212
# CS12:
# okay, let's be honest. Make a performance check that determines the DC of the persuasion check.
#
# 500
# 00:19:10,212 --> 00:19:13,856
# CS12:
# Pretty much no matter what, you're gonna do good because you're an expert in persuasion, but like,
#
# 501
# 00:19:13,856 --> 00:19:14,236
# Jade:
# Okay,
#
# 502
# 00:19:14,236 --> 00:19:15,096
# CS12:
# he's a kid.
#
# 503
# 00:19:15,096 --> 00:19:16,660
# CS12:
# Persuasion's not super.
#
# 504
# 00:19:16,660 --> 00:19:18,224
# CS12:
# He's like literally two.
#
# 505
# 00:19:18,796 --> 00:19:19,656
# CS12:
# He's like three.
#
# 506
# 00:19:19,972 --> 00:19:20,576
# Jade:
# yeah,
#
# 507
# 00:19:20,576 --> 00:19:21,116
# Jade:
# okay.
#
# 508
# 00:19:21,116 --> 00:19:21,528
# CS12:
# I mean, 27 on
#
# 509
# 00:19:21,528 --> 00:19:25,076
# CS12:
# persuasion. 24 on persuasion is really good.
#
# 510
# 00:19:25,076 --> 00:19:29,008
# CS12:
# Um, 13 on performance means that the DC was like...
#
# 511
# 00:19:29,008 --> 00:19:31,212
# CS12:
# I mean, he's not your best friend, you know?
#
# 512
# 00:19:31,212 --> 00:19:33,512
# CS12:
# He doesn't really bond to you,
#
# 513
# 00:19:33,512 --> 00:19:38,532
# CS12:
# um, after just like a little bit of time. Depends on how much time you spend doing this, actually.
#
# 514
# 00:19:38,532 --> 00:19:40,416
# CS12:
# Uh, but at least initially,
#
# 515
# 00:19:40,416 --> 00:19:42,044
# CS12:
# uh, he likes you.
#
# 516
# 00:19:42,044 --> 00:19:43,608
# CS12:
# You get a smile out of him
#
# 517
# 00:19:43,608 --> 00:19:46,548
# CS12:
# and you think that he would like to talk to you again.
#
# 518
# 00:19:46,548 --> 00:19:49,328
# CS12:
# But that it's not a sure thing that he's like
#
# 519
# 00:19:49,328 --> 00:19:50,700
# CS12:
# chummy with you yet.
#
# 520
# 00:19:50,700 --> 00:19:51,688
# Jade:
# Oh, okay.
#
# 521
# 00:19:51,688 --> 00:19:54,372
# Jade:
# Well, that's That's to be accepted I suppose.
#
# 522
# 00:19:54,372 --> 00:19:55,232
# IlMa:
# a step.
#
# 523
# 00:19:55,232 --> 00:19:55,836
# CS12:
# It's a good step.
#
# 524
# 00:19:56,248 --> 00:19:56,596
# IlMa:
# Mm-hmm.
#
# 525
# 00:19:56,596 --> 00:20:00,496
# CS12:
# You see he's 27 by the way. So.
#
# 526
# 00:20:00,496 --> 00:20:02,284
# Jade:
# The DC's 27?
#
# 527
# 00:20:02,284 --> 00:20:05,128
# CS12:
# On the persuasion check. So you went a little
#
# 528
# 00:20:05,128 --> 00:20:07,236
# Jade:
# Well, uh, what are you guys up to?
#
# 529
# 00:20:07,236 --> 00:20:08,384
# IlMa:
# through Ezria?
#
# 530
# 00:20:08,384 --> 00:20:09,276
# Jade:
# Yeah,
#
# 531
# 00:20:09,276 --> 00:20:10,488
# Jade:
# and Miley.
#
# 532
# 00:20:10,488 --> 00:20:12,628
# IlMa:
# Currently, uh,
#
# 533
# 00:20:12,628 --> 00:20:15,600
# IlMa:
# going through all the messed up shit in her head. Yes.
#
# 534
# 00:20:15,600 --> 00:20:17,228
# CS12:
# meditating.
#
# 535
# 00:20:17,228 --> 00:20:18,248
# IlMa:
# It's
#
# 536
# 00:20:18,248 --> 00:20:19,780
# IlMa:
# going,
#
# 537
# 00:20:19,780 --> 00:20:22,976
# CS12:
# Tick tick, tick, tick.
#
# 538
# 00:20:22,976 --> 00:20:23,676
# IlMa:
# I think.
#
# 539
# 00:20:23,676 --> 00:20:26,136
# CS12:
# Yep. And there's Miley and then there's Smeeple.
#
# 540
# 00:20:26,136 --> 00:20:26,612
# IlMa:
# Meeple?
#
# 541
# 00:20:26,612 --> 00:20:27,792
# CS12:
# Yep. Smeeple.
#
# 542
# 00:20:27,792 --> 00:20:29,132
# CS12:
# Smoke people.
#
# 543
# 00:20:29,132 --> 00:20:29,640
# IlMa:
# Oh,
#
# 544
# 00:20:29,640 --> 00:20:30,628
# IlMa:
# uh, what?
#
# 545
# 00:20:30,628 --> 00:20:32,384
# Jade:
# Yeah, Smeeple. The smokeman.
#
# 546
# 00:20:32,384 --> 00:20:33,372
# IlMa:
# Oh. I,
#
# 547
# 00:20:33,372 --> 00:20:34,456
# IlMa:
# yes. Yes, this
#
# 548
# 00:20:34,456 --> 00:20:35,572
# IlMa:
# Meeple. I think Ezria's in
#
# 549
# 00:20:35,572 --> 00:20:36,880
# CS12:
# Yes.
#
# 550
# 00:20:36,880 --> 00:20:37,580
# CS12:
# Yeah. The,
#
# 551
# 00:20:37,580 --> 00:20:40,712
# CS12:
# the entire point of this journey?
#
# 552
# 00:20:41,092 --> 00:20:44,064
# IlMa:
# the same room as them when she's meditating.
#
# 553
# 00:20:44,064 --> 00:20:44,604
# IlMa:
# Uh,
#
# 554
# 00:20:44,604 --> 00:20:47,288
# Jade:
# What do they do to pass the time?
#
# 555
# 00:20:47,288 --> 00:20:47,764
# IlMa:
# if there's-
#
# 556
# 00:20:47,764 --> 00:20:49,328
# IlMa:
# yeah, I'm curious too.
#
# 557
# 00:20:49,328 --> 00:20:51,916
# Jade:
# Josh, what do they do to pass the time? I
#
# 558
# 00:20:51,916 --> 00:20:53,608
# Crux:
# Ah, shit, I'm muted.
#
# 559
# 00:20:53,608 --> 00:20:54,564
# IlMa:
# Ahh.
#
# 560
# 00:20:54,564 --> 00:20:56,064
# CS12:
# Sure are.
#
# 561
# 00:20:56,064 --> 00:20:59,004
# Crux:
# Here, I thought y'all was just ignoring me. I was getting a little sad.
#
# 562
# 00:20:59,004 --> 00:21:00,024
# CS12:
# No.
#
# 563
# 00:21:00,024 --> 00:21:03,508
# CS12:
# Josh, we would never ignore you.
#
# 564
# 00:21:03,824 --> 00:21:06,380
# Crux:
# Oh, you should sometimes, to be honest.
#
# 565
# 00:21:06,380 --> 00:21:08,424
# CS12:
# Yeah, but we will never.
#
# 566
# 00:21:08,424 --> 00:21:09,828
# IlMa:
# That will be our downfall.
#
# 567
# 00:21:09,828 --> 00:21:10,400
# Crux:
# Um,
#
# 568
# 00:21:10,400 --> 00:21:11,484
# Crux:
# how much, uh,
#
# 569
# 00:21:11,484 --> 00:21:12,856
# Crux:
# how much time are they passing?
#
# 570
# 00:21:12,856 --> 00:21:16,340
# IlMa:
# I think definitely the initial, like, trying to heal Ezria stage. The
#
# 571
# 00:21:16,340 --> 00:21:17,136
# Jade:
# mean,
#
# 572
# 00:21:17,136 --> 00:21:20,844
# Jade:
# imagine what they're doing over the course of a day. What are they up to?
#
# 573
# 00:21:20,844 --> 00:21:21,320
# Crux:
# Okay,
#
# 574
# 00:21:21,320 --> 00:21:21,732
# Crux:
# okay.
#
# 575
# 00:21:21,732 --> 00:21:22,272
# Crux:
# Well,
#
# 576
# 00:21:23,004 --> 00:21:25,336
# Crux:
# you already saw them in the school,
#
# 577
# 00:21:25,336 --> 00:21:26,132
# Crux:
# so they're
#
# 578
# 00:21:26,132 --> 00:21:27,312
# Crux:
# trying to learn
#
# 579
# 00:21:27,312 --> 00:21:30,188
# Crux:
# more about this new world that they find themselves in.
#
# 580
# 00:21:30,188 --> 00:21:31,304
# Crux:
# One of them
#
# 581
# 00:21:31,304 --> 00:21:32,132
# Crux:
# would
#
# 582
# 00:21:32,132 --> 00:21:36,800
# Crux:
# like to return to the Astral Sea in order to dispose of this
#
# 583
# 00:21:36,800 --> 00:21:37,564
# Crux:
# Far Realm
#
# 584
# 00:21:38,072 --> 00:21:38,516
# Crux:
# bomb
#
# 585
# 00:21:38,516 --> 00:21:39,888
# Crux:
# that they've been carrying around.
#
# 586
# 00:21:40,396 --> 00:21:41,960
# Crux:
# In about
#
# 587
# 00:21:41,960 --> 00:21:42,980
# Crux:
# two days,
#
# 588
# 00:21:42,980 --> 00:21:44,832
# Crux:
# they're going to complain
#
# 589
# 00:21:44,832 --> 00:21:45,820
# Crux:
# that they're hungry.
#
# 590
# 00:21:46,424 --> 00:21:48,500
# Crux:
# I'm wondering who they approach about that.
#
# 591
# 00:21:48,500 --> 00:21:49,648
# Jade:
# We're hungry.
#
# 592
# 00:21:49,648 --> 00:21:51,628
# CS12:
# As yours didn't make sense.
#
# 593
# 00:21:52,328 --> 00:21:54,340
# Jade:
# It's time to eat your flesh.
#
# 594
# 00:21:54,340 --> 00:21:56,960
# IlMa:
# worst part is I think you're talking from experience.
#
# 595
# 00:21:57,848 --> 00:21:59,060
# IlMa:
# That's what gets me anyway.
#
# 596
# 00:21:59,472 --> 00:22:00,268
# Crux:
# Well,
#
# 597
# 00:22:00,268 --> 00:22:03,016
# Crux:
# Ezri is meditating, so they'll bug Vakumi.
#
# 598
# 00:22:03,016 --> 00:22:03,396
# IlMa:
# Oh,
#
# 599
# 00:22:03,396 --> 00:22:03,776
# IlMa:
# okay.
#
# 600
# 00:22:03,776 --> 00:22:11,708
# CS12:
# Just a reminder, when you guys leave, you need to come back in disguise, because Miley doesn't want you guys around,
#
# 601
# 00:22:11,708 --> 00:22:18,040
# CS12:
# publicly. So Miley doesn't want you around publicly, so sticking around is up to you.
#
# 602
# 00:22:18,704 --> 00:22:19,692
# IlMa:
# Ezria is...
#
# 603
# 00:22:19,692 --> 00:22:21,416
# IlMa:
# I don't think she leaves her room really.
#
# 604
# 00:22:21,416 --> 00:22:23,332
# Jade:
# You're describing hunger. Do you
#
# 605
# 00:22:23,332 --> 00:22:24,320
# Jade:
# remember it? Yeah,
#
# 606
# 00:22:25,496 --> 00:22:26,996
# Crux:
# So they approach you, Vakumi,
#
# 607
# 00:22:26,996 --> 00:22:28,048
# Crux:
# together,
#
# 608
# 00:22:28,524 --> 00:22:30,280
# Crux:
# and they say,
#
# 609
# 00:22:30,660 --> 00:22:32,128
# Crux:
# A moment of your time?
#
# 610
# 00:22:32,540 --> 00:22:33,080
# Jade:
# what's up?
#
# 611
# 00:22:33,080 --> 00:22:35,924
# Crux:
# We require sustenance.
#
# 612
# 00:22:36,368 --> 00:22:36,684
# Jade:
# uh,
#
# 613
# 00:22:36,684 --> 00:22:37,768
# Jade:
# what do you eat?
#
# 614
# 00:22:37,768 --> 00:22:38,468
# Crux:
# Current.
#
# 615
# 00:22:38,468 --> 00:22:38,912
# Jade:
# what?
#
# 616
# 00:22:38,912 --> 00:22:39,644
# Jade:
# you eat what?
#
# 617
# 00:22:39,644 --> 00:22:42,040
# Crux:
# You would describe this as lightning,
#
# 618
# 00:22:42,040 --> 00:22:43,380
# Crux:
# in small amounts?
#
# 619
# 00:22:43,380 --> 00:22:44,272
# Jade:
# lightning
#
# 620
# 00:22:44,272 --> 00:22:45,068
# Jade:
# bugs,
#
# 621
# 00:22:45,068 --> 00:22:45,384
# Crux:
# No.
#
# 622
# 00:22:45,956 --> 00:22:46,592
# Jade:
# okay
#
# 623
# 00:22:46,592 --> 00:22:48,476
# Crux:
# Flux. What you would know as
#
# 624
# 00:22:48,476 --> 00:22:49,240
# Jade:
# um,
#
# 625
# 00:22:49,240 --> 00:22:49,876
# Crux:
# lightning. You
#
# 626
# 00:22:49,876 --> 00:22:52,848
# Crux:
# are known to have magical power.
#
# 627
# 00:22:52,848 --> 00:22:54,124
# Jade:
# i can't create a light-
#
# 628
# 00:22:54,124 --> 00:22:57,320
# CS12:
# Miley's pressing X to doubt.
#
# 629
# 00:22:57,320 --> 00:22:57,668
# Crux:
# Right?
#
# 630
# 00:22:58,016 --> 00:22:58,588
# Jade:
# oh wait,
#
# 631
# 00:22:58,588 --> 00:22:59,960
# Jade:
# i can!
#
# 632
# 00:22:59,960 --> 00:23:01,780
# Jade:
# i've got lightning lure!
#
# 633
# 00:23:01,780 --> 00:23:06,032
# Jade:
# my long forgotten, mostly useless cantrip
#
# 634
# 00:23:06,032 --> 00:23:09,196
# Jade:
# that has never worked in this campaign
#
# 635
# 00:23:09,196 --> 00:23:10,792
# Jade:
# but one day it will uh,
#
# 636
# 00:23:10,792 --> 00:23:11,172
# Jade:
# i
#
# 637
# 00:23:11,172 --> 00:23:13,536
# Jade:
# don't know, i guess i use my cantrip
#
# 638
# 00:23:13,536 --> 00:23:14,140
# Jade:
# and
#
# 639
# 00:23:14,140 --> 00:23:15,096
# Jade:
# say afterwards,
#
# 640
# 00:23:15,096 --> 00:23:15,508
# Jade:
# uh,
#
# 641
# 00:23:15,508 --> 00:23:17,168
# Jade:
# does this look tasty at all?
#
# 642
# 00:23:17,676 --> 00:23:23,080
# CS12:
# One byproduct of lightning lure is you last to something and the tether remains.
#
# 643
# 00:23:23,396 --> 00:23:24,064
# Crux:
# Alright.
#
# 644
# 00:23:24,064 --> 00:23:26,524
# Crux:
# Are you doing 48 damage with this?
#
# 645
# 00:23:26,524 --> 00:23:30,424
# CS12:
# I don't think she's attacking them.
#
# 646
# 00:23:30,424 --> 00:23:31,092
# Jade:
# yeah
#
# 647
# 00:23:31,092 --> 00:23:35,056
# Jade:
# I'm not attacking you guys, I'm just attacking, I don't know,
#
# 648
# 00:23:35,056 --> 00:23:36,908
# Jade:
# the door or something.
#
# 649
# 00:23:36,908 --> 00:23:37,768
# CS12:
# nice
#
# 650
# 00:23:37,768 --> 00:23:39,268
# CS12:
# statue.
#
# 651
# 00:23:40,252 --> 00:23:41,176
# Jade:
# I'm not gonna
#
# 652
# 00:23:41,176 --> 00:23:45,012
# Jade:
# destroy Miley's statue, I'm gonna destroy her door.
#
# 653
# 00:23:45,488 --> 00:23:47,020
# IlMa:
# F to the doors.
#
# 654
# 00:23:47,020 --> 00:23:50,152
# CS12:
# Maybe Hot Tree seems like it
#
# 655
# 00:23:50,152 --> 00:23:56,772
# CS12:
# would have mostly, like, curtain doors. But you could definitely have a solid door.
#
# 656
# 00:23:56,772 --> 00:23:57,792
# IlMa:
# F to the curtain.
#
# 657
# 00:23:57,792 --> 00:23:59,324
# Jade:
# Get to the curtain.
#
# 658
# 00:23:59,928 --> 00:24:00,532
# Crux:
# With
#
# 659
# 00:24:00,532 --> 00:24:02,192
# Crux:
# a little bit of
#
# 660
# 00:24:02,192 --> 00:24:02,828
# Crux:
# careful
#
# 661
# 00:24:02,828 --> 00:24:03,496
# Crux:
# core planning
#
# 662
# 00:24:03,496 --> 00:24:04,036
# Crux:
# and
#
# 663
# 00:24:04,036 --> 00:24:04,800
# Crux:
# cooperation,
#
# 664
# 00:24:05,244 --> 00:24:05,752
# Crux:
# they'll
#
# 665
# 00:24:05,752 --> 00:24:06,964
# Crux:
# use their magic
#
# 666
# 00:24:06,964 --> 00:24:07,504
# Crux:
# by, or
#
# 667
# 00:24:07,504 --> 00:24:09,228
# Crux:
# use your magic by like
#
# 668
# 00:24:09,228 --> 00:24:12,680
# Crux:
# putting themselves in contact with it and drinking it slowly. So
#
# 669
# 00:24:12,680 --> 00:24:16,484
# Crux:
# it takes several castings of this cantrip or like, you know, you hold it and
#
# 670
# 00:24:17,216 --> 00:24:17,916
# Crux:
# yeah,
#
# 671
# 00:24:17,916 --> 00:24:19,544
# Crux:
# these people eat electricity.
#
# 672
# 00:24:20,624 --> 00:24:20,972
# IlMa:
# Hmm.
#
# 673
# 00:24:20,972 --> 00:24:22,920
# IlMa:
# Hmm. Good
#
# 674
# 00:24:23,300 --> 00:24:24,896
# IlMa:
# to know. Don't become lightning.
#
# 675
# 00:24:24,896 --> 00:24:26,204
# Jade:
# Raph
#
# 676
# 00:24:26,552 --> 00:24:28,596
# Jade:
# has, yeah, Zun Raph has this like
#
# 677
# 00:24:28,596 --> 00:24:29,424
# Jade:
# kind of
#
# 678
# 00:24:29,424 --> 00:24:30,476
# Jade:
# weirded out
#
# 679
# 00:24:30,476 --> 00:24:33,384
# Jade:
# expression, watching them consume this,
#
# 680
# 00:24:33,384 --> 00:24:38,756
# Jade:
# but she doesn't say anything. She understands that they're far wrong
#
# 681
# 00:24:38,756 --> 00:24:39,840
# Jade:
# influenced,
#
# 682
# 00:24:39,840 --> 00:24:40,476
# Jade:
# so,
#
# 683
# 00:24:40,476 --> 00:24:40,856
# Jade:
# and
#
# 684
# 00:24:40,856 --> 00:24:41,172
# Jade:
# not
#
# 685
# 00:24:41,172 --> 00:24:43,088
# Jade:
# like they can do anything about it
#
# 686
# 00:24:43,756 --> 00:24:47,112
# Crux:
# So while they're charging the golden lightning that
#
# 687
# 00:24:47,112 --> 00:24:47,652
# Crux:
# kind of
#
# 688
# 00:24:47,652 --> 00:24:51,072
# Crux:
# pulses within their bodies, you know, gets a little bit more intense.
#
# 689
# 00:24:51,072 --> 00:24:55,420
# Crux:
# So you can actually tell exactly how hungry they are by how bright their lightning is.
#
# 690
# 00:24:55,420 --> 00:24:57,752
# IlMa:
# Hmm. They have a little gauge in their eyes.
#
# 691
# 00:24:58,132 --> 00:24:59,952
# IlMa:
# Lets you know what battery percent they're at.
#
# 692
# 00:24:59,952 --> 00:25:00,492
# Jade:
# well,
#
# 693
# 00:25:00,840 --> 00:25:01,380
# Jade:
# yeah,
#
# 694
# 00:25:01,380 --> 00:25:02,432
# Jade:
# were you gonna say something?
#
# 695
# 00:25:03,772 --> 00:25:04,600
# Crux:
# ...
# Crux:
# these individuals away,
#
# 3749
# 01:47:26,724 --> 01:47:27,040
# Crux:
# and
#
# 3750
# 01:47:27,040 --> 01:47:28,380
# Crux:
# when they return, they will
#
# 3751
# 01:47:28,380 --> 01:47:30,200
# Crux:
# bring to me what they have experienced,
#
# 3752
# 01:47:30,200 --> 01:47:30,772
# Crux:
# or
#
# 3753
# 01:47:30,772 --> 01:47:32,848
# Crux:
# bring back to us what they have experienced.
#
# 3754
# 01:47:34,496 --> 01:47:38,076
# Crux:
# And as was the means of escaping Anil,
#
# 3755
# 01:47:38,076 --> 01:47:39,512
# Crux:
# we are confident this will
#
# 3756
# 01:47:40,144 --> 01:47:42,412
# Crux:
# reveal the means to escape the
#
# 3757
# 01:47:42,412 --> 01:47:42,792
# Jade:
# well
#
# 3758
# 01:47:42,792 --> 01:47:43,780
# Jade:
# it's decided then
#
# 3759
# 01:47:43,780 --> 01:47:44,768
# Jade:
# that sounds
#
# 3760
# 01:47:45,592 --> 01:47:46,324
# Jade:
# um
#
# 3761
# 01:47:46,324 --> 01:47:50,000
# Jade:
# sounds like a plan sounds like a I'm on board.
#
# 3762
# 01:47:50,412 --> 01:47:51,176
# IlMa:
# And Gray.
#
# 3763
# 01:47:51,176 --> 01:47:51,908
# Crux:
# Astral.
#
# 3764
# 01:47:52,988 --> 01:47:58,488
# Crux:
# You feel a flurry of deliberation among the people of which she basically just gave an order to as
#
# 3765
# 01:47:58,488 --> 01:48:02,388
# Crux:
# they decide whether or not they're okay with this. And some of them are like, Well, I
#
# 3766
# 01:48:02,388 --> 01:48:02,896
# Crux:
# mean, it's
#
# 3767
# 01:48:02,896 --> 01:48:03,948
# Crux:
# not a time limit.
#
# 3768
# 01:48:03,948 --> 01:48:04,328
# IlMa:
# Hmm.
#
# 3769
# 01:48:04,932 --> 01:48:06,240
# CS12:
# Lurry.
#
# 3770
# 01:48:06,240 --> 01:48:09,372
# CS12:
# It's a good word for this.
#
# 3771
# 01:48:09,372 --> 01:48:10,616
# Crux:
# What were you about to say, Ezra?
#
# 3772
# 01:48:10,616 --> 01:48:10,932
# IlMa:
# Oh,
#
# 3773
# 01:48:10,932 --> 01:48:11,344
# IlMa:
# um,
#
# 3774
# 01:48:11,344 --> 01:48:12,652
# IlMa:
# while we are going to be in a
#
# 3775
# 01:48:12,652 --> 01:48:14,600
# IlMa:
# war very soon here,
#
# 3776
# 01:48:14,600 --> 01:48:15,428
# IlMa:
# it would be
#
# 3777
# 01:48:15,428 --> 01:48:16,640
# IlMa:
# quite an effort, but
#
# 3778
# 01:48:16,640 --> 01:48:19,644
# IlMa:
# perhaps that could be the timer? How long the war lasts?
#
# 3779
# 01:48:19,644 --> 01:48:20,728
# Crux:
# The timer for
#
# 3780
# 01:48:20,728 --> 01:48:21,172
# Crux:
# what?
#
# 3781
# 01:48:21,172 --> 01:48:21,520
# IlMa:
# Is
#
# 3782
# 01:48:21,520 --> 01:48:22,444
# IlMa:
# them all returning,
#
# 3783
# 01:48:22,444 --> 01:48:23,528
# IlMa:
# giving you what they know?
#
# 3784
# 01:48:23,528 --> 01:48:24,708
# IlMa:
# Or would it be
#
# 3785
# 01:48:24,708 --> 01:48:26,208
# IlMa:
# smaller timers, like
#
# 3786
# 01:48:26,208 --> 01:48:28,924
# IlMa:
# once every 10 days, which is a cycle we'll
#
# 3787
# 01:48:28,924 --> 01:48:30,008
# IlMa:
# tell you how it works?
#
# 3788
# 01:48:31,248 --> 01:48:32,012
# Crux:
# They will decide.
#
# 3789
# 01:48:32,012 --> 01:48:32,712
# IlMa:
# fair enough
#
# 3790
# 01:48:33,060 --> 01:48:33,664
# IlMa:
# then
#
# 3791
# 01:48:33,664 --> 01:48:34,460
# IlMa:
# i believe we are
#
# 3792
# 01:48:34,460 --> 01:48:35,640
# IlMa:
# good to move forward then
#
# 3793
# 01:48:36,020 --> 01:48:37,776
# IlMa:
# and i will be able to visit gray
#
# 3794
# 01:48:37,776 --> 01:48:38,252
# IlMa:
# so
#
# 3795
# 01:48:38,252 --> 01:48:41,096
# IlMa:
# if you ever want to have a conversation just let
#
# 3796
# 01:48:41,096 --> 01:48:41,476
# IlMa:
# me know
#
# 3797
# 01:48:41,824 --> 01:48:46,684
# CS12:
# We cannot have such traffic in, and we cannot have such traffic out.
#
# 3798
# 01:48:46,684 --> 01:48:53,176
# CS12:
# Thousands of individuals are not permitted to travel within, without,
#
# 3799
# 01:48:53,176 --> 01:48:56,308
# CS12:
# constantly, at their beck and call.
#
# 3800
# 01:48:56,308 --> 01:48:57,040
# Jade:
# Uhhhhh
#
# 3801
# 01:48:57,040 --> 01:48:58,316
# IlMa:
# i went to it all the time and i
#
# 3802
# 01:48:58,316 --> 01:48:58,888
# IlMa:
# can do it
#
# 3803
# 01:48:58,888 --> 01:49:00,004
# IlMa:
# myself
#
# 3804
# 01:49:00,004 --> 01:49:01,248
# IlMa:
# now anyway i'm
#
# 3805
# 01:49:01,248 --> 01:49:01,756
# IlMa:
# sure of it
#
# 3806
# 01:49:01,756 --> 01:49:04,024
# CS12:
# Yeah, not talking about you.
#
# 3807
# 01:49:05,108 --> 01:49:05,776
# IlMa:
# okay
#
# 3808
# 01:49:05,776 --> 01:49:07,020
# IlMa:
# yeah she definitely sued
#
# 3809
# 01:49:07,020 --> 01:49:07,720
# IlMa:
# whoops
#
# 3810
# 01:49:07,720 --> 01:49:08,644
# Crux:
# Is that Zarth'Amon
#
# 3811
# 01:49:08,644 --> 01:49:09,568
# Crux:
# trying to tell Gray off?
#
# 3812
# 01:49:09,568 --> 01:49:10,908
# CS12:
# No, it was call
#
# 3813
# 01:49:10,908 --> 01:49:11,416
# IlMa:
# let's call
#
# 3814
# 01:49:11,416 --> 01:49:11,796
# CS12:
# being like,
#
# 3815
# 01:49:11,796 --> 01:49:14,864
# CS12:
# what are you doing? You can't have channels constantly
#
# 3816
# 01:49:14,864 --> 01:49:16,396
# CS12:
# running in and running out.
#
# 3817
# 01:49:16,396 --> 01:49:17,928
# CS12:
# That's called get found out.
#
# 3818
# 01:49:19,988 --> 01:49:21,296
# Crux:
# Then you would
#
# 3819
# 01:49:21,296 --> 01:49:23,500
# CS12:
# There are ways
#
# 3820
# 01:49:23,500 --> 01:49:24,648
# Crux:
# propose an alternative.
#
# 3821
# 01:49:24,996 --> 01:49:26,400
# CS12:
# to transmit information
#
# 3822
# 01:49:26,400 --> 01:49:29,980
# CS12:
# to this place that do not require the rejoining.
#
# 3823
# 01:49:29,980 --> 01:49:32,184
# CS12:
# I will show you the name and regard.
#
# 3824
# 01:49:32,184 --> 01:49:32,852
# IlMa:
# oh
#
# 3825
# 01:49:32,852 --> 01:49:34,800
# IlMa:
# okay
#
# 3826
# 01:49:34,800 --> 01:49:35,436
# IlMa:
# it is a
#
# 3827
# 01:49:35,436 --> 01:49:36,040
# IlMa:
# lot
#
# 3828
# 01:49:36,040 --> 01:49:36,836
# IlMa:
# it is useful
#
# 3829
# 01:49:36,836 --> 01:49:39,872
# CS12:
# It is as much as can be.
#
# 3830
# 01:49:40,668 --> 01:49:42,712
# Crux:
# I think Gray just
#
# 3831
# 01:49:42,712 --> 01:49:45,364
# Crux:
# drops the conversation entirely and
#
# 3832
# 01:49:45,364 --> 01:49:46,512
# Crux:
# walks away.
#
# 3833
# 01:49:46,512 --> 01:49:49,964
# IlMa:
# sorry to understand someone whose life is very different
#
# 3834
# 01:49:49,964 --> 01:49:50,856
# IlMa:
# still i appreciate
#
# 3835
# 01:49:50,856 --> 01:49:51,204
# IlMa:
# their
#
# 3836
# 01:49:51,204 --> 01:49:51,584
# IlMa:
# health
#
# 3837
# 01:49:51,584 --> 01:49:52,508
# IlMa:
# and then she like
#
# 3838
# 01:49:52,508 --> 01:49:54,040
# IlMa:
# as we grabs zonneth's hand
#
# 3839
# 01:49:54,040 --> 01:49:54,836
# IlMa:
# well um
#
# 3840
# 01:49:55,536 --> 01:49:56,268
# IlMa:
# how about to walk i
#
# 3841
# 01:49:56,268 --> 01:49:57,224
# IlMa:
# just want to
#
# 3842
# 01:49:57,224 --> 01:49:58,148
# IlMa:
# be in the moment with you
#
# 3843
# 01:49:58,148 --> 01:49:58,848
# IlMa:
# she smiles
#
# 3844
# 01:49:58,848 --> 01:49:59,900
# Jade:
# She smiles back.
#
# 3845
# 01:49:59,900 --> 01:50:01,464
# Jade:
# It sounds perfect.
#
# 3846
# 01:50:01,780 --> 01:50:05,520
# CS12:
# That's our end of session to do to do.
#
# 3847
# 01:50:05,900 --> 01:50:06,408
# IlMa:
# that
#
# 3848
# 01:50:06,408 --> 01:50:08,452
# IlMa:
# was our direction i was expecting at all
#
# 3849
# 01:50:08,452 --> 01:50:09,184
# IlMa:
# uh
#
# 3850
# 01:50:09,184 --> 01:50:09,628
# CS12:
# No!
#
# 3851
# 01:50:09,628 --> 01:50:10,104
# IlMa:
# huh
#
# 3852
# 01:50:10,104 --> 01:50:10,772
# CS12:
# No bastard!
#
# 3853
# 01:50:11,376 --> 01:50:13,004
# CS12:
# De-brailed everything I had planned.
#
# 3854
# 01:50:13,320 --> 01:50:13,988
# CS12:
# Well, you didn't.
#
# 3855
# 01:50:13,988 --> 01:50:15,040
# Crux:
# All you
#
# 3856
# 01:50:15,040 --> 01:50:15,804
# CS12:
# We're still on
#
# 3857
# 01:50:15,804 --> 01:50:17,496
# CS12:
# that path, but you know, we
#
# 3858
# 01:50:17,496 --> 01:50:18,516
# CS12:
# got a flat tire.
#
# 3859
# 01:50:19,688 --> 01:50:24,292
# Crux:
# to do is consider a far-realm infected object as the same as yourself.
#
# 3860
# 01:50:24,672 --> 01:50:26,076
# CS12:
# Couldn't just let her drink it.
#
# 3861
# 01:50:27,348 --> 01:50:28,048
# Jade:
# I wasn't
#
# 3862
# 01:50:28,048 --> 01:50:28,940
# Jade:
# even...
#
# 3863
# 01:50:28,940 --> 01:50:29,608
# Jade:
# Yeah,
#
# 3864
# 01:50:29,608 --> 01:50:30,468
# Jade:
# well, yeah.
#
# 3865
# 01:50:30,468 --> 01:50:30,976
# CS12:
# All right.
#
# 3866
# 01:50:30,976 --> 01:50:33,724
# CS12:
# We solved the tumors. Zunereth, you've aged 10 years.
#
# 3867
# 01:50:34,136 --> 01:50:35,988
# Jade:
# I already marked it on my sheet.
#
# 3868
# 01:50:36,496 --> 01:50:37,132
# IlMa:
# no
#
# 3869
# 01:50:37,132 --> 01:50:38,216
# IlMa:
# i mean at least that's like
#
# 3870
# 01:50:38,216 --> 01:50:40,260
# IlMa:
# a little over uh what
#
# 3871
# 01:50:40,260 --> 01:50:40,704
# IlMa:
# is it
#
# 3872
# 01:50:40,704 --> 01:50:41,948
# IlMa:
# you age 118 16 oh yeah 116 so
#
# 3873
# 01:50:41,948 --> 01:50:43,608
# CS12:
# 16th.
#
# 3874
# 01:50:43,608 --> 01:50:45,428
# Jade:
# No, it's off my macbook.
#
# 3875
# 01:50:45,428 --> 01:50:45,840
# IlMa:
# it's
#
# 3876
# 01:50:45,840 --> 01:50:46,892
# IlMa:
# like a
#
# 3877
# 01:50:47,560 --> 01:50:48,580
# IlMa:
# year and a half
#
# 3878
# 01:50:48,580 --> 01:50:49,504
# IlMa:
# effectively for you
#
# 3879
# 01:50:49,504 --> 01:50:51,484
# CS12:
# Yeah, but it's actual 10 years.
#
# 3880
# 01:50:51,484 --> 01:50:51,992
# IlMa:
# oh
#
# 3881
# 01:50:51,992 --> 01:50:52,404
# IlMa:
# i see
#
# 3882
# 01:50:52,404 --> 01:50:54,416
# CS12:
# No, it's actual 10 years because,
#
# 3883
# 01:50:54,416 --> 01:50:55,948
# CS12:
# I mean, she's only like
#
# 3884
# 01:50:55,948 --> 01:50:56,648
# CS12:
# that much
#
# 3885
# 01:50:56,648 --> 01:50:57,924
# CS12:
# older physically in
#
# 3886
# 01:50:57,924 --> 01:50:59,232
# CS12:
# like age
#
# 3887
# 01:50:59,232 --> 01:51:00,476
# CS12:
# and decrepitness,
#
# 3888
# 01:51:00,476 --> 01:51:01,304
# CS12:
# but she's
#
# 3889
# 01:51:01,304 --> 01:51:04,148
# CS12:
# lost 10 years of eventual lifespan, you know,
#
# 3890
# 01:51:04,464 --> 01:51:06,188
# CS12:
# people died 10 years earlier, that
#
# 3891
# 01:51:06,188 --> 01:51:07,400
# CS12:
# is how it is.
#
# 3892
# 01:51:07,400 --> 01:51:08,580
# CS12:
# That doesn't really matter, you
#
# 3893
# 01:51:08,580 --> 01:51:12,736
# CS12:
# know, considering she's likely to not die of old age anyway.
#
# 3894
# 01:51:13,308 --> 01:51:14,008
# IlMa:
# oh no
#
# 3895
# 01:51:14,008 --> 01:51:14,740
# IlMa:
# yeah
#
# 3896
# 01:51:14,740 --> 01:51:17,104
# CS12:
# That's, that's game guys.
#
# 3897
# 01:51:17,104 --> 01:51:17,868
# Crux:
# Thank you, Bryce.
#
# 3898
# 01:51:18,760 --> 01:51:19,876
# IlMa:
# thank you bryce
#
# 3899
# 01:51:19,876 --> 01:51:21,504
# IlMa:
# thank you everyone that That got weird.
#
# 3900
# 01:51:22,076 --> 01:51:22,456
# IlMa:
# Loved it.
#
# 3901
# 01:51:22,456 --> 01:51:24,148
# Jade:
# Yeah, it did.
#
# 3902
# 01:51:24,148 --> 01:51:24,752
# CS12:
# Got weird,
#
# 3903
# 01:51:24,752 --> 01:51:26,444
# CS12:
# we can fast.
#
# 3904
# 01:51:26,444 --> 01:51:27,080
# Jade:
# And
#
# 3905
# 01:51:27,080 --> 01:51:28,356
# Jade:
# I was like,
#
# 3906
# 01:51:28,356 --> 01:51:29,216
# Jade:
# gosh,
#
# 3907
# 01:51:29,216 --> 01:51:29,884
# Jade:
# um,
#
# 3908
# 01:51:29,884 --> 01:51:32,056
# Jade:
# what a situation have
#
# 3909
# 01:51:32,056 --> 01:51:33,236
# Jade:
# we put in? Bryce, I think you know how
#
# 3910
# 01:51:33,236 --> 01:51:35,920
# Jade:
# to you know how to
#
# 3911
# 01:51:35,920 --> 01:51:38,540
# Jade:
# harm into me in this campaign
#
# 3912
# 01:51:38,952 --> 01:51:41,540
# CS12:
# Well, the purpose of horror
#
# 3913
# 01:51:41,540 --> 01:51:45,216
# CS12:
# like this is to create torment.
#
# 3914
# 01:51:45,216 --> 01:51:45,980
# CS12:
# And it's just
#
# 3915
# 01:51:45,980 --> 01:51:51,000
# CS12:
# the truth, as I spoke earlier in this session, that the,
#
# 3916
# 01:51:51,000 --> 01:51:51,700
# CS12:
# the, the,
#
# 3917
# 01:51:51,700 --> 01:51:52,752
# CS12:
# the evil of
#
# 3918
# 01:51:53,580 --> 01:51:55,400
# CS12:
# cosmic horror is that it isn't evil.
#
# 3919
# 01:51:55,400 --> 01:51:56,004
# Jade:
# yeah
#
# 3920
# 01:51:56,004 --> 01:52:00,832
# CS12:
# You're just, your assumptions breaking down
#
# 3921
# 01:52:00,832 --> 01:52:02,780
# CS12:
# and being proven untrue, eroding
#
# 3922
# 01:52:02,780 --> 01:52:08,792
# CS12:
# every sense you thought you had, making you question everything and understand nothing, that
#
# 3923
# 01:52:08,792 --> 01:52:09,428
# CS12:
# is a
#
# 3924
# 01:52:09,428 --> 01:52:10,032
# CS12:
# problem,
#
# 3925
# 01:52:10,032 --> 01:52:12,428
# CS12:
# because it makes you understand how little you know. And
#
# 3926
# 01:52:12,428 --> 01:52:16,616
# CS12:
# it lets you know that the rules can change and that you don't actually know
#
# 3927
# 01:52:16,616 --> 01:52:17,540
# CS12:
# anything,
#
# 3928
# 01:52:17,540 --> 01:52:21,760
# CS12:
# that there's no right answer that you can make cause you don't fucking have any clue.
#
# 3929
# 01:52:21,760 --> 01:52:23,836
# CS12:
# I'm glad I was able to have Zirthamon just
#
# 3930
# 01:52:24,664 --> 01:52:26,388
# CS12:
# yo up and just
#
# 3931
# 01:52:27,404 --> 01:52:28,456
# Jade:
# thank you so much
#
# 3932
# 01:52:29,060 --> 01:52:29,664
# CS12:
# be like,
#
# 3933
# 01:52:29,664 --> 01:52:30,620
# Jade:
# for doing them
#
# 3934
# 01:52:30,620 --> 01:52:32,664
# CS12:
# dick philosophy in the dick, you know?
#
# 3935
# 01:52:32,664 --> 01:52:34,228
# Jade:
# it was wonderful it
#
# 3936
# 01:52:34,228 --> 01:52:35,856
# Crux:
# I really like the line, well,
#
# 3937
# 01:52:35,856 --> 01:52:37,356
# Crux:
# uh, Ezria changes all the time,
#
# 3938
# 01:52:37,356 --> 01:52:37,672
# Crux:
# right?
#
# 3939
# 01:52:37,672 --> 01:52:39,108
# Crux:
# So I'm sure she'd be happy for
#
# 3940
# 01:52:39,108 --> 01:52:39,968
# Crux:
# you to hold the brush.
#
# 3941
# 01:52:39,968 --> 01:52:40,924
# IlMa:
# Yeah, that was beautiful.
#
# 3942
# 01:52:41,368 --> 01:52:43,092
# Jade:
# was beautiful i'm all
#
# 3943
# 01:52:43,092 --> 01:52:44,368
# IlMa:
# And you know, Esri's here?
#
# 3944
# 01:52:44,368 --> 01:52:45,036
# IlMa:
# Holdin' your hand.
#
# 3945
# 01:52:45,036 --> 01:52:45,512
# CS12:
# Also,
#
# 3946
# 01:52:45,828 --> 01:52:47,968
# Jade:
# curious what would have happened if i
#
# 3947
# 01:52:47,968 --> 01:52:49,692
# Jade:
# hadn't used tatsu though oh no
#
# 3948
# 01:52:49,692 --> 01:52:52,312
# CS12:
# as you would have been an eyeball monster,
#
# 3949
# 01:52:52,312 --> 01:52:54,260
# Crux:
# Maile would have been really happy with the disguise.
#
# 3950
# 01:52:54,576 --> 01:52:58,220
# Crux:
# Not what I expected, but, um, you know, I think it works.
#
# 3951
# 01:52:58,696 --> 01:53:11,556
# CS12:
# as you would have had a, uh, an aura of, an aura of total nightmares, which is the longer that it's like she sees from the eyes of all creatures near her. Like she sees all eyes.
#
# 3952
# 01:53:11,556 --> 01:53:12,064
# Crux:
# Uh, she
#
# 3953
# 01:53:12,064 --> 01:53:12,892
# CS12:
# Um,
#
# 3954
# 01:53:12,892 --> 01:53:14,680
# Crux:
# would have joined with the hive mind.
#
# 3955
# 01:53:14,680 --> 01:53:15,604
# CS12:
# you know,
#
# 3956
# 01:53:15,604 --> 01:53:17,552
# CS12:
# problem is, is that like,
#
# 3957
# 01:53:17,552 --> 01:53:18,124
# IlMa:
# Mmm.
#
# 3958
# 01:53:18,124 --> 01:53:21,672
# CS12:
# she also, like those eyes become her.
#
# 3959
# 01:53:21,672 --> 01:53:26,340
# Jade:
# other people's eyes become her
#
# 3960
# 01:53:27,036 --> 01:53:27,928
# Jade:
# oh
#
# 3961
# 01:53:27,928 --> 01:53:28,660
# CS12:
# They just like
#
# 3962
# 01:53:28,660 --> 01:53:30,544
# CS12:
# pop themselves out of their skulls somewhere
#
# 3963
# 01:53:30,544 --> 01:53:31,436
# CS12:
# to follow.
#
# 3964
# 01:53:31,436 --> 01:53:32,808
# Jade:
# so cursed
#
# 3965
# 01:53:32,808 --> 01:53:34,404
# Crux:
# Oh, I thought like people,
#
# 3966
# 01:53:34,404 --> 01:53:34,752
# CS12:
# Yeah.
#
# 3967
# 01:53:34,752 --> 01:53:37,596
# Crux:
# like as she looks through people's eyes, they become
#
# 3968
# 01:53:37,596 --> 01:53:38,008
# Crux:
# her
#
# 3969
# 01:53:38,008 --> 01:53:39,892
# Crux:
# and then she just self replicates and
#
# 3970
# 01:53:39,892 --> 01:53:43,856
# Crux:
# suddenly, uh, uh, Khaestus doesn't stand a fucking chance.
#
# 3971
# 01:53:43,856 --> 01:53:47,500
# Crux:
# How will you do against the might of 10,000 Ezrias?
#
# 3972
# 01:53:47,500 --> 01:53:51,208
# CS12:
# And that's my eyes.
#
# 3973
# 01:53:51,748 --> 01:53:54,752
# Crux:
# 10,000 eyes in the air.
#
# 3974
# 01:53:54,752 --> 01:53:56,700
# CS12:
# Eyes.
#
# 3975
# 01:53:56,700 --> 01:53:57,144
# Jade:
# okay
#
# 3976
# 01:53:57,588 --> 01:54:00,272
# Jade:
# i feel like i've made a good choice then.
#
# 3977
# 01:54:01,036 --> 01:54:01,768
# Crux:
# Oh, what's
#
# 3978
# 01:54:01,768 --> 01:54:04,132
# IlMa:
# That was a real life DC-25.
#
# 3979
# 01:54:04,512 --> 01:54:05,340
# Crux:
# going on?
#
# 3980
# 01:54:05,340 --> 01:54:07,480
# Jade:
# What was a DC-25?
#
# 3981
# 01:54:07,480 --> 01:54:09,748
# IlMa:
# Just letting you making that choice.
#
# 3982
# 01:54:09,748 --> 01:54:11,056
# IlMa:
# Like, which choice is correct?
#
# 3983
# 01:54:11,056 --> 01:54:12,012
# Jade:
# Yeah,
#
# 3984
# 01:54:13,376 --> 01:54:14,524
# CS12:
# Um,
#
# 3985
# 01:54:14,524 --> 01:54:16,824
# CS12:
# I highly recommend
#
# 3986
# 01:54:16,824 --> 01:54:17,460
# CS12:
# that we let
#
# 3987
# 01:54:17,460 --> 01:54:21,200
# CS12:
# Second Hand Scribe go for the night. Devil.
#
# 3988
# 01:54:21,200 --> 01:54:21,708
# Jade:
# okay.
#
# 3989
# 01:54:21,708 --> 01:54:22,408
# Crux:
# Get out of here.
#
# 3990
# 01:54:22,408 --> 01:54:22,980
# IlMa:
# indeed
#
# 3991
# 01:54:22,980 --> 01:54:23,968
# Crux:
# Get out of here, Craig.
#
# 3992
# 01:54:25,464 --> 01:54:27,348
# Jade:
# You've listened for long enough.
