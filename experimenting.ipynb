# %% [markdown]
# The idea behind this notebook is to transcribe and align an entire audacity project.  However, this time I will take a different approach:
#
# Instead of transcribing and then mixing the files together I will try to transcribe after mixing the files together.

# %%
import os, re, json
import pandas as pd

import torch
import torchaudio

import utils
import utils.prepare as prep

from IPython.display import display, Audio

# %%
SR = 16_000
folder = './data/jotun 02-05-2023/'
vofile = 'voice_only.wav'

# %%
aupfile = utils.find_aup_file(folder)
aupfile = os.path.join(folder,aupfile)
project = utils.parse_audacity_project(aupfile)
project
# Out:
# {'project_name': 'gWJmbiLGkb_data',
#  'root_path': './data/jotun 02-05-2023',
#  'data_path': './data/jotun 02-05-2023\\gWJmbiLGkb_data',
#  'files': [{'filename': '1-JadePixie_7138.ogg', 'offset': 0.0},
#   {'filename': '2-CS12_4510.ogg', 'offset': 0.0},
#   {'filename': '3-Marburg42_5566.ogg', 'offset': 0.0},
#   {'filename': '4-IlMaximuslI_9218.ogg', 'offset': 0.0},
#   {'filename': '5-Crux_4429.ogg', 'offset': 0.0}]}

# %%
vad_datas = list()
datapath = project['data_path']
for file in project['files']:
    filename = file['filename']
    path = os.path.join(datapath,filename)
    segments = prep.get_vad_data(path)
    for segment in segments:
        segment['file'] = filename
    vad_datas.append(segments)

# %%
vad_df = [pd.DataFrame(data) for data in vad_datas]
vad_df = pd.concat(vad_df)
vad_df = vad_df.sort_values('start').reset_index().drop(columns='index')
vad_df.head()
# Out:
#     start     end                  file
# 0   69664  109024       2-CS12_4510.ogg
# 1  111136  120800       2-CS12_4510.ogg
# 2  217120  259552       2-CS12_4510.ogg
# 3  268320  284128  1-JadePixie_7138.ogg
# 4  288800  306656  3-Marburg42_5566.ogg

# %%
# def save_audio(path: str,
#                tensor: torch.Tensor,
#                sampling_rate: int = 16000):
#     torchaudio.save(path, tensor.unsqueeze(0), sampling_rate, bits_per_sample=16)

# audios = dict()
# for file in project['files']:
#         filename = file['filename']
#         filepath = os.path.join(project['data_path'], file['filename'])
#         audios[filename] = prep.get_waveform(filepath)

# chunks = []
# for idx, row in df.sort_values('start').iterrows():
#     file = row['file']
#     start = row['start']
#     end = row['end']
#     chunks.append(audios[file][start:end])

# wav = torch.cat(chunks)
# save_audio(os.path.join(folder, 'voice_only.wav'), wav)

# short_vad = prep.align_chunks(df.to_dict(orient='records'))
# prep.cache_json(short_vad, os.path.join(folder, 'voice_only.wav_vad.json'))

# del audios

# %%
filepath = os.path.join(folder, vofile)
vad_short = prep.get_vad_data(filepath)
align_short = prep.get_alignment_data(filepath)

# %%
seg_short = pd.DataFrame(vad_short)
seg_short['file'] = vad_df['file']
words = pd.DataFrame(align_short)
display(words.head(15))
display(seg_short.head())
# Out:
#           text  start    end
# 0     Welcome,    322   5154
# 1      scribe,   5798  12885
# 2           to  13207  13851
# 3         this  26736  28991
# 4       place.  30601  35111
# 5   Apparently  48640  53476
# 6       nobody  54121  57345
# 7         else  57990  60569
# 8        wants  60891  63793
# 9           to  64115  64760
# 10         say  65728  67340
# 11          hi  67984  69919
# 12          to  70241  70886
# 13         you  71208  72820
# 14    anymore.  73465  77012
#     start     end                  file
# 0       0   39360       2-CS12_4510.ogg
# 1   39360   49024       2-CS12_4510.ogg
# 2   49024   91456       2-CS12_4510.ogg
# 3   91456  107264  1-JadePixie_7138.ogg
# 4  107264  125120  3-Marburg42_5566.ogg

# %%
# filter if words midframe in segment
words[words[['start','end']].mean(axis=1).between(49024,91456)]
# Out:
#           text  start    end
# 5   Apparently  48640  53476
# 6       nobody  54121  57345
# 7         else  57990  60569
# 8        wants  60891  63793
# 9           to  64115  64760
# 10         say  65728  67340
# 11          hi  67984  69919
# 12          to  70241  70886
# 13         you  71208  72820
# 14    anymore.  73465  77012

# %%
seg_short['subsegments'] = seg_short.apply(lambda x: words[words[['start','end']].mean(axis=1).between(x['start'],x['end'])], axis=1)

# %%
words['mid'] = words[['start','end']].mean(axis=1)

# %%
seg_short['subsegments'] = seg_short.apply(lambda x: words[words.mid.between(x['start'],x['end'])], axis=1)

# %%
seg_short['text'] = seg_short.apply(lambda x: ' '.join(x.subsegments.text.ravel()), axis=1)
seg_short.head()
# Out:
#     start     end                  file  \
# 0       0   39360       2-CS12_4510.ogg
# 1   39360   49024       2-CS12_4510.ogg
# 2   49024   91456       2-CS12_4510.ogg
# 3   91456  107264  1-JadePixie_7138.ogg
# 4  107264  125120  3-Marburg42_5566.ogg
#
#                                          subsegments  \
# 0         text  start    end
# 0  Welcome,    322  ...
# 1  Empty DataFrame
# Columns: [text, start, end]
# In...
# 2            text  start    end
# 5   Apparently  4...
# 3        text  start     end
# 15     Hi,  91847   ...
# 4        text   start     end
# 17     Hi,  107520 ...
#
#                                                 text
# 0                    Welcome, scribe, to this place.
# 1
# 2  Apparently nobody else wants to say hi to you ...
# 3                                         Hi, Craig.
# 4                                         Hi, Craig.

# %%
## srt subtitles
output = ''
n = '\n'
count = 0
for i, (idx, row) in enumerate(seg_short.sort_values('start').iterrows()):
    txt = row['text']
    if len(txt) > 0:
        count += 1
        speaker = utils.get_discord_name(row['file'])
        start = utils.frame_to_srt_timestamp(row['start'])
        end = utils.frame_to_srt_timestamp(row['end'])
        output += f"{count}"+n
        output += f"{start} --> {end}"+n
        output += f"{speaker}:{n}{txt.strip()}"+n+n

with open(os.path.join(folder, 'short.srt'), 'w') as f:
    f.write(output)    
print(output)
# Out:
# 1
# 00:00:00,000 --> 00:00:02,460
# CS12_4510:
# Welcome, scribe, to this place.
#
# 2
# 00:00:03,064 --> 00:00:05,716
# CS12_4510:
# Apparently nobody else wants to say hi to you anymore.
#
# 3
# 00:00:05,716 --> 00:00:06,704
# JadePixie_7138:
# Hi, Craig.
#
# 4
# 00:00:06,704 --> 00:00:07,820
# Marburg42_5566:
# Hi, Craig.
#
# 5
# 00:00:07,820 --> 00:00:08,712
# IlMaximuslI_9218:
# Hi,
#
# 6
# 00:00:08,712 --> 00:00:09,412
# IlMaximuslI_9218:
# thing.
#
# 7
# 00:00:09,412 --> 00:00:10,080
# IlMaximuslI_9218:
# First to go.
#
# 8
# 00:00:10,080 --> 00:00:11,612
# Crux_4429:
# His name's not Craig anymore.
#
# 9
# 00:00:11,612 --> 00:00:15,704
# CS12_4510:
# Hello, jerk. Hello, jerks, evil twin.
#
# 10
# 00:00:17,200 --> 00:00:18,956
# CS12_4510:
# OK, OK.
#
# 11
# 00:00:18,956 --> 00:00:23,688
# CS12_4510:
# Yggdrasil. Hello, Library of Jade. Hello, all my players.
#
# 12
# 00:00:23,688 --> 00:00:27,588
# CS12_4510:
# Hello, me being a player. Actually, sorry, let's just have it.
#
# 13
# 00:00:27,588 --> 00:00:31,136
# CS12_4510:
# at us doing research,
#
# 14
# 00:00:31,136 --> 00:00:32,220
# CS12_4510:
# doing things
#
# 15
# 00:00:32,824 --> 00:00:33,588
# CS12_4510:
# this week
#
# 16
# 00:00:33,904 --> 00:00:34,444
# CS12_4510:
# are
#
# 17
# 00:00:34,824 --> 00:00:36,004
# CS12_4510:
# the fuck we doing.
#
# 18
# 00:00:36,004 --> 00:00:37,888
# Crux_4429:
# Yeah.
#
# 19
# 00:00:38,652 --> 00:00:43,512
# Crux_4429:
# You had a interesting conversation with some people displaced out of time.
#
# 20
# 00:00:43,512 --> 00:00:46,868
# Crux_4429:
# You had an interesting conversation with some books,
#
# 21
# 00:00:46,868 --> 00:00:48,304
# Crux_4429:
# some information was gained.
#
# 22
# 00:00:48,304 --> 00:00:49,324
# CS12_4510:
# Yeah.
#
# 23
# 00:00:49,324 --> 00:00:50,408
# Crux_4429:
# And then you went home
#
# 24
# 00:00:50,408 --> 00:00:51,044
# Crux_4429:
# and
#
# 25
# 00:00:51,936 --> 00:00:55,324
# Crux_4429:
# sold a dead body for a telescope and some monies.
#
# 26
# 00:00:55,324 --> 00:01:02,200
# CS12_4510:
# Coloscopes, some money, some typewriters, and some hot rocks. They interact with water in order to boil it.
#
# 27
# 00:01:02,200 --> 00:01:03,508
# IlMaximuslI_9218:
# Damn right we did.
#
# 28
# 00:01:03,508 --> 00:01:04,592
# CS12_4510:
# Well, in order to heat it,
#
# 29
# 00:01:04,940 --> 00:01:06,376
# CS12_4510:
# there's little enough it can boil.
#
# 30
# 00:01:07,716 --> 00:01:09,216
# CS12_4510:
# Don't grab it if you're sweaty.
#
# 31
# 00:01:09,216 --> 00:01:11,036
# IlMaximuslI_9218:
# Grab it if you're sweaty?
#
# 32
# 00:01:11,036 --> 00:01:11,896
# IlMaximuslI_9218:
# Oh no.
#
# 33
# 00:01:11,896 --> 00:01:13,076
# Crux_4429:
# Mom's spaghetti.
#
# 34
# 00:01:13,744 --> 00:01:16,076
# Crux_4429:
# Today is Sunday. Y'all got paid.
#
# 35
# 00:01:16,076 --> 00:01:24,968
# CS12_4510:
# Paid 130 monies. Everybody add their appropriate dividends from that chair to their sheet. I take 65, Max takes 65.
#
# 36
# 00:01:24,968 --> 00:01:25,476
# Crux_4429:
# Uh,
#
# 37
# 00:01:25,476 --> 00:01:26,400
# Crux_4429:
# that is just
#
# 38
# 00:01:26,400 --> 00:01:27,324
# Crux_4429:
# patently false.
#
# 39
# 00:01:27,324 --> 00:01:29,272
# Marburg42_5566:
# Alright, it was a 65, it was... What do
#
# 40
# 00:01:29,272 --> 00:01:30,004
# CS12_4510:
# you mean?
#
# 41
# 00:01:30,004 --> 00:01:32,112
# CS12_4510:
# Oh, 35! Whoops.
#
# 42
# 00:01:32,112 --> 00:01:32,940
# Marburg42_5566:
# Yeah, okay.
#
# 43
# 00:01:32,940 --> 00:01:37,640
# IlMaximuslI_9218:
# I was gonna say, did we just give Andre and Aloe Cher to you guys? Like...
#
# 44
# 00:01:38,692 --> 00:01:39,456
# IlMaximuslI_9218:
# That's funny.
#
# 45
# 00:01:39,456 --> 00:01:39,964
# CS12_4510:
# Okay.
#
# 46
# 00:01:40,312 --> 00:01:43,188
# Crux_4429:
# I don't know why we didn't just do 32 and a half all around.
#
# 47
# 00:01:43,188 --> 00:01:45,136
# CS12_4510:
# No.
#
# 48
# 00:01:45,136 --> 00:01:46,252
# IlMaximuslI_9218:
# No. I think it's because
#
# 49
# 00:01:46,252 --> 00:01:48,040
# IlMaximuslI_9218:
# Lauren spends a lot of money.
#
# 50
# 00:01:48,388 --> 00:01:48,800
# Crux_4429:
# I
#
# 51
# 00:01:48,800 --> 00:01:51,836
# Crux_4429:
# think this is the patriarchy. Why do the men get paid more than the women?
#
# 52
# 00:01:51,836 --> 00:01:52,632
# IlMaximuslI_9218:
# Oh no.
#
# 53
# 00:01:52,632 --> 00:01:53,716
# IlMaximuslI_9218:
# Now there is a problem.
#
# 54
# 00:01:53,716 --> 00:01:56,816
# JadePixie_7138:
# I assumed it was because, uh...
#
# 55
# 00:01:56,816 --> 00:01:58,156
# CS12_4510:
# I think
#
# 56
# 00:01:58,156 --> 00:02:02,280
# CS12_4510:
# it's entirely related to our individual expenses.
#
# 57
# 00:02:02,280 --> 00:02:03,236
# JadePixie_7138:
# Rox needs
#
# 58
# 00:02:03,236 --> 00:02:04,192
# JadePixie_7138:
# to eat
#
# 59
# 00:02:04,192 --> 00:02:04,732
# JadePixie_7138:
# and
#
# 60
# 00:02:04,732 --> 00:02:05,720
# JadePixie_7138:
# Lauren's either wizard.
#
# 61
# 00:02:05,720 --> 00:02:07,188
# CS12_4510:
# Pretty much, yeah.
#
# 62
# 00:02:07,792 --> 00:02:15,340
# CS12_4510:
# Anyway, I wasn't trying to make that decision for you guys. If you really want to get into the details of negotiating our wages each week, we can.
#
# 63
# 00:02:15,340 --> 00:02:16,680
# Crux_4429:
# It's not with the patriarchy.
#
# 64
# 00:02:16,680 --> 00:02:17,220
# IlMaximuslI_9218:
# I mean,
#
# 65
# 00:02:17,220 --> 00:02:19,296
# IlMaximuslI_9218:
# I have a lot of money, so I'm fine. Oh yeah, I'm
#
# 66
# 00:02:19,296 --> 00:02:20,028
# Marburg42_5566:
# very comfortable.
#
# 67
# 00:02:21,176 --> 00:02:22,932
# IlMaximuslI_9218:
# Max, why did you say it like that?
#
# 68
# 00:02:22,932 --> 00:02:27,408
# CS12_4510:
# Well, Aloe, I suppose you can have the farm gold instead of Max then.
#
# 69
# 00:02:28,616 --> 00:02:30,916
# CS12_4510:
# Since we know that you're in debt.
#
# 70
# 00:02:30,916 --> 00:02:35,616
# CS12_4510:
# And it would be cruel if Max has to
#
# 71
# 00:02:35,616 --> 00:02:41,116
# CS12_4510:
# take that dividend away from her. I just know you have a certain lifestyle. You like to leave Max?
#
# 72
# 00:02:41,116 --> 00:02:42,936
# Marburg42_5566:
# Although once Ayan's got a phone call. Hello?
#
# 73
# 00:02:42,936 --> 00:02:43,412
# JadePixie_7138:
# Mm?
#
# 74
# 00:02:43,412 --> 00:02:45,232
# CS12_4510:
# He had a phone call.
#
# 75
# 00:02:45,232 --> 00:02:45,612
# JadePixie_7138:
# Oh,
#
# 76
# 00:02:45,612 --> 00:02:46,024
# JadePixie_7138:
# well,
#
# 77
# 00:02:46,024 --> 00:02:49,476
# JadePixie_7138:
# Aloe will be like, no, no, I insist Max has it.
#
# 78
# 00:02:50,272 --> 00:02:51,068
# IlMaximuslI_9218:
# Josh,
#
# 79
# 00:02:51,068 --> 00:02:57,368
# IlMaximuslI_9218:
# is there another dead nimblewright or can we remove the one that's currently in uh, Andrea's rooms?
#
# 80
# 00:02:57,368 --> 00:02:58,004
# Crux_4429:
# That's
#
# 81
# 00:02:58,004 --> 00:02:58,992
# IlMaximuslI_9218:
# me.
#
# 82
# 00:02:58,992 --> 00:03:00,332
# IlMaximuslI_9218:
# Please. No, why on the bed?
#
# 83
# 00:03:00,332 --> 00:03:01,288
# IlMaximuslI_9218:
# That's worse.
#
# 84
# 00:03:01,288 --> 00:03:03,684
# Crux_4429:
# Tuck them in, make them comfortable.
#
# 85
# 00:03:03,684 --> 00:03:05,984
# IlMaximuslI_9218:
# I thought it's God! Yeah,
#
# 86
# 00:03:05,984 --> 00:03:07,452
# IlMaximuslI_9218:
# that's what I'm wondering.
#
# 87
# 00:03:07,452 --> 00:03:08,312
# IlMaximuslI_9218:
# Thank you, Bryce.
#
# 88
# 00:03:08,312 --> 00:03:12,052
# Crux_4429:
# I think he went off the phone call.
#
# 89
# 00:03:13,392 --> 00:03:15,692
# IlMaximuslI_9218:
# Probably. So, what are we doing this session, guys?
#
# 90
# 00:03:15,692 --> 00:03:17,384
# JadePixie_7138:
# Uh, maybe we should go
#
# 91
# 00:03:17,384 --> 00:03:19,012
# JadePixie_7138:
# into the water clock, guys.
#
# 92
# 00:03:19,012 --> 00:03:21,504
# JadePixie_7138:
# I don't have any other suggestions, I don't think.
#
# 93
# 00:03:21,504 --> 00:03:25,148
# CS12_4510:
# Probably. I mean, we spend this time, we
#
# 94
# 00:03:25,148 --> 00:03:31,288
# CS12_4510:
# have time pass out of game in order to take care of the abstractions that we're setting up that would be really tedious to go through.
#
# 95
# 00:03:31,288 --> 00:03:33,684
# CS12_4510:
# Such as fake casing out,
#
# 96
# 00:03:33,684 --> 00:03:34,224
# CS12_4510:
# uh,
#
# 97
# 00:03:34,224 --> 00:03:35,020
# CS12_4510:
# the Larren Tower.
#
# 98
# 00:03:35,020 --> 00:03:37,352
# CS12_4510:
# And we do in-game stuff,
#
# 99
# 00:03:37,352 --> 00:03:37,860
# CS12_4510:
# uh,
#
# 100
# 00:03:37,860 --> 00:03:38,848
# CS12_4510:
# when it's interesting,
#
# 101
# 00:03:38,848 --> 00:03:41,404
# CS12_4510:
# such as going to the Water Clock Guild and other
#
# 102
# 00:03:41,404 --> 00:03:43,320
# CS12_4510:
# things.
#
# 103
# 00:03:43,320 --> 00:03:44,052
# JadePixie_7138:
# We
#
# 104
# 00:03:44,052 --> 00:03:44,656
# IlMaximuslI_9218:
# could,
#
# 105
# 00:03:44,656 --> 00:03:46,988
# JadePixie_7138:
# we could also like try to meet,
#
# 106
# 00:03:46,988 --> 00:03:47,304
# JadePixie_7138:
# like
#
# 107
# 00:03:47,304 --> 00:03:48,004
# JadePixie_7138:
# try to
#
# 108
# 00:03:48,004 --> 00:03:55,328
# JadePixie_7138:
# mess with Cass a little bit if you don't know what to do with the water clock. Those are all the suggestions. Stay in your eyes. I don't have any more.
#
# 109
# 00:03:55,328 --> 00:04:02,524
# CS12_4510:
# Okay. Well, we don't really know anything about Cass and we don't really need to look into Cass because
#
# 110
# 00:04:02,524 --> 00:04:05,304
# CS12_4510:
# if we want to look into Cass we should just talk to Mariposa
#
# 111
# 00:04:05,304 --> 00:04:09,908
# CS12_4510:
# and ask if they found anything because they are spending all of their resources looking into Cass.
#
# 112
# 00:04:11,372 --> 00:04:19,240
# IlMaximuslI_9218:
# I believe the current theory is that the historian royal guard or the historian royal family is helping her hide away in some way. At
#
# 113
# 00:04:19,240 --> 00:04:20,804
# IlMaximuslI_9218:
# the very least not trying to find her.
#
# 114
# 00:04:20,804 --> 00:04:23,936
# CS12_4510:
# Yeah, I doubt they're sheltering her.
#
# 115
# 00:04:23,936 --> 00:04:24,348
# CS12_4510:
# Not
#
# 116
# 00:04:24,348 --> 00:04:26,232
# CS12_4510:
# by like taking the investigation and
#
# 117
# 00:04:26,836 --> 00:04:29,680
# CS12_4510:
# willfully flubbing it, I think is likely.
#
# 118
# 00:04:29,680 --> 00:04:30,636
# IlMaximuslI_9218:
# Yeah, either way. I
#
# 119
# 00:04:30,636 --> 00:04:36,552
# IlMaximuslI_9218:
# agree that water clock is probably the most interesting thing, unless we wait an entire day in-game
#
# 120
# 00:04:36,552 --> 00:04:38,916
# IlMaximuslI_9218:
# because I believe, I believe,
#
# 121
# 00:04:38,916 --> 00:04:40,672
# IlMaximuslI_9218:
# tomorrow is Lawrence's birthday?
#
# 122
# 00:04:40,672 --> 00:04:43,452
# CS12_4510:
# You just click on the calendar to find out.
#
# 123
# 00:04:43,452 --> 00:04:44,664
# CS12_4510:
# No.
#
# 124
# 00:04:44,664 --> 00:04:47,220
# CS12_4510:
# My birthday was nine days ago.
#
# 125
# 00:04:47,220 --> 00:04:49,232
# IlMaximuslI_9218:
# 9 days ago? I thought it was the...
#
# 126
# 00:04:49,232 --> 00:04:50,636
# CS12_4510:
# Do you see?
#
# 127
# 00:04:50,636 --> 00:04:51,368
# IlMaximuslI_9218:
# Oh, I thought
#
# 128
# 00:04:51,368 --> 00:04:52,516
# IlMaximuslI_9218:
# it was the 31st.
#
# 129
# 00:04:52,516 --> 00:04:53,408
# CS12_4510:
# No. It
#
# 130
# 00:04:53,408 --> 00:04:54,812
# CS12_4510:
# was the 22nd.
#
# 131
# 00:04:54,812 --> 00:04:55,576
# IlMaximuslI_9218:
# Hmm.
#
# 132
# 00:04:55,576 --> 00:04:59,476
# CS12_4510:
# Or we played card, we played Liar's Dice this day,
#
# 133
# 00:04:59,476 --> 00:05:00,560
# CS12_4510:
# then time passed,
#
# 134
# 00:05:00,560 --> 00:05:02,188
# CS12_4510:
# then we got to dual day,
#
# 135
# 00:05:02,188 --> 00:05:05,448
# CS12_4510:
# then we went to the library, then we came back,
#
# 136
# 00:05:05,448 --> 00:05:07,364
# CS12_4510:
# then our weekend passed and we got paid.
#
# 137
# 00:05:07,364 --> 00:05:08,064
# JadePixie_7138:
# Dang.
#
# 138
# 00:05:08,064 --> 00:05:11,996
# JadePixie_7138:
# I also would have liked to play something out that day.
#
# 139
# 00:05:11,996 --> 00:05:14,840
# CS12_4510:
# Well, you can always just do a late birthday.
#
# 140
# 00:05:14,840 --> 00:05:15,572
# JadePixie_7138:
# Yeah, but...
#
# 141
# 00:05:15,572 --> 00:05:15,920
# CS12_4510:
# Like,
#
# 142
# 00:05:15,920 --> 00:05:18,540
# CS12_4510:
# sorry, but birthday's an illusion.
#
# 143
# 00:05:19,336 --> 00:05:21,956
# CS12_4510:
# We didn't skip over it, like,
#
# 144
# 00:05:21,956 --> 00:05:23,104
# CS12_4510:
# between sessions.
#
# 145
# 00:05:23,104 --> 00:05:24,476
# CS12_4510:
# We just didn't do anything on it.
#
# 146
# 00:05:24,952 --> 00:05:26,708
# JadePixie_7138:
# Okay. It's just,
#
# 147
# 00:05:26,708 --> 00:05:27,472
# JadePixie_7138:
# uh,
#
# 148
# 00:05:27,472 --> 00:05:28,428
# JadePixie_7138:
# well, I don't know.
#
# 149
# 00:05:28,428 --> 00:05:31,624
# CS12_4510:
# Note to self, figure out what Alison's birthday is.
#
# 150
# 00:05:32,292 --> 00:05:34,144
# CS12_4510:
# Curious when Adrian's going to get picked up
#
# 151
# 00:05:34,716 --> 00:05:44,792
# CS12_4510:
# and like, if it's not going to happen this campaign, you can just let us know, Josh, because then I won't constantly wonder and we can just always remember that he is here.
#
# 152
# 00:05:44,792 --> 00:05:47,124
# Marburg42_5566:
# I am so sorry about that. That was my son.
#
# 153
# 00:05:47,124 --> 00:05:48,560
# CS12_4510:
# No problem.
#
# 154
# 00:05:48,560 --> 00:05:49,388
# Marburg42_5566:
# Uh, Colin?
#
# 155
# 00:05:49,388 --> 00:05:50,632
# Crux_4429:
# No worries.
#
# 156
# 00:05:50,632 --> 00:05:52,612
# Marburg42_5566:
# I just missed the last few minutes.
#
# 157
# 00:05:52,612 --> 00:05:56,064
# CS12_4510:
# Uh, we were just fill in get time.
#
# 158
# 00:05:56,064 --> 00:06:03,356
# CS12_4510:
# All that we really said was, um, Sam was under the impression that it was Lawrence's birthday tomorrow.
#
# 159
# 00:06:03,356 --> 00:06:05,464
# Marburg42_5566:
# I thought it was a week ago, like four days.
#
# 160
# 00:06:05,464 --> 00:06:10,996
# CS12_4510:
# It was nine days ago, and I told him as such, and he said, but, but,
#
# 161
# 00:06:11,312 --> 00:06:12,300
# CS12_4510:
# you lie!
#
# 162
# 00:06:12,300 --> 00:06:13,576
# CS12_4510:
# And then we looked at the calendar.
#
# 163
# 00:06:13,576 --> 00:06:14,660
# Marburg42_5566:
# heheheheheheheheheheheheheh
#
# 164
# 00:06:14,660 --> 00:06:22,368
# CS12_4510:
# Ummmm And I said, well don't worry about it Birthdays are an illusion anyway If you wanna do something He intentionally didn't give you very much time in order to...
#
# 165
# 00:06:22,368 --> 00:06:23,836
# Marburg42_5566:
# It's alright
#
# 166
# 00:06:23,836 --> 00:06:27,544
# IlMaximuslI_9218:
# He intentionally chose his birthday to be very much on short notice
#
# 167
# 00:06:27,544 --> 00:06:32,660
# CS12_4510:
# Well I did But I rolled a DE-100 and then I got a 2 which meant it was 2 days
#
# 168
# 00:06:32,660 --> 00:06:33,424
# CS12_4510:
# So yeah
#
# 169
# 00:06:33,424 --> 00:06:36,748
# CS12_4510:
# Not... Sorry, not a DE-100 A DE-10
#
# 170
# 00:06:36,748 --> 00:06:37,192
# CS12_4510:
# Oahhh
#
# 171
# 00:06:37,796 --> 00:06:38,624
# CS12_4510:
# Alright
#
# 172
# 00:06:38,624 --> 00:06:41,180
# CS12_4510:
# Well, what are we doing tonight's D&D?
#
# 173
# 00:06:42,072 --> 00:06:44,788
# IlMaximuslI_9218:
# to the Water Clock Guild to, uh,
#
# 174
# 00:06:44,788 --> 00:06:46,672
# IlMaximuslI_9218:
# figure it all out and
#
# 175
# 00:06:46,672 --> 00:06:47,052
# IlMaximuslI_9218:
# to
#
# 176
# 00:06:47,052 --> 00:06:48,136
# IlMaximuslI_9218:
# closer to the mystery.
#
# 177
# 00:06:48,136 --> 00:06:49,476
# CS12_4510:
# All right. Yeah.
#
# 178
# 00:06:49,476 --> 00:06:53,344
# CS12_4510:
# Uh, is there anything that we needed to talk to, uh,
#
# 179
# 00:06:53,344 --> 00:06:54,012
# CS12_4510:
# are
#
# 180
# 00:06:54,012 --> 00:06:55,096
# CS12_4510:
# the Rose about?
#
# 181
# 00:06:55,508 --> 00:07:02,896
# CS12_4510:
# Black Rose. I feel like there was something I wanted to, but I don't think I wrote it down. So I'm just hoping somebody else can remind me what it was.
#
# 182
# 00:07:02,896 --> 00:07:08,076
# IlMaximuslI_9218:
# Well, we could say, well, we're there. Offices with Andrea asks her question while you ruminate on that.
#
# 183
# 00:07:08,076 --> 00:07:09,160
# CS12_4510:
# Sure, sure, sure.
#
# 184
# 00:07:09,700 --> 00:07:17,152
# IlMaximuslI_9218:
# Book comes out. uh she flips over a few pages and we'll go all right uh today's question is
#
# 185
# 00:07:17,152 --> 00:07:17,788
# IlMaximuslI_9218:
# do do do uh
#
# 186
# 00:07:17,788 --> 00:07:19,864
# IlMaximuslI_9218:
# can you tell when someone is flirting with you
#
# 187
# 00:07:19,864 --> 00:07:21,140
# CS12_4510:
# yes
#
# 188
# 00:07:21,140 --> 00:07:21,776
# JadePixie_7138:
# yes
#
# 189
# 00:07:21,776 --> 00:07:23,404
# Marburg42_5566:
# i mean it's pretty much all the time
#
# 190
# 00:07:23,752 --> 00:07:28,356
# CS12_4510:
# i look at andrea and shake my head slightly at his answer
#
# 191
# 00:07:28,832 --> 00:07:30,716
# IlMaximuslI_9218:
# she puts that one down like why
#
# 192
# 00:07:30,716 --> 00:07:32,408
# Marburg42_5566:
# do you have issues with that andrea
#
# 193
# 00:07:32,408 --> 00:07:35,252
# IlMaximuslI_9218:
# no no i appreciate that you are used
#
# 194
# 00:07:35,252 --> 00:07:38,000
# IlMaximuslI_9218:
# more than just simply saying yes in your answer
#
# 195
# 00:07:38,000 --> 00:07:40,044
# IlMaximuslI_9218:
# helps fill in the character a bit more I think.
#
# 196
# 00:07:40,044 --> 00:07:42,344
# Marburg42_5566:
# He kinda looks confused like what? Yeah
#
# 197
# 00:07:42,660 --> 00:07:43,264
# Marburg42_5566:
# happy to help.
#
# 198
# 00:07:43,264 --> 00:07:44,700
# CS12_4510:
# Yourself Andrea?
#
# 199
# 00:07:44,700 --> 00:07:45,560
# IlMaximuslI_9218:
# Hope I could. Um,
#
# 200
# 00:07:45,560 --> 00:07:46,196
# IlMaximuslI_9218:
# it's
#
# 201
# 00:07:46,196 --> 00:07:46,672
# IlMaximuslI_9218:
# all good.
#
# 202
# 00:07:46,672 --> 00:07:54,284
# CS12_4510:
# How about you, Estelle? Why? Why have we been clicking the serpentine token?
#
# 203
# 00:07:54,284 --> 00:07:55,528
# IlMaximuslI_9218:
# I'll go with it probably.
#
# 204
# 00:07:55,528 --> 00:07:57,700
# Marburg42_5566:
# Why am I clicking this? Yeah I was just reading it.
#
# 205
# 00:07:57,700 --> 00:07:58,400
# Marburg42_5566:
# Sorry about that.
#
# 206
# 00:08:00,728 --> 00:08:03,892
# Marburg42_5566:
# I didn't realize it showed up in there three times. It's
#
# 207
# 00:08:04,464 --> 00:08:04,972
# Marburg42_5566:
# okay,
#
# 208
# 00:08:04,972 --> 00:08:05,992
# Crux_4429:
# I can save us. I only
#
# 209
# 00:08:05,992 --> 00:08:06,916
# Crux_4429:
# did it the ones.
#
# 210
# 00:08:06,916 --> 00:08:07,584
# Marburg42_5566:
# Appreciate that.
#
# 211
# 00:08:07,584 --> 00:08:10,012
# IlMaximuslI_9218:
# What's the Rose's answer since we're here?
#
# 212
# 00:08:10,012 --> 00:08:13,112
# CS12_4510:
# No, we didn't ask the Rose, we asked Estelle, the Viper.
#
# 213
# 00:08:13,112 --> 00:08:13,812
# IlMaximuslI_9218:
# Dang it.
#
# 214
# 00:08:13,812 --> 00:08:15,952
# IlMaximuslI_9218:
# Oh, Estelle, yes.
#
# 215
# 00:08:15,952 --> 00:08:16,716
# Crux_4429:
# Mmm. Does
#
# 216
# 00:08:16,716 --> 00:08:18,056
# IlMaximuslI_9218:
# she have answers?
#
# 217
# 00:08:18,056 --> 00:08:20,804
# Crux_4429:
# What's the context of Estelle being here?
#
# 218
# 00:08:20,804 --> 00:08:24,160
# CS12_4510:
# We are like, we're at
#
# 219
# 00:08:24,160 --> 00:08:31,196
# CS12_4510:
# the, uh, we're taking a mid-thieving, like, lunch break. We just brought out the sandwiches and the picnic basket.
#
# 220
# 00:08:31,196 --> 00:08:40,792
# CS12_4510:
# Uh, the jellies come out, uh, Andrea takes this opportunity in order to pull, ask a question from her book. So she asks, can you tell if people are flirting with you?
#
# 221
# 00:08:40,792 --> 00:08:42,740
# CS12_4510:
# And then everybody here answers.
#
# 222
# 00:08:43,280 --> 00:08:47,532
# CS12_4510:
# And then I say, I suppose we say, so what about you, Estelle?
#
# 223
# 00:08:47,848 --> 00:08:50,180
# CS12_4510:
# Or I know I say, and you, Estelle?
#
# 224
# 00:08:50,180 --> 00:08:54,784
# IlMaximuslI_9218:
# And as soon as Lawrence says that, she makes a new note for Estelle's log.
#
# 225
# 00:08:54,784 --> 00:08:55,804
# IlMaximuslI_9218:
# Like, okay, yeah, I'm ready.
#
# 226
# 00:08:55,804 --> 00:08:56,792
# IlMaximuslI_9218:
# Like, looks.
#
# 227
# 00:08:56,792 --> 00:08:57,748
# Crux_4429:
# He
#
# 228
# 00:08:57,748 --> 00:08:59,024
# Crux_4429:
# cautiously
#
# 229
# 00:08:59,024 --> 00:09:00,300
# Crux_4429:
# stops chewing,
#
# 230
# 00:09:00,300 --> 00:09:01,352
# Crux_4429:
# swallows,
#
# 231
# 00:09:01,352 --> 00:09:01,892
# Crux_4429:
# and says, no?
#
# 232
# 00:09:02,720 --> 00:09:04,380
# CS12_4510:
# Right!
#
# 233
# 00:09:04,380 --> 00:09:06,552
# CS12_4510:
# You handled that nicely.
#
# 234
# 00:09:06,552 --> 00:09:16,884
# CS12_4510:
# I was actually trying to get you to tell her that this question was ridiculous and kind of out of the blue considering our current Vairon, but you
#
# 235
# 00:09:16,884 --> 00:09:17,232
# CS12_4510:
# know,
#
# 236
# 00:09:17,232 --> 00:09:19,308
# CS12_4510:
# good on you. Proving me wrong.
#
# 237
# 00:09:19,976 --> 00:09:22,116
# Crux_4429:
# I thought this was her attempt to fight with all of you.
#
# 238
# 00:09:22,116 --> 00:09:24,192
# CS12_4510:
# No, she just
#
# 239
# 00:09:24,192 --> 00:09:26,908
# CS12_4510:
# take a peek at her book sometime and see something odd.
#
# 240
# 00:09:27,892 --> 00:09:28,528
# IlMaximuslI_9218:
# Or you know,
#
# 241
# 00:09:28,528 --> 00:09:29,068
# IlMaximuslI_9218:
# don't.
#
# 242
# 00:09:29,068 --> 00:09:30,792
# IlMaximuslI_9218:
# She like puts the book away quickly and-
#
# 243
# 00:09:30,792 --> 00:09:35,236
# CS12_4510:
# your out of the blue questions I could recite.
#
# 244
# 00:09:35,236 --> 00:09:36,416
# IlMaximuslI_9218:
# It's good for getting
#
# 245
# 00:09:36,416 --> 00:09:37,372
# IlMaximuslI_9218:
# to know each other.
#
# 246
# 00:09:37,372 --> 00:09:41,752
# CS12_4510:
# Yeah, don't worry, I won't ask you where your first kiss was.
#
# 247
# 00:09:41,752 --> 00:09:44,308
# Marburg42_5566:
# I think we know each other just fine, it's really been great.
#
# 248
# 00:09:44,308 --> 00:09:45,136
# IlMaximuslI_9218:
# She like,
#
# 249
# 00:09:45,136 --> 00:09:47,468
# IlMaximuslI_9218:
# does like a aha type of face.
#
# 250
# 00:09:47,912 --> 00:09:50,372
# CS12_4510:
# Right, well.
#
# 251
# 00:09:50,372 --> 00:09:52,416
# IlMaximuslI_9218:
# Well anyway, thank you for your answers though.
#
# 252
# 00:09:52,416 --> 00:09:54,876
# Crux_4429:
# Besides, goes back to eating your sandwich.
#
# 253
# 00:09:55,192 --> 00:09:59,764
# CS12_4510:
# She should be glad that I'm not like my sister. I would have just flavored her sandwich.
#
# 254
# 00:10:03,300 --> 00:10:05,376
# Crux_4429:
# Alright, so, mid
#
# 255
# 00:10:05,376 --> 00:10:05,948
# Crux_4429:
# thieving.
#
# 256
# 00:10:05,948 --> 00:10:06,296
# Crux_4429:
# We're
#
# 257
# 00:10:06,296 --> 00:10:06,740
# Crux_4429:
# just...
#
# 258
# 00:10:06,740 --> 00:10:09,776
# CS12_4510:
# I mean,
#
# 259
# 00:10:09,776 --> 00:10:13,932
# CS12_4510:
# we're looking at the water clock, we're here.
#
# 260
# 00:10:13,932 --> 00:10:15,880
# CS12_4510:
# Hello. Looking on our stuff.
#
# 261
# 00:10:16,292 --> 00:10:17,216
# CS12_4510:
# Okay.
#
# 262
# 00:10:17,216 --> 00:10:18,364
# Crux_4429:
# Alright, let's get a recap. Yeah,
#
# 263
# 00:10:18,364 --> 00:10:19,960
# CS12_4510:
# let's talk about... Ugh, go
#
# 264
# 00:10:19,960 --> 00:10:20,756
# Crux_4429:
# ahead. No, you go.
#
# 265
# 00:10:20,756 --> 00:10:22,320
# CS12_4510:
# No, you go.
#
# 266
# 00:10:23,340 --> 00:10:31,112
# CS12_4510:
# Now, let's figure out how we are going to either move the statue, we're going to divide it into two teams. One,
#
# 267
# 00:10:31,112 --> 00:10:34,692
# CS12_4510:
# move the statue team. Two,
#
# 268
# 00:10:34,692 --> 00:10:35,296
# CS12_4510:
# team,
#
# 269
# 00:10:35,296 --> 00:10:39,708
# CS12_4510:
# figure out how in the world Max got into the other place.
#
# 270
# 00:10:39,708 --> 00:10:41,944
# Marburg42_5566:
# Well, I just walked through the wall.
#
# 271
# 00:10:41,944 --> 00:10:47,988
# CS12_4510:
# Yep, yep. And I would recommend you try to do that again. Here's some candle, here's some ceiling wax.
#
# 272
# 00:10:47,988 --> 00:10:48,560
# Marburg42_5566:
# Uh,
#
# 273
# 00:10:48,560 --> 00:10:50,284
# Marburg42_5566:
# so I can make an etching.
#
# 274
# 00:10:50,284 --> 00:10:51,144
# CS12_4510:
# Yep.
#
# 275
# 00:10:51,144 --> 00:10:52,100
# Crux_4429:
# So you can make a what?
#
# 276
# 00:10:52,100 --> 00:10:53,024
# Marburg42_5566:
# An etching.
#
# 277
# 00:10:53,024 --> 00:10:54,044
# IlMaximuslI_9218:
# Try and do
#
# 278
# 00:10:54,044 --> 00:10:56,120
# IlMaximuslI_9218:
# everything the same that you did last time
#
# 279
# 00:10:56,120 --> 00:10:56,820
# IlMaximuslI_9218:
# and then
#
# 280
# 00:10:56,820 --> 00:11:01,648
# IlMaximuslI_9218:
# we can start to know, you know If there's certain steps they need to take to it or whatever else
#
# 281
# 00:11:01,648 --> 00:11:02,380
# CS12_4510:
# We
#
# 282
# 00:11:02,380 --> 00:11:03,112
# IlMaximuslI_9218:
# got this
#
# 283
# 00:11:03,112 --> 00:11:06,980
# CS12_4510:
# potentially save some time. You can do this at will right? How about you just
#
# 284
# 00:11:06,980 --> 00:11:09,728
# CS12_4510:
# do what you think you need to do and then we can do
#
# 285
# 00:11:09,728 --> 00:11:11,228
# CS12_4510:
# everything
#
# 286
# 00:11:11,228 --> 00:11:11,768
# IlMaximuslI_9218:
# Sure
#
# 287
# 00:11:11,768 --> 00:11:12,788
# IlMaximuslI_9218:
# max if you would
#
# 288
# 00:11:12,788 --> 00:11:13,744
# Marburg42_5566:
# sure
#
# 289
# 00:11:13,744 --> 00:11:16,780
# Marburg42_5566:
# He's you're I'm gonna walk through the
#
# 290
# 00:11:16,780 --> 00:11:17,640
# Marburg42_5566:
# pass wall
#
# 291
# 00:11:17,640 --> 00:11:18,468
# Marburg42_5566:
# with the
#
# 292
# 00:11:18,468 --> 00:11:18,944
# Marburg42_5566:
# etching
#
# 293
# 00:11:18,944 --> 00:11:19,804
# Crux_4429:
# Alright.
#
# 294
# 00:11:20,312 --> 00:11:22,868
# CS12_4510:
# Passwall is a melding to stone, but yeah.
#
# 295
# 00:11:22,868 --> 00:11:26,416
# Marburg42_5566:
# Yeah, I was sorry, melding to stone. Passwall is even better. That could get us all through. Passwall
#
# 296
# 00:11:26,416 --> 00:11:29,516
# CS12_4510:
# is a great spell. But, it's a great spell. I can't wait.
#
# 297
# 00:11:29,516 --> 00:11:30,088
# Marburg42_5566:
# Be level
#
# 298
# 00:11:30,088 --> 00:11:30,916
# Marburg42_5566:
# mind. Alright, so you step
#
# 299
# 00:11:30,916 --> 00:11:31,584
# Marburg42_5566:
# through into
#
# 300
# 00:11:31,584 --> 00:11:34,300
# CS12_4510:
# the tombs.
#
# 301
# 00:11:38,928 --> 00:11:40,556
# Crux_4429:
# Bind yourself in darkness. Some
#
# 302
# 00:11:40,556 --> 00:11:41,384
# Crux_4429:
# steps.
#
# 303
# 00:11:41,384 --> 00:11:43,396
# CS12_4510:
# Wanna show the tombs again?
#
# 304
# 00:11:43,396 --> 00:11:44,096
# Crux_4429:
# Turn around.
#
# 305
# 00:11:44,096 --> 00:11:44,828
# Marburg42_5566:
# Yeah,
#
# 306
# 00:11:44,828 --> 00:11:45,208
# Marburg42_5566:
# yeah.
#
# 307
# 00:11:45,208 --> 00:11:48,532
# Crux_4429:
# Alright, you turn around, cast, uh, Melodin to Stone again, and
#
# 308
# 00:11:48,532 --> 00:11:50,224
# Crux_4429:
# emerge, uh, on the other
#
# 309
# 00:11:50,224 --> 00:11:51,692
# Crux_4429:
# side,
#
# 310
# 00:11:51,692 --> 00:11:53,032
# Crux_4429:
# face to face with your friends.
#
# 311
# 00:11:53,032 --> 00:11:55,908
# Marburg42_5566:
# I thought there was a, wasn't there a statue I was supposed to take an etching
#
# 312
# 00:11:55,908 --> 00:11:56,864
# Marburg42_5566:
# from the, uh,
#
# 313
# 00:11:56,864 --> 00:11:58,108
# Marburg42_5566:
# on the inside of the...
#
# 314
# 00:11:58,108 --> 00:12:00,024
# CS12_4510:
# Yeah, but it's in the other place.
#
# 315
# 00:12:00,024 --> 00:12:00,372
# Marburg42_5566:
# Right.
#
# 316
# 00:12:00,372 --> 00:12:02,640
# CS12_4510:
# In place of this statue
#
# 317
# 00:12:02,640 --> 00:12:04,044
# CS12_4510:
# in the other place.
#
# 318
# 00:12:04,044 --> 00:12:05,128
# Marburg42_5566:
# Over in there, right?
#
# 319
# 00:12:05,860 --> 00:12:06,976
# Marburg42_5566:
# No. I have it all
#
# 320
# 00:12:06,976 --> 00:12:07,612
# CS12_4510:
# backwards.
#
# 321
# 00:12:07,612 --> 00:12:08,504
# Marburg42_5566:
# Here.
#
# 322
# 00:12:08,504 --> 00:12:10,708
# IlMaximuslI_9218:
# Ah, okay. Oh, Max, you're back already! Um,
#
# 323
# 00:12:10,708 --> 00:12:11,152
# IlMaximuslI_9218:
# and...
#
# 324
# 00:12:11,152 --> 00:12:13,068
# CS12_4510:
# So that didn't work, I take it?
#
# 325
# 00:12:13,544 --> 00:12:23,588
# CS12_4510:
# Oh, I start investigating bottom of this, looking for mechanisms, yada yada yada on the statue. We're... Focus on Max, please. Did
#
# 326
# 00:12:23,588 --> 00:12:25,536
# IlMaximuslI_9218:
# you do everything the exact same
#
# 327
# 00:12:25,536 --> 00:12:26,076
# IlMaximuslI_9218:
# as last time?
#
# 328
# 00:12:26,076 --> 00:12:26,808
# IlMaximuslI_9218:
# Like, was it
#
# 329
# 00:12:26,808 --> 00:12:30,196
# IlMaximuslI_9218:
# out of there that you tried to get out? Is that the other sealed door?
#
# 330
# 00:12:30,196 --> 00:12:31,472
# Marburg42_5566:
# I thought it was here. Where
#
# 331
# 00:12:31,472 --> 00:12:35,884
# Marburg42_5566:
# was the, uh, cause I'm looking for the, uh, the spot with the sarcophagus.
#
# 332
# 00:12:35,884 --> 00:12:36,936
# Marburg42_5566:
# Wasn't that through this wall?
#
# 333
# 00:12:36,936 --> 00:12:37,508
# Crux_4429:
# Yes.
#
# 334
# 00:12:37,508 --> 00:12:46,944
# CS12_4510:
# Yes. But the thing that we wanted to take you a waxed cast of was after you left the sarcophagus area, you were in this new area, but it was different.
#
# 335
# 00:12:46,944 --> 00:12:47,676
# Marburg42_5566:
# Oh right, but
#
# 336
# 00:12:47,676 --> 00:12:49,624
# Marburg42_5566:
# it was a new... right, right.
#
# 337
# 00:12:49,624 --> 00:12:50,932
# Marburg42_5566:
# So I come back through... hmm.
#
# 338
# 00:12:51,408 --> 00:12:54,796
# CS12_4510:
# Yep, so it wasn't simple. Now you just have to retrace
#
# 339
# 00:12:54,796 --> 00:12:56,648
# CS12_4510:
# all of your steps. Do you want me to walk with you?
#
# 340
# 00:12:56,648 --> 00:12:58,340
# Marburg42_5566:
# So I have to do everything the same.
#
# 341
# 00:12:58,340 --> 00:12:58,816
# Marburg42_5566:
# Because I
#
# 342
# 00:12:58,816 --> 00:13:00,476
# Marburg42_5566:
# didn't want to tell you guys, but I...
#
# 343
# 00:13:00,476 --> 00:13:04,568
# Marburg42_5566:
# there's a... there's sarcophagus in there, and there was a watch, and I touched it. Tell
#
# 344
# 00:13:04,568 --> 00:13:05,940
# CS12_4510:
# us about that.
#
# 345
# 00:13:05,940 --> 00:13:06,384
# Crux_4429:
# You did...
#
# 346
# 00:13:06,384 --> 00:13:07,660
# Crux_4429:
# you did tell us about that.
#
# 347
# 00:13:07,660 --> 00:13:09,192
# Marburg42_5566:
# Okay, I'll go back through.
#
# 348
# 00:13:09,192 --> 00:13:11,172
# Marburg42_5566:
# So I'll pass through, and then seeing this...
#
# 349
# 00:13:11,172 --> 00:13:13,792
# CS12_4510:
# You want me to come with you?
#
# 350
# 00:13:13,792 --> 00:13:14,300
# Marburg42_5566:
# It's just
#
# 351
# 00:13:14,300 --> 00:13:15,096
# Marburg42_5566:
# he's already gone.
#
# 352
# 00:13:15,096 --> 00:13:16,596
# Marburg42_5566:
# Is this
#
# 353
# 00:13:16,596 --> 00:13:18,224
# Marburg42_5566:
# is this sarcophagus there again?
#
# 354
# 00:13:18,224 --> 00:13:18,860
# Marburg42_5566:
# It's still there?
#
# 355
# 00:13:18,860 --> 00:13:21,128
# Crux_4429:
# Yeah, you're in darkness.
#
# 356
# 00:13:21,128 --> 00:13:23,396
# Marburg42_5566:
# Oh, I need to... And I'm blind. I'll
#
# 357
# 00:13:23,396 --> 00:13:24,800
# Marburg42_5566:
# do something about that one day.
#
# 358
# 00:13:25,244 --> 00:13:28,696
# Marburg42_5566:
# All right, I will... I'll have to light my lamp
#
# 359
# 00:13:28,696 --> 00:13:30,932
# Marburg42_5566:
# and I'll just... I'll place it on the floor
#
# 360
# 00:13:30,932 --> 00:13:31,376
# Marburg42_5566:
# here
#
# 361
# 00:13:31,376 --> 00:13:33,868
# Marburg42_5566:
# so it illuminates the room, but it's not in my hands.
#
# 362
# 00:13:36,456 --> 00:13:39,012
# Marburg42_5566:
# And then I want to cast a
#
# 363
# 00:13:39,012 --> 00:13:43,456
# Marburg42_5566:
# detect magic again and make sure I can see the zapago watch still in
#
# 364
# 00:13:43,456 --> 00:13:44,124
# Marburg42_5566:
# where I left it?
#
# 365
# 00:13:44,124 --> 00:13:45,048
# Crux_4429:
# Yeah, it's still
#
# 366
# 00:13:45,048 --> 00:13:46,260
# Crux_4429:
# detectable.
#
# 367
# 00:13:46,260 --> 00:13:46,640
# Marburg42_5566:
# OK.
#
# 368
# 00:13:46,640 --> 00:13:48,268
# Marburg42_5566:
# And I will
#
# 369
# 00:13:48,268 --> 00:13:49,352
# Marburg42_5566:
# cast the
#
# 370
# 00:13:49,352 --> 00:13:53,380
# Marburg42_5566:
# Melu stone again to get through the sarcophagus and pick up the
#
# 371
# 00:13:53,380 --> 00:13:54,112
# Marburg42_5566:
# the.
#
# 372
# 00:13:54,112 --> 00:14:05,660
# CS12_4510:
# We'll remind you, because I know there was a confusion about this last time, and I think it's likely that you forgot in the correction. This is in a normal, small, normal humanoid sized
#
# 373
# 00:14:05,660 --> 00:14:06,168
# Crux_4429:
# zapago
#
# 374
# 00:14:06,168 --> 00:14:06,836
# Marburg42_5566:
# watch
#
# 375
# 00:14:06,836 --> 00:14:07,248
# CS12_4510:
# coffin
#
# 376
# 00:14:07,248 --> 00:14:11,372
# CS12_4510:
# that you shuffle in, then fish back in his pocket.
#
# 377
# 00:14:11,372 --> 00:14:11,912
# Marburg42_5566:
# Right.
#
# 378
# 00:14:11,912 --> 00:14:13,188
# CS12_4510:
# Pull out his pocket watch.
#
# 379
# 00:14:13,568 --> 00:14:14,332
# Crux_4429:
# Yep.
#
# 380
# 00:14:14,332 --> 00:14:15,000
# CS12_4510:
# And then you do what?
#
# 381
# 00:14:15,000 --> 00:14:16,180
# CS12_4510:
# Josh, we cannot see the red.
#
# 382
# 00:14:16,180 --> 00:14:16,592
# Crux_4429:
# Oh,
#
# 383
# 00:14:16,592 --> 00:14:16,972
# Crux_4429:
# thank you.
#
# 384
# 00:14:17,384 --> 00:14:17,956
# Crux_4429:
# Do you, uh,
#
# 385
# 00:14:17,956 --> 00:14:20,320
# Crux_4429:
# you just cuddle up with a corpse real quick.
#
# 386
# 00:14:20,320 --> 00:14:20,956
# Marburg42_5566:
# Yes.
#
# 387
# 00:14:20,956 --> 00:14:22,904
# Crux_4429:
# Um, you find yourself in darkness,
#
# 388
# 00:14:22,904 --> 00:14:26,676
# Crux_4429:
# but you can feel around. You can still, you still have detect magic up.
#
# 389
# 00:14:26,676 --> 00:14:27,216
# Crux_4429:
# Um,
#
# 390
# 00:14:27,216 --> 00:14:31,404
# Crux_4429:
# so you can feel around and get the, uh, the pocket watch into your hand.
#
# 391
# 00:14:31,404 --> 00:14:32,264
# Crux_4429:
# What do you do from here?
#
# 392
# 00:14:32,264 --> 00:14:35,524
# Marburg42_5566:
# Uh, so I will have the, the pocket watch in my hand. And this time I'm going
#
# 393
# 00:14:35,524 --> 00:14:37,728
# Marburg42_5566:
# to leave my lantern here. It's my only lantern.
#
# 394
# 00:14:37,728 --> 00:14:42,332
# Marburg42_5566:
# No, we're going to pick up the, I'll pick up the lantern. And this time I'll be, I'll open the, I
#
# 395
# 00:14:42,332 --> 00:14:44,952
# Marburg42_5566:
# think last time I opened the pocket watch to investigate it.
#
# 396
# 00:14:44,952 --> 00:14:45,908
# Marburg42_5566:
# And
#
# 397
# 00:14:45,908 --> 00:14:46,672
# Marburg42_5566:
# when
#
# 398
# 00:14:46,672 --> 00:14:48,620
# Marburg42_5566:
# I open the pocket watch, does it do anything?
#
# 399
# 00:14:48,620 --> 00:14:50,600
# Crux_4429:
# So you have light in here now?
#
# 400
# 00:14:50,600 --> 00:14:52,292
# Marburg42_5566:
# It's, yeah, it's on the floor.
#
# 401
# 00:14:52,292 --> 00:14:52,640
# Crux_4429:
# Okay,
#
# 402
# 00:14:52,640 --> 00:14:55,132
# Crux_4429:
# so last time when you looked at this pocket watch,
#
# 403
# 00:14:55,132 --> 00:14:56,440
# Crux_4429:
# it still had water in it
#
# 404
# 00:14:56,440 --> 00:14:57,588
# Crux_4429:
# and it was ticking away.
#
# 405
# 00:14:57,588 --> 00:14:59,184
# Crux_4429:
# You click open
#
# 406
# 00:15:00,428 --> 00:15:01,128
# Crux_4429:
# the face,
#
# 407
# 00:15:01,128 --> 00:15:08,036
# Crux_4429:
# and when you pushed that button last time, there was a pulse of transmutation magic. But this time it's empty, the watch is stopped, and there's no pulse of magic.
#
# 408
# 00:15:08,036 --> 00:15:08,864
# Marburg42_5566:
# Oh shit.
#
# 409
# 00:15:08,864 --> 00:15:09,564
# Marburg42_5566:
# And then I'll
#
# 410
# 00:15:09,564 --> 00:15:10,744
# Marburg42_5566:
# meld with stone.
#
# 411
# 00:15:10,744 --> 00:15:15,380
# Marburg42_5566:
# Other than taking the lantern with me, I'll meld with stone with the pocket watch in my hand and return to
#
# 412
# 00:15:15,380 --> 00:15:16,496
# Marburg42_5566:
# what I think will be my
#
# 413
# 00:15:16,496 --> 00:15:17,228
# Marburg42_5566:
# group of friends.
#
# 414
# 00:15:17,228 --> 00:15:17,576
# Crux_4429:
# Okay.
#
# 415
# 00:15:17,576 --> 00:15:19,012
# Crux_4429:
# You return to your group of friends
#
# 416
# 00:15:19,012 --> 00:15:20,256
# Crux_4429:
# with pocket watch in hand.
#
# 417
# 00:15:20,256 --> 00:15:21,372
# Marburg42_5566:
# Yeah. I... it...
#
# 418
# 00:15:22,068 --> 00:15:23,824
# Marburg42_5566:
# I kinda hold the pocket watch out.
#
# 419
# 00:15:23,824 --> 00:15:24,332
# Marburg42_5566:
# Like, it...
#
# 420
# 00:15:24,332 --> 00:15:26,344
# Marburg42_5566:
# it didn't do it this time.
#
# 421
# 00:15:26,344 --> 00:15:31,492
# CS12_4510:
# Okay. Um... what... what do you mean it didn't do it?
#
# 422
# 00:15:31,492 --> 00:15:33,792
# CS12_4510:
# It did something last time?
#
# 423
# 00:15:33,792 --> 00:15:34,492
# Marburg42_5566:
# The, uh...
#
# 424
# 00:15:34,492 --> 00:15:36,472
# Marburg42_5566:
# ah, it went blooosh.
#
# 425
# 00:15:36,472 --> 00:15:37,332
# Marburg42_5566:
# I kinda...
#
# 426
# 00:15:37,332 --> 00:15:39,120
# Marburg42_5566:
# I opened it and it...
#
# 427
# 00:15:39,120 --> 00:15:39,884
# CS12_4510:
# it...
#
# 428
# 00:15:39,884 --> 00:15:40,200
# Marburg42_5566:
# it
#
# 429
# 00:15:40,200 --> 00:15:42,788
# Marburg42_5566:
# pulsed. And then I got... then I put it back down.
#
# 430
# 00:15:42,788 --> 00:15:47,040
# CS12_4510:
# You did... oh. I just pinched my nose. I just pinched...
#
# 431
# 00:15:47,040 --> 00:15:48,220
# IlMaximuslI_9218:
# It pulsed?
#
# 432
# 00:15:48,220 --> 00:15:49,752
# CS12_4510:
# Hi. Um...
#
# 433
# 00:15:49,752 --> 00:15:50,868
# Marburg42_5566:
# Sorry, I forgot that part.
#
# 434
# 00:15:50,868 --> 00:15:57,488
# CS12_4510:
# No, that's okay, because you remembered this time. All we needed to do was figure it out.
#
# 435
# 00:15:57,488 --> 00:15:59,724
# CS12_4510:
# Um... it didn't do that this time?
#
# 436
# 00:15:59,724 --> 00:16:04,328
# Marburg42_5566:
# No, it just opened and... and... it still looks like it's magic, but it
#
# 437
# 00:16:04,328 --> 00:16:05,700
# Marburg42_5566:
# didn't do what it did before.
#
# 438
# 00:16:05,700 --> 00:16:10,240
# CS12_4510:
# Okay, well hopefully it's not one-time use.
#
# 439
# 00:16:10,240 --> 00:16:11,804
# JadePixie_7138:
# Can
#
# 440
# 00:16:11,804 --> 00:16:16,312
# JadePixie_7138:
# you describe exactly how it is different now than it was
#
# 441
# 00:16:16,312 --> 00:16:16,820
# JadePixie_7138:
# before?
#
# 442
# 00:16:16,820 --> 00:16:18,896
# Marburg42_5566:
# When I opened it before, it
#
# 443
# 00:16:18,896 --> 00:16:21,996
# Marburg42_5566:
# let out a pulse of transmutation magic. I could see it.
#
# 444
# 00:16:21,996 --> 00:16:22,440
# Marburg42_5566:
# I was-
#
# 445
# 00:16:22,440 --> 00:16:23,940
# Marburg42_5566:
# I could detect it.
#
# 446
# 00:16:23,940 --> 00:16:26,656
# Marburg42_5566:
# That's what made me nervous, and I put it back into
#
# 447
# 00:16:26,656 --> 00:16:27,644
# Marburg42_5566:
# where it was from.
#
# 448
# 00:16:27,644 --> 00:16:35,064
# CS12_4510:
# That happened just when you touched it before? I've like placed my handkerchief- Okay, I've like placed my handkerchief across my hand and I reach out.
#
# 449
# 00:16:35,064 --> 00:16:36,148
# Marburg42_5566:
# when I opened it.
#
# 450
# 00:16:36,148 --> 00:16:38,544
# CS12_4510:
# With the hand placed the pocket watch?
#
# 451
# 00:16:38,544 --> 00:16:40,876
# IlMaximuslI_9218:
# Is that the only pocket watch in there?
#
# 452
# 00:16:40,876 --> 00:16:41,736
# IlMaximuslI_9218:
# Are there others?
#
# 453
# 00:16:41,736 --> 00:16:44,068
# Marburg42_5566:
# When I looked around, that was the only
#
# 454
# 00:16:44,068 --> 00:16:45,280
# Marburg42_5566:
# source of magic I saw.
#
# 455
# 00:16:45,280 --> 00:16:47,964
# Marburg42_5566:
# Right? I didn't see any other sources.
#
# 456
# 00:16:47,964 --> 00:16:48,344
# Crux_4429:
# Right.
#
# 457
# 00:16:48,948 --> 00:16:52,976
# CS12_4510:
# Well, may I?
#
# 458
# 00:16:52,976 --> 00:16:54,412
# Marburg42_5566:
# The hands of the pocket watch owner.
#
# 459
# 00:16:54,412 --> 00:17:01,832
# CS12_4510:
# I do not make physical contact with it. And I do a little bit of a rudimentary investigation,
#
# 460
# 00:17:01,832 --> 00:17:03,364
# CS12_4510:
# followed by, uh,
#
# 461
# 00:17:04,416 --> 00:17:06,556
# CS12_4510:
# like casting identify.
#
# 462
# 00:17:06,556 --> 00:17:09,688
# JadePixie_7138:
# I'm looking over your shoulder as well. I'm just like
#
# 463
# 00:17:09,688 --> 00:17:12,820
# JadePixie_7138:
# looking at the watch and just making sure that it's, uh,
#
# 464
# 00:17:12,820 --> 00:17:13,584
# JadePixie_7138:
# working.
#
# 465
# 00:17:13,584 --> 00:17:18,540
# CS12_4510:
# I think we'll clump back behind the staircase. Cause it's fairly close to the exit while also, um,
#
# 466
# 00:17:18,540 --> 00:17:21,864
# CS12_4510:
# being shielded from prying eyes from above.
#
# 467
# 00:17:21,864 --> 00:17:22,372
# Crux_4429:
# All right.
#
# 468
# 00:17:22,372 --> 00:17:24,032
# Crux_4429:
# Go ahead. And
#
# 469
# 00:17:24,032 --> 00:17:25,564
# Crux_4429:
# well, it's a ritual spell, isn't it?
#
# 470
# 00:17:25,564 --> 00:17:26,072
# Crux_4429:
# Identify.
#
# 471
# 00:17:26,072 --> 00:17:29,844
# CS12_4510:
# Otherwise I would expend it. Yeah. Let me, sure I can click it.
#
# 472
# 00:17:29,844 --> 00:17:30,192
# Crux_4429:
# Yeah.
#
# 473
# 00:17:30,192 --> 00:17:30,636
# Crux_4429:
# Um, you
#
# 474
# 00:17:30,636 --> 00:17:31,240
# Crux_4429:
# don't need to.
#
# 475
# 00:17:31,240 --> 00:17:34,468
# Crux_4429:
# I was like, hey, spell slots, but then I was like, oh, wait, you don't need to.
#
# 476
# 00:17:34,944 --> 00:17:35,484
# Crux_4429:
# So
#
# 477
# 00:17:35,484 --> 00:17:36,152
# Crux_4429:
# this
#
# 478
# 00:17:36,152 --> 00:17:38,804
# Crux_4429:
# is an intricate pocket watch made of brass and glass.
#
# 479
# 00:17:38,804 --> 00:17:40,464
# Crux_4429:
# It's powered
#
# 480
# 00:17:40,464 --> 00:17:42,284
# Crux_4429:
# by a small vial of water
#
# 481
# 00:17:42,284 --> 00:17:43,816
# Crux_4429:
# that is currently empty.
#
# 482
# 00:17:43,816 --> 00:17:45,220
# Crux_4429:
# And it is,
#
# 483
# 00:17:45,220 --> 00:17:47,072
# Crux_4429:
# because of the empty water, the
#
# 484
# 00:17:47,580 --> 00:17:48,536
# Crux_4429:
# timekeeping
#
# 485
# 00:17:48,536 --> 00:17:50,100
# Crux_4429:
# portion of it is not operating.
#
# 486
# 00:17:50,512 --> 00:17:54,220
# Crux_4429:
# There are magnetic load stones that hold the face cover in place.
#
# 487
# 00:17:54,220 --> 00:17:54,760
# Crux_4429:
# And
#
# 488
# 00:17:54,760 --> 00:17:56,292
# Crux_4429:
# there's a button
#
# 489
# 00:17:56,292 --> 00:17:57,536
# Crux_4429:
# located on the winding knob
#
# 490
# 00:17:57,536 --> 00:17:58,236
# Crux_4429:
# that kind of
#
# 491
# 00:17:58,236 --> 00:18:00,120
# Crux_4429:
# temporarily deactivates the,
#
# 492
# 00:18:00,120 --> 00:18:01,908
# Crux_4429:
# the load stones and and allows
#
# 493
# 00:18:01,908 --> 00:18:03,152
# Crux_4429:
# the face to flip open.
#
# 494
# 00:18:03,500 --> 00:18:05,256
# Crux_4429:
# Just by holding this token,
#
# 495
# 00:18:05,256 --> 00:18:06,756
# Crux_4429:
# you can use it
#
# 496
# 00:18:07,264 --> 00:18:09,852
# Crux_4429:
# to cast Mending twice a day. That's
#
# 497
# 00:18:09,852 --> 00:18:11,672
# CS12_4510:
# impressive.
#
# 498
# 00:18:12,052 --> 00:18:12,784
# Crux_4429:
# And
#
# 499
# 00:18:12,784 --> 00:18:14,860
# Crux_4429:
# identification also
#
# 500
# 00:18:14,860 --> 00:18:15,656
# Crux_4429:
# tells you that.
#
# 501
# 00:18:16,228 --> 00:18:16,544
# Crux_4429:
# So
#
# 502
# 00:18:16,544 --> 00:18:18,460
# Crux_4429:
# you come across something interesting,
#
# 503
# 00:18:18,460 --> 00:18:19,032
# Crux_4429:
# actually.
#
# 504
# 00:18:19,032 --> 00:18:21,172
# Crux_4429:
# You remember your Hexmere project?
#
# 505
# 00:18:21,172 --> 00:18:22,928
# CS12_4510:
# Yes.
#
# 506
# 00:18:22,928 --> 00:18:25,164
# Crux_4429:
# Where it has runes that identify it.
#
# 507
# 00:18:25,164 --> 00:18:26,664
# CS12_4510:
# Mm-hmm.
#
# 508
# 00:18:27,140 --> 00:18:29,280
# Crux_4429:
# You're able to detect
#
# 509
# 00:18:29,280 --> 00:18:30,460
# Crux_4429:
# similar
#
# 510
# 00:18:30,460 --> 00:18:31,384
# Crux_4429:
# ideology
#
# 511
# 00:18:31,384 --> 00:18:32,052
# Crux_4429:
# in the
#
# 512
# 00:18:32,052 --> 00:18:33,648
# Crux_4429:
# construction of this pocket watch.
#
# 513
# 00:18:33,648 --> 00:18:35,244
# Crux_4429:
# Like, this pocket watch has, like,
#
# 514
# 00:18:35,244 --> 00:18:35,944
# Crux_4429:
# an ID.
#
# 515
# 00:18:35,944 --> 00:18:36,548
# CS12_4510:
# Okay,
#
# 516
# 00:18:36,548 --> 00:18:46,656
# CS12_4510:
# good to know. I share this information with the party, but it's magical. It's just a token. Andrea, could you get me a snowball?
#
# 517
# 00:18:46,656 --> 00:18:47,132
# IlMaximuslI_9218:
# Uh, I
#
# 518
# 00:18:47,132 --> 00:18:51,000
# IlMaximuslI_9218:
# can do one better. And she just, like, shapes water out of her
#
# 519
# 00:18:51,000 --> 00:18:52,660
# IlMaximuslI_9218:
# watering skin, and it's just sort of
#
# 520
# 00:18:52,660 --> 00:18:53,584
# IlMaximuslI_9218:
# in her hand now.
#
# 521
# 00:18:53,584 --> 00:18:57,740
# CS12_4510:
# Yes, but I want actually pure water, I don't want to gunk on any of the...
#
# 522
# 00:18:57,740 --> 00:18:58,088
# IlMaximuslI_9218:
# I
#
# 523
# 00:18:58,088 --> 00:18:59,268
# IlMaximuslI_9218:
# don't drink gunk!
#
# 524
# 00:18:59,268 --> 00:18:59,616
# IlMaximuslI_9218:
# Look how
#
# 525
# 00:18:59,616 --> 00:19:00,220
# IlMaximuslI_9218:
# fucking good
#
# 526
# 00:19:00,220 --> 00:19:01,208
# IlMaximuslI_9218:
# fucking snow is.
#
# 527
# 00:19:01,208 --> 00:19:02,228
# JadePixie_7138:
# Heh heh heh heh.
#
# 528
# 00:19:02,228 --> 00:19:03,568
# Crux_4429:
# Heh heh heh.
#
# 529
# 00:19:03,568 --> 00:19:05,676
# IlMaximuslI_9218:
# She like, uh, goes outside,
#
# 530
# 00:19:05,676 --> 00:19:07,688
# IlMaximuslI_9218:
# shapes some snow into her hand,
#
# 531
# 00:19:07,688 --> 00:19:08,644
# IlMaximuslI_9218:
# comes back,
#
# 532
# 00:19:08,644 --> 00:19:11,008
# IlMaximuslI_9218:
# it's a little cold, this is like looking at you like,
#
# 533
# 00:19:11,008 --> 00:19:11,516
# IlMaximuslI_9218:
# here's your
#
# 534
# 00:19:11,516 --> 00:19:12,280
# IlMaximuslI_9218:
# pure water,
#
# 535
# 00:19:12,280 --> 00:19:12,820
# IlMaximuslI_9218:
# you mmm.
#
# 536
# 00:19:12,820 --> 00:19:14,960
# IlMaximuslI_9218:
# And then she just instantly liquefies it.
#
# 537
# 00:19:14,960 --> 00:19:15,724
# CS12_4510:
# Yep.
#
# 538
# 00:19:15,724 --> 00:19:16,392
# CS12_4510:
# Yeah.
#
# 539
# 00:19:16,392 --> 00:19:17,700
# IlMaximuslI_9218:
# There, pure... snow water.
#
# 540
# 00:19:18,940 --> 00:19:21,624
# CS12_4510:
# Yes, it is. Thank you.
#
# 541
# 00:19:21,624 --> 00:19:25,492
# IlMaximuslI_9218:
# Much better than my drinkable water. Anyway, here you go.
#
# 542
# 00:19:25,492 --> 00:19:29,936
# CS12_4510:
# Yeah, it's not about you. It's about the skin itself.
#
# 543
# 00:19:29,936 --> 00:19:32,076
# CS12_4510:
# Um, and...
#
# 544
# 00:19:32,076 --> 00:19:33,000
# IlMaximuslI_9218:
# What?
#
# 545
# 00:19:33,000 --> 00:19:36,868
# CS12_4510:
# I was speaking ill of your water skin. And, uh,
#
# 546
# 00:19:37,504 --> 00:19:38,620
# CS12_4510:
# I just,
#
# 547
# 00:19:38,620 --> 00:19:40,824
# CS12_4510:
# I try to figure out,
#
# 548
# 00:19:40,824 --> 00:19:44,852
# CS12_4510:
# I hope that I don't need to take this apart, but I do have Tinker's tools
#
# 549
# 00:19:44,852 --> 00:19:46,416
# CS12_4510:
# if that's necessary.
#
# 550
# 00:19:47,980 --> 00:19:48,872
# Crux_4429:
# Are you trying to refill it?
#
# 551
# 00:19:48,872 --> 00:19:50,148
# CS12_4510:
# I'm trying to refill it.
#
# 552
# 00:19:50,148 --> 00:19:54,080
# Crux_4429:
# It's painfully obvious how to refill it. Like there's like a little
#
# 553
# 00:19:54,080 --> 00:19:54,652
# Crux_4429:
# glass vial
#
# 554
# 00:19:54,652 --> 00:19:55,928
# Crux_4429:
# that
#
# 555
# 00:19:55,928 --> 00:19:57,972
# Crux_4429:
# has like a little screw cap topper.
#
# 556
# 00:19:57,972 --> 00:20:00,336
# Crux_4429:
# You just unscrew the topper, you fill the water in there,
#
# 557
# 00:20:01,768 --> 00:20:02,884
# Crux_4429:
# screw the topper back on.
#
# 558
# 00:20:02,884 --> 00:20:08,352
# CS12_4510:
# Well, I'll make sure to investigate it for any sort of magical traps.
#
# 559
# 00:20:08,892 --> 00:20:10,040
# Crux_4429:
# You have an
#
# 560
# 00:20:10,040 --> 00:20:12,692
# Crux_4429:
# automatic success, did you earlier identify?
#
# 561
# 00:20:12,692 --> 00:20:13,392
# CS12_4510:
# Yeah.
#
# 562
# 00:20:13,392 --> 00:20:16,812
# CS12_4510:
# Great success. And I just
#
# 563
# 00:20:16,812 --> 00:20:19,624
# CS12_4510:
# refill the watch,
#
# 564
# 00:20:19,624 --> 00:20:21,380
# CS12_4510:
# look at it, examine it,
#
# 565
# 00:20:22,808 --> 00:20:25,652
# CS12_4510:
# see that again. And now Max,
#
# 566
# 00:20:25,652 --> 00:20:27,504
# CS12_4510:
# and I hand the watch back to you.
#
# 567
# 00:20:27,504 --> 00:20:30,220
# CS12_4510:
# What exactly did you do before? That's it.
#
# 568
# 00:20:30,220 --> 00:20:31,496
# CS12_4510:
# Show us.
#
# 569
# 00:20:31,496 --> 00:20:33,572
# Marburg42_5566:
# He just quickly does the same thing. He
#
# 570
# 00:20:33,572 --> 00:20:38,624
# Marburg42_5566:
# turns on his detect magic, he casts detect magic, he looks at it, I assume it has the same aura?
#
# 571
# 00:20:38,624 --> 00:20:39,580
# Crux_4429:
# Max Yeah. Max
#
# 572
# 00:20:39,580 --> 00:20:40,792
# Marburg42_5566:
# And then he'll
#
# 573
# 00:20:40,792 --> 00:20:41,364
# Marburg42_5566:
# open it,
#
# 574
# 00:20:41,364 --> 00:20:41,808
# Marburg42_5566:
# start
#
# 575
# 00:20:41,808 --> 00:20:42,924
# Marburg42_5566:
# everything the same way.
#
# 576
# 00:20:42,924 --> 00:20:43,496
# Crux_4429:
# Um,
#
# 577
# 00:20:43,496 --> 00:20:45,412
# Crux_4429:
# you open it, there's a pulse of magic.
#
# 578
# 00:20:45,412 --> 00:20:45,952
# Crux_4429:
# Um,
#
# 579
# 00:20:45,952 --> 00:20:46,524
# Crux_4429:
# the-
#
# 580
# 00:20:46,524 --> 00:20:47,160
# Crux_4429:
# what's the word?
#
# 581
# 00:20:47,160 --> 00:20:51,796
# Crux_4429:
# I guess those of you paying close attention, please roll an investigation check.
#
# 582
# 00:20:51,796 --> 00:20:55,504
# IlMaximuslI_9218:
# Uh, sure. I mean, I'm not good at it, but I am paying close attention.
#
# 583
# 00:20:55,504 --> 00:20:57,420
# CS12_4510:
# Okay.
#
# 584
# 00:20:57,420 --> 00:20:59,688
# JadePixie_7138:
# You know, guys also have plus one from
#
# 585
# 00:20:59,688 --> 00:21:00,644
# JadePixie_7138:
# being close to me.
#
# 586
# 00:21:01,376 --> 00:21:03,068
# IlMaximuslI_9218:
# Ooh, 20 then.
#
# 587
# 00:21:03,068 --> 00:21:04,376
# CS12_4510:
# Yes.
#
# 588
# 00:21:04,376 --> 00:21:05,364
# Marburg42_5566:
# Nice.
#
# 589
# 00:21:05,364 --> 00:21:06,128
# Marburg42_5566:
# Two 20s.
#
# 590
# 00:21:07,372 --> 00:21:08,456
# Crux_4429:
# Everybody succeeds.
#
# 591
# 00:21:08,456 --> 00:21:09,092
# Crux_4429:
# Um.
#
# 592
# 00:21:09,092 --> 00:21:11,776
# CS12_4510:
# Still, darling.
#
# 593
# 00:21:11,776 --> 00:21:12,220
# Crux_4429:
# The
#
# 594
# 00:21:12,984 --> 00:21:13,748
# Crux_4429:
# Caesar lookout.
#
# 595
# 00:21:14,288 --> 00:21:18,732
# Crux_4429:
# Though nothing seems to happen to Max while he's playing with this watch,
#
# 596
# 00:21:19,304 --> 00:21:20,100
# Crux_4429:
# the
#
# 597
# 00:21:20,100 --> 00:21:22,016
# Crux_4429:
# water inside the watch
#
# 598
# 00:21:22,016 --> 00:21:23,804
# Crux_4429:
# over the course of the next
#
# 599
# 00:21:23,804 --> 00:21:27,928
# Crux_4429:
# 30 seconds, you can see that it's visibly dropped the water level.
#
# 600
# ...
#
# 3595
# 02:12:46,400 --> 02:12:46,876
# IlMaximuslI_9218:
# Oh
#
# 3596
# 02:12:48,148 --> 02:12:48,784
# Marburg42_5566:
# right,
#
# 3597
# 02:12:48,784 --> 02:12:49,612
# Marburg42_5566:
# we could say...
#
# 3598
# 02:12:49,612 --> 02:12:51,624
# Marburg42_5566:
# never mind Estelle, just kidding.
#
# 3599
# 02:12:51,624 --> 02:12:54,852
# CS12_4510:
# We can say that she had a slip and fall.
#
# 3600
# 02:12:55,548 --> 02:12:56,440
# Marburg42_5566:
# Yeah.
#
# 3601
# 02:12:56,440 --> 02:12:57,524
# IlMaximuslI_9218:
# No, no.
#
# 3602
# 02:12:57,524 --> 02:12:58,128
# IlMaximuslI_9218:
# Um.
#
# 3603
# 02:12:58,128 --> 02:12:59,756
# Crux_4429:
# Sacrifice her to the giant spiders.
#
# 3604
# 02:12:59,756 --> 02:13:02,408
# JadePixie_7138:
# I mean, she can do what she wants.
#
# 3605
# 02:13:02,408 --> 02:13:04,196
# CS12_4510:
# Oh yes.
#
# 3606
# 02:13:04,196 --> 02:13:05,120
# JadePixie_7138:
# But I mean, I don't,
#
# 3607
# 02:13:05,120 --> 02:13:06,876
# JadePixie_7138:
# not necessarily in a hurry
#
# 3608
# 02:13:06,876 --> 02:13:08,376
# JadePixie_7138:
# to get them to move in
#
# 3609
# 02:13:08,376 --> 02:13:10,452
# JadePixie_7138:
# when we haven't finished exploring it yet.
#
# 3610
# 02:13:11,792 --> 02:13:15,628
# IlMaximuslI_9218:
# Yeah. I think we control the tokens, but those who are willing can.
#
# 3611
# 02:13:15,628 --> 02:13:28,200
# CS12_4510:
# I'm, I guess, I guess what I'm thinking about that is, is, uh, the pa- the, the, the Tavern of Many Fashions or Colors or whatever it is, is already under suspicion by Balaran Tower.
#
# 3612
# 02:13:28,200 --> 02:13:38,948
# CS12_4510:
# They're using it as a safe house. They are innocent. So like, if they're going to be sitting around all day, I feel like it's not a bad idea to have them guarding
#
# 3613
# 02:13:38,948 --> 02:13:41,920
# CS12_4510:
# our entrance, we are working with them.
#
# 3614
# 02:13:41,920 --> 02:13:43,452
# JadePixie_7138:
# I think we should
#
# 3615
# 02:13:43,452 --> 02:13:44,056
# JadePixie_7138:
# like
#
# 3616
# 02:13:44,056 --> 02:13:46,740
# JadePixie_7138:
# after we finish exploring we can
#
# 3617
# 02:13:46,740 --> 02:13:48,880
# JadePixie_7138:
# probably go back there and like
#
# 3618
# 02:13:48,880 --> 02:13:50,668
# JadePixie_7138:
# have them investigate
#
# 3619
# 02:13:50,668 --> 02:13:52,584
# JadePixie_7138:
# independently I guess that they want.
#
# 3620
# 02:13:53,860 --> 02:13:56,096
# CS12_4510:
# Well, collaboratively I would say.
#
# 3621
# 02:13:56,540 --> 02:13:59,832
# IlMaximuslI_9218:
# We already know who we can and can't trust and
#
# 3622
# 02:13:59,832 --> 02:14:00,980
# IlMaximuslI_9218:
# that was said we were
#
# 3623
# 02:14:00,980 --> 02:14:02,992
# IlMaximuslI_9218:
# under their good graces so I
#
# 3624
# 02:14:02,992 --> 02:14:04,076
# IlMaximuslI_9218:
# think we can trust them
#
# 3625
# 02:14:04,076 --> 02:14:06,792
# IlMaximuslI_9218:
# at least to the extent of
#
# 3626
# 02:14:06,792 --> 02:14:08,644
# IlMaximuslI_9218:
# together is the only way way we'll be able to
#
# 3627
# 02:14:08,644 --> 02:14:10,432
# IlMaximuslI_9218:
# get and go through because Max
#
# 3628
# 02:14:10,432 --> 02:14:11,932
# IlMaximuslI_9218:
# with the bloodstone is the key.
#
# 3629
# 02:14:11,932 --> 02:14:15,032
# IlMaximuslI_9218:
# So they can't like explore anything more than us.
#
# 3630
# 02:14:15,796 --> 02:14:20,272
# IlMaximuslI_9218:
# So having them be based there, then they can find it for us while we go out and do other stuff and then
#
# 3631
# 02:14:20,272 --> 02:14:22,540
# IlMaximuslI_9218:
# we help out when we are actually here camping.
#
# 3632
# 02:14:23,848 --> 02:14:27,460
# IlMaximuslI_9218:
# I mean, this is putting a lot of trust on, uh, Maga's words, but
#
# 3633
# 02:14:27,460 --> 02:14:46,784
# CS12_4510:
# I mean, it's not like Maga was vouching for him. Um, but we do like Kailas. We've shared information with him. We decided to complain about the bloodstone. He's given us a lot of information because we worked with him. That was super helpful.
#
# 3634
# 02:14:47,164 --> 02:14:48,056
# IlMaximuslI_9218:
# And resources.
#
# 3635
# 02:14:48,056 --> 02:14:50,932
# CS12_4510:
# In understanding what's actually happening.
#
# 3636
# 02:14:50,932 --> 02:14:51,728
# Marburg42_5566:
# Yeah.
#
# 3637
# 02:14:52,844 --> 02:14:58,504
# CS12_4510:
# If Estelle already knows this place, there's no way that she's not reporting back to Tyla's.
#
# 3638
# 02:14:58,504 --> 02:14:59,396
# Crux_4429:
# She's been here before.
#
# 3639
# 02:15:01,596 --> 02:15:02,872
# CS12_4510:
# Might as well
#
# 3640
# 02:15:02,872 --> 02:15:11,604
# CS12_4510:
# let them know. I was going to let them know this session, but we just didn't have that conversation with them, that their safe house is under some pretty bad suspicion.
#
# 3641
# 02:15:11,604 --> 02:15:13,488
# CS12_4510:
# So they might want to get out of there.
#
# 3642
# 02:15:13,488 --> 02:15:20,684
# CS12_4510:
# This just happens to be a place that is like, well, this might be a really good safe house for them to be, or to move to. And it
#
# 3643
# 02:15:20,684 --> 02:15:23,528
# CS12_4510:
# gives us a minor workforce and
#
# 3644
# 02:15:23,528 --> 02:15:29,028
# CS12_4510:
# an expeditionary crew. As long as they can support and feed them, we should be good.
#
# 3645
# 02:15:29,028 --> 02:15:32,384
# IlMaximuslI_9218:
# And Max with the Bloodstones the key, so they can't get anywhere we don't want
#
# 3646
# 02:15:32,384 --> 02:15:33,308
# IlMaximuslI_9218:
# them to go to.
#
# 3647
# 02:15:33,308 --> 02:15:34,072
# CS12_4510:
# Yeah.
#
# 3648
# 02:15:34,072 --> 02:15:35,156
# Marburg42_5566:
# That's the idea.
#
# 3649
# 02:15:35,156 --> 02:15:36,176
# CS12_4510:
# That is the idea.
#
# 3650
# 02:15:36,176 --> 02:15:38,764
# IlMaximuslI_9218:
# I think it's a really good idea. Um, but that's me personally.
#
# 3651
# 02:15:38,764 --> 02:15:41,256
# CS12_4510:
# I think we open ourselves up to being backstabbed
#
# 3652
# 02:15:41,256 --> 02:15:43,684
# CS12_4510:
# or their brains sucked out and
#
# 3653
# 02:15:43,684 --> 02:15:46,240
# CS12_4510:
# the information being leaked, but...
#
# 3654
# 02:15:46,240 --> 02:15:49,148
# IlMaximuslI_9218:
# By the same time, there's pros and cons of
#
# 3655
# 02:15:49,148 --> 02:15:52,728
# IlMaximuslI_9218:
# what might be bad if it happens, but there's a lot of good that will happen.
#
# 3656
# 02:15:53,524 --> 02:16:00,624
# CS12_4510:
# Yeah. Like, if we disappear wholesale off the face of the earth and we were just based out of here, what would happen is, Mariposa, uh,
#
# 3657
# 02:16:01,260 --> 02:16:02,344
# CS12_4510:
# like,
#
# 3658
# 02:16:02,344 --> 02:16:03,332
# CS12_4510:
# Belarren Tower,
#
# 3659
# 02:16:03,332 --> 02:16:07,328
# CS12_4510:
# anybody else who's keeping and I on us would cast divination in order to be like,
#
# 3660
# 02:16:07,328 --> 02:16:10,908
# CS12_4510:
# they would cast the spell divination in order to figure out our location.
#
# 3661
# 02:16:10,908 --> 02:16:12,984
# CS12_4510:
# And it would point them exactly to where we are.
#
# 3662
# 02:16:12,984 --> 02:16:17,428
# CS12_4510:
# It wouldn't be on this plane, but you know, it took us how long to figure it out?
#
# 3663
# 02:16:17,428 --> 02:16:18,480
# Marburg42_5566:
# Three and a half months.
#
# 3664
# 02:16:22,912 --> 02:16:27,196
# CS12_4510:
# Yeah, in secret at night. Disperse.
#
# 3665
# 02:16:27,608 --> 02:16:27,988
# Crux_4429:
# All
#
# 3666
# 02:16:27,988 --> 02:16:28,816
# Marburg42_5566:
# right.
#
# 3667
# 02:16:29,420 --> 02:16:30,088
# Crux_4429:
# To be fair,
#
# 3668
# 02:16:30,088 --> 02:16:30,980
# Marburg42_5566:
# to be fair,
#
# 3669
# 02:16:30,980 --> 02:16:33,952
# Crux_4429:
# you had an edge, you had a big fucking edge.
#
# 3670
# 02:16:33,952 --> 02:16:34,620
# IlMaximuslI_9218:
# With our?
#
# 3671
# 02:16:34,620 --> 02:16:35,192
# Crux_4429:
# Um...
#
# 3672
# 02:16:36,724 --> 02:16:38,544
# Crux_4429:
# Yeah, you knew that something was here.
#
# 3673
# 02:16:38,544 --> 02:16:43,244
# CS12_4510:
# Yeah, and if they try to figure out where we're being watched by people,
#
# 3674
# 02:16:43,244 --> 02:16:49,288
# CS12_4510:
# like we're sneaking away from those people, if we disappear, they can just use divination magic in order to say, where are they hiding?
#
# 3675
# 02:16:49,288 --> 02:16:53,252
# CS12_4510:
# And since we don't have any fucking magic resistance or ways to hide that,
#
# 3676
# 02:16:53,252 --> 02:16:55,936
# CS12_4510:
# it'd be like the water clock tower.
#
# 3677
# 02:16:56,348 --> 02:16:58,648
# Crux_4429:
# Well... Demiplane.
#
# 3678
# 02:16:58,648 --> 02:17:05,492
# CS12_4510:
# Yeah, but it's not... There's no reason that divination would be limited by that. it wouldn't tell us it wouldn't tell them that we're in a demiplane yeah
#
# 3679
# 02:17:05,904 --> 02:17:06,284
# CS12_4510:
# but
#
# 3680
# 02:17:06,284 --> 02:17:07,144
# CS12_4510:
# you know either
#
# 3681
# 02:17:07,144 --> 02:17:08,708
# IlMaximuslI_9218:
# way i'm i'm
#
# 3682
# 02:17:08,708 --> 02:17:10,208
# IlMaximuslI_9218:
# for uh getting the
#
# 3683
# 02:17:10,208 --> 02:17:11,804
# IlMaximuslI_9218:
# organization in here
#
# 3684
# 02:17:11,804 --> 02:17:12,696
# CS12_4510:
# yeah
#
# 3685
# 02:17:12,696 --> 02:17:13,396
# IlMaximuslI_9218:
# based out here
#
# 3686
# 02:17:13,396 --> 02:17:14,608
# CS12_4510:
# i'm
#
# 3687
# 02:17:14,608 --> 02:17:26,348
# CS12_4510:
# i'm i could go either way i'm not attached to either but i am for getting max's like stuff here francesca notably
#
# 3688
# 02:17:26,348 --> 02:17:27,112
# IlMaximuslI_9218:
# oh yeah
#
# 3689
# 02:17:27,112 --> 02:17:27,524
# Marburg42_5566:
# that
#
# 3690
# 02:17:27,524 --> 02:17:29,536
# IlMaximuslI_9218:
# might be an interesting uh mix
#
# 3691
# 02:17:29,536 --> 02:17:32,604
# Marburg42_5566:
# what do you know about who who what do you know about friendship.
#
# 3692
# 02:17:32,604 --> 02:17:34,296
# IlMaximuslI_9218:
# No, this is out of character.
#
# 3693
# 02:17:34,296 --> 02:17:36,244
# CS12_4510:
# This is out of character. I
#
# 3694
# 02:17:36,244 --> 02:17:37,712
# Marburg42_5566:
# know I'm just kidding.
#
# 3695
# 02:17:38,508 --> 02:17:44,520
# Marburg42_5566:
# I actually think I should start carrying around too. It's about time that that that secret has to come out at some point.
#
# 3696
# 02:17:44,520 --> 02:17:48,036
# CS12_4510:
# Yeah. And it's just like, you're either gonna start abandoning her at the house. Yeah,
#
# 3697
# 02:17:48,036 --> 02:17:49,312
# IlMaximuslI_9218:
# because you have like the
#
# 3698
# 02:17:49,312 --> 02:17:50,076
# Marburg42_5566:
# or
#
# 3699
# 02:17:50,076 --> 02:17:52,536
# CS12_4510:
# you're gonna move her to where it matters.
#
# 3700
# 02:17:52,536 --> 02:17:52,948
# Marburg42_5566:
# Right?
#
# 3701
# 02:17:52,948 --> 02:17:58,320
# Marburg42_5566:
# Well, I've Yeah, so I have to, I will start addressing that because I agree. It's time
#
# 3702
# 02:17:58,320 --> 02:18:01,900
# IlMaximuslI_9218:
# Because you like have the ability to just carry stuff in your pocket or in your
#
# 3703
# 02:18:01,900 --> 02:18:03,688
# Marburg42_5566:
# in my ring. Yeah.
#
# 3704
# 02:18:04,004 --> 02:18:04,544
# IlMaximuslI_9218:
# Your ring
#
# 3705
# 02:18:04,544 --> 02:18:05,788
# IlMaximuslI_9218:
# and like it's a full room,
#
# 3706
# 02:18:05,788 --> 02:18:08,568
# Marburg42_5566:
# which I almost when when
#
# 3707
# 02:18:08,568 --> 02:18:13,364
# Marburg42_5566:
# Aloué was using the watch, I was thought like I could put myself in the ring and have her
#
# 3708
# 02:18:13,364 --> 02:18:14,352
# Marburg42_5566:
# hold the ring.
#
# 3709
# 02:18:14,796 --> 02:18:15,368
# JadePixie_7138:
# That's
#
# 3710
# 02:18:15,368 --> 02:18:16,068
# Marburg42_5566:
# true.
#
# 3711
# 02:18:16,480 --> 02:18:17,628
# Marburg42_5566:
# But I was like, Yeah,
#
# 3712
# 02:18:17,628 --> 02:18:19,704
# Marburg42_5566:
# one day soon. It's gonna happen soon.
#
# 3713
# 02:18:19,704 --> 02:18:20,084
# Crux_4429:
# Yeah,
#
# 3714
# 02:18:20,464 --> 02:18:23,788
# Crux_4429:
# that would work. You can put yourself in the ring, but you can't put other people in the ring.
#
# 3715
# 02:18:23,788 --> 02:18:24,456
# Crux_4429:
# that so.
#
# 3716
# 02:18:24,836 --> 02:18:27,808
# IlMaximuslI_9218:
# Can you put Francesca in the mirror and then put the mirror in the ring?
#
# 3717
# 02:18:29,076 --> 02:18:32,112
# JadePixie_7138:
# I'm personally really excited for us to
#
# 3718
# 02:18:32,716 --> 02:18:34,760
# JadePixie_7138:
# reveal each other's secrets.
#
# 3719
# 02:18:35,300 --> 02:18:38,336
# CS12_4510:
# Yeah, there was fun shit today. Yeah,
#
# 3720
# 02:18:38,336 --> 02:18:40,220
# Marburg42_5566:
# it's time for them to start coming out.
#
# 3721
# 02:18:41,044 --> 02:18:47,888
# Marburg42_5566:
# I'll probably reveal Francesca before I reveal the fact that I really haven't had a bite of food since I picked up the
#
# 3722
# 02:18:47,888 --> 02:18:48,556
# IlMaximuslI_9218:
# bloodstone.
#
# 3723
# 02:18:48,556 --> 02:18:49,928
# CS12_4510:
# Oh, you've had several bites.
#
# 3724
# 02:18:51,072 --> 02:18:54,236
# IlMaximuslI_9218:
# yeah, you specifically ate that fruit
#
# 3725
# 02:18:54,236 --> 02:18:55,160
# JadePixie_7138:
# so our character-
#
# 3726
# 02:18:55,668 --> 02:18:56,560
# Marburg42_5566:
# oh i've eaten it
#
# 3727
# 02:18:57,260 --> 02:18:58,792
# Marburg42_5566:
# it doesn't do anything
#
# 3728
# 02:18:58,792 --> 02:18:59,972
# JadePixie_7138:
# our characters don't
#
# 3729
# 02:18:59,972 --> 02:19:01,920
# JadePixie_7138:
# know that you eat curds
#
# 3730
# 02:19:02,396 --> 02:19:14,968
# CS12_4510:
# nope, he's keeping it to himself he's afraid of the fact that he's vitrifying we'll eventually remind him he'll unattune and then he'll be like oh man i forgot how good this tastes and i was like what? this is what i've made every day for the past three weeks
#
# 3731
# 02:19:14,968 --> 02:19:15,316
# Marburg42_5566:
# nope
#
# 3732
# 02:19:15,316 --> 02:19:17,104
# Marburg42_5566:
# i've been keeping it secret
#
# 3733
# 02:19:17,104 --> 02:19:17,420
# IlMaximuslI_9218:
# what?
#
# 3734
# 02:19:17,420 --> 02:19:18,728
# IlMaximuslI_9218:
# it's almost kind of sloppy
#
# 3735
# 02:19:18,728 --> 02:19:19,524
# JadePixie_7138:
# Okay, so
#
# 3736
# 02:19:19,524 --> 02:19:22,176
# JadePixie_7138:
# we know that he's vitrifying, we just don't know that
#
# 3737
# 02:19:22,176 --> 02:19:23,228
# JadePixie_7138:
# he's eating karasi.
#
# 3738
# 02:19:23,704 --> 02:19:26,996
# CS12_4510:
# We don't know that he's eating precious metals.
#
# 3739
# 02:19:26,996 --> 02:19:27,344
# Marburg42_5566:
# Right.
#
# 3740
# 02:19:27,344 --> 02:19:27,692
# Crux_4429:
# So
#
# 3741
# 02:19:27,692 --> 02:19:28,392
# Crux_4429:
# also,
#
# 3742
# 02:19:28,392 --> 02:19:31,716
# Crux_4429:
# just so you know, Francesca is the notable exception of
#
# 3743
# 02:19:31,716 --> 02:19:33,984
# Crux_4429:
# somebody that you can carry in your exponential space.
#
# 3744
# 02:19:33,984 --> 02:19:37,052
# Marburg42_5566:
# Right, right. I figured that was because she's pretty much the
#
# 3745
# 02:19:37,052 --> 02:19:38,744
# Marburg42_5566:
# avatar of my
#
# 3746
# 02:19:38,744 --> 02:19:39,348
# Marburg42_5566:
# pact.
#
# 3747
# 02:19:39,348 --> 02:19:39,760
# Crux_4429:
# Yeah,
#
# 3748
# 02:19:39,760 --> 02:19:41,036
# Crux_4429:
# yeah, she's mad out of stone.
#
# 3749
# 02:19:41,036 --> 02:19:47,400
# CS12_4510:
# Yeah, well, there's a lot of interesting stuff here.
#
# 3750
# 02:19:50,620 --> 02:19:57,656
# Crux_4429:
# Thank you for freaking out about the book, by the way, Bryce. That's what I live for. I was holding onto this for so long, just like, man, this is going to be good to reveal.
#
# 3751
# 02:19:57,656 --> 02:19:58,836
# JadePixie_7138:
# Oh.
#
# 3752
# 02:20:00,368 --> 02:20:02,188
# JadePixie_7138:
# Yeah, that was a lot of fun.
#
# 3753
# 02:20:03,112 --> 02:20:03,780
# JadePixie_7138:
# This
#
# 3754
# 02:20:03,780 --> 02:20:04,992
# JadePixie_7138:
# text right here
#
# 3755
# 02:20:04,992 --> 02:20:05,948
# JadePixie_7138:
# adds a lot.
#
# 3756
# 02:20:07,732 --> 02:20:11,472
# IlMaximuslI_9218:
# Yeah, with the ambient music, it was like, oh, it's little spooky
#
# 3757
# 02:20:11,472 --> 02:20:12,076
# IlMaximuslI_9218:
# okay
#
# 3758
# 02:20:12,076 --> 02:20:12,968
# IlMaximuslI_9218:
# possessions
#
# 3759
# 02:20:13,476 --> 02:20:13,856
# CS12_4510:
# yeah
#
# 3760
# 02:20:13,856 --> 02:20:19,452
# CS12_4510:
# I appreciate your perspective that isn't mine Sam because I didn't think about that at all
#
# 3761
# 02:20:19,452 --> 02:20:19,800
# IlMaximuslI_9218:
# hmm
#
# 3762
# 02:20:19,800 --> 02:20:20,596
# IlMaximuslI_9218:
# you're welcome
#
# 3763
# 02:20:20,596 --> 02:20:21,424
# CS12_4510:
# yeah all
#
# 3764
# 02:20:21,424 --> 02:20:23,820
# Crux_4429:
# right well we're about six minutes over time
#
# 3765
# 02:20:23,820 --> 02:20:24,872
# Crux_4429:
# but I'm gonna go ahead and
#
# 3766
# 02:20:24,872 --> 02:20:25,892
# Crux_4429:
# kick the Scribe.
#
# 3767
# 02:20:25,892 --> 02:20:28,128
# CS12_4510:
# Yeah, get out of here, Scribe.
#
# 3768
# 02:20:28,128 --> 02:20:28,540
# JadePixie_7138:
# Yeah.
#
# 3769
# 02:20:28,540 --> 02:20:29,496
# IlMaximuslI_9218:
# Bye, Scribe.
#
# 3770
# 02:20:29,496 --> 02:20:30,868
# CS12_4510:
# We appreciate you though.

# %%
## Script format
text = ''
current_speaker = ''
for idx, row in seg_short.sort_values('start').iterrows():
    speaker = utils.get_discord_name(row['file']).split('_')[0]
    s = row['text']
    if len(s.strip()) > 0:
        if not current_speaker == speaker:
            text += f"\n\n{speaker}:\n"
            current_speaker = speaker
    text = ' '.join([text,s])


with open(os.path.join(folder, 'script.txt'), 'w') as f:
    f.write(text)
